# %%
'''
图像增广处理汇总
'''

import cv2
import abc
import random
import numpy as np
from PIL import Image, ImageEnhance, ImageFilter, ImageOps, ImageDraw

def cv2pil(image):
    """
    将bgr格式的numpy的图像转换为pil
    :param image:   图像数组
    :return:    Image对象
    """
    assert isinstance(image, np.ndarray), 'input image type is not cv2'
    if len(image.shape) == 2:
        return Image.fromarray(image)
    elif len(image.shape) == 3:
        return Image.fromarray(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

def get_pil_image(image):
    """
    将图像统一转换为PIL格式
    :param image:   图像
    :return:    Image格式的图像
    """
    if isinstance(image, Image.Image):  # or isinstance(image, PIL.JpegImagePlugin.JpegImageFile):
        return image
    elif isinstance(image, np.ndarray):
        return cv2pil(image)

def get_cv_image(image):
    """
    将图像转换为numpy格式的数据
    :param image:   图像
    :return:    ndarray格式的图像数据
    """
    if isinstance(image, np.ndarray):
        return image
    elif isinstance(image, Image.Image):  # or isinstance(image, PIL.JpegImagePlugin.JpegImageFile):
        return pil2cv(image)

def pil2cv(image):
    """
    将Image对象转换为ndarray格式图像
    :param image:   图像对象
    :return:    ndarray图像数组
    """
    if len(image.split()) == 1:
        return np.asarray(image)
    elif len(image.split()) == 3:
        return cv2.cvtColor(np.asarray(image), cv2.COLOR_RGB2BGR)
    elif len(image.split()) == 4:
        return cv2.cvtColor(np.asarray(image), cv2.COLOR_RGBA2BGR)

class TransBase(object):
    """
    数据增广的基类
    """

    def __init__(self, probability=1.):
        """
        初始化对象
        :param probability:     执行概率
        """
        super(TransBase, self).__init__()
        self.probability = probability

    @abc.abstractmethod
    def trans_function(self, _image):
        """
        初始化执行函数，需要进行重载
        :param _image:  待处理图像
        :return:    执行后的Image对象
        """
        pass

    # @utils.zlog
    def process(self, _image):
        """
        调用执行函数
        :param _image:  待处理图像
        :return:    执行后的Image对象
        """
        if np.random.random() < self.probability:
            return self.trans_function(_image)
        else:
            return _image

    def __call__(self, _image):
        """
        重载()，方便直接进行调用
        :param _image:  待处理图像
        :return:    执行后的Image
        """
        return self.process(_image)

class RandomContrast(TransBase):
    """
    随机对比度
    """

    def setparam(self, lower=0.5, upper=1.5):
        self.lower = lower
        self.upper = upper
        assert self.upper >= self.lower, "upper must be >= lower."
        assert self.lower >= 0, "lower must be non-negative."

    def trans_function(self, _image):
        _image = get_pil_image(_image)
        contrast_enhance = ImageEnhance.Contrast(_image)
        return contrast_enhance.enhance(random.uniform(self.lower, self.upper))

class RandomLine(TransBase):
    """
    在图像增加一条简单的随机线
    """

    def trans_function(self, image):
        image = get_pil_image(image)
        draw = ImageDraw.Draw(image)
        h = image.height
        w = image.width
        y0 = random.randint(h // 4, h * 3 // 4)
        y1 = np.clip(random.randint(-3, 3) + y0, 0, h - 1)
        color = random.randint(0, 30)
        draw.line(((0, y0), (w - 1, y1)), fill=(color, color, color), width=2)
        return image

class RandomBrightness(TransBase):
    """
    随机对比度
    """

    def setparam(self, lower=0.5, upper=1.5):
        self.lower = lower
        self.upper = upper
        assert self.upper >= self.lower, "upper must be >= lower."
        assert self.lower >= 0, "lower must be non-negative."

    def trans_function(self, image):
        image = get_pil_image(image)
        bri = ImageEnhance.Brightness(image)
        return bri.enhance(random.uniform(self.lower, self.upper))

class RandomColor(TransBase):
    """
    随机色彩平衡
    """

    def setparam(self, lower=0.5, upper=1.5):
        self.lower = lower
        self.upper = upper
        assert self.upper >= self.lower, "upper must be >= lower."
        assert self.lower >= 0, "lower must be non-negative."

    def trans_function(self, image):
        image = get_pil_image(image)
        col = ImageEnhance.Color(image)
        return col.enhance(random.uniform(self.lower, self.upper))

class RandomSharpness(TransBase):
    """
    随机锐度
    """

    def setparam(self, lower=0.5, upper=1.5):
        self.lower = lower
        self.upper = upper
        assert self.upper >= self.lower, "upper must be >= lower."
        assert self.lower >= 0, "lower must be non-negative."

    def trans_function(self, image):
        image = get_pil_image(image)
        sha = ImageEnhance.Sharpness(image)
        return sha.enhance(random.uniform(self.lower, self.upper))

class Compress(TransBase):
    """
    随机压缩率，利用jpeg的有损压缩来增广
    """

    def setparam(self, lower=5, upper=85):
        self.lower = lower
        self.upper = upper
        assert self.upper >= self.lower, "upper must be >= lower."
        assert self.lower >= 0, "lower must be non-negative."

    def trans_function(self, image):
        img = get_cv_image(image)
        param = [int(cv2.IMWRITE_JPEG_QUALITY), random.randint(self.lower, self.upper)]
        img_encode = cv2.imencode('.jpeg', img, param)
        img_decode = cv2.imdecode(img_encode[1], cv2.IMREAD_COLOR)
        pil_img = cv2pil(img_decode)
        if len(image.split()) == 1:
            pil_img = pil_img.convert('L')
        return pil_img

class Exposure(TransBase):
    """
    随机区域曝光
    """

    def setparam(self, lower=5, upper=10):
        self.lower = lower
        self.upper = upper
        assert self.upper >= self.lower, "upper must be >= lower."
        assert self.lower >= 0, "lower must be non-negative."

    def trans_function(self, image):
        image = get_cv_image(image)
        h, w = image.shape[:2]
        x0 = random.randint(0, w)
        y0 = random.randint(0, h)
        x1 = random.randint(x0, w)
        y1 = random.randint(y0, h)
        transparent_area = (x0, y0, x1, y1)
        mask = Image.new('L', (w, h), color=255)
        draw = ImageDraw.Draw(mask)
        mask = np.array(mask)
        if len(image.shape) == 3:
            mask = mask[:, :, np.newaxis]
            mask = np.concatenate([mask, mask, mask], axis=2)
        draw.rectangle(transparent_area, fill=random.randint(150, 255))
        reflection_result = image + (255 - mask)
        reflection_result = np.clip(reflection_result, 0, 255)
        return cv2pil(reflection_result)

class Rotate(TransBase):
    """
    随机旋转
    """

    def setparam(self, lower=-5, upper=5):
        self.lower = lower
        self.upper = upper
        assert self.upper >= self.lower, "upper must be >= lower."

    def trans_function(self, image):
        image = get_pil_image(image)
        rot = random.uniform(self.lower, self.upper)
        trans_img = image.rotate(rot, expand=True)
        return trans_img

class Blur(TransBase):
    """
    随机高斯模糊
    """

    def setparam(self, lower=0, upper=1):
        self.lower = lower
        self.upper = upper
        assert self.upper >= self.lower, "upper must be >= lower."
        assert self.lower >= 0, "lower must be non-negative."

    def trans_function(self, image):
        image = get_pil_image(image)
        image = image.filter(ImageFilter.GaussianBlur(radius=1.5))
        return image

class MotionBlur(TransBase):
    """
    随机运动模糊
    """

    def setparam(self, degree=5, angle=180):
        self.degree = degree
        self.angle = angle

    def trans_function(self, image):
        image = get_pil_image(image)
        angle = random.randint(0, self.angle)
        M = cv2.getRotationMatrix2D((self.degree / 2, self.degree / 2), angle, 1)
        motion_blur_kernel = np.diag(np.ones(self.degree))
        motion_blur_kernel = cv2.warpAffine(motion_blur_kernel, M, (self.degree, self.degree))
        motion_blur_kernel = motion_blur_kernel / self.degree
        image = image.filter(ImageFilter.Kernel(size=(self.degree, self.degree), kernel=motion_blur_kernel.reshape(-1)))
        return image

class Salt(TransBase):
    """
    随机椒盐噪音
    """

    def setparam(self, rate=0.02):
        self.rate = rate

    def trans_function(self, image):
        image = get_pil_image(image)
        num_noise = int(image.size[1] * image.size[0] * self.rate)
        # assert len(image.split()) == 1
        for k in range(num_noise):
            i = int(np.random.random() * image.size[1])
            j = int(np.random.random() * image.size[0])
            image.putpixel((j, i), int(np.random.random() * 255))
        return image

class AdjustResolution(TransBase):
    """
    随机分辨率
    """

    def setparam(self, max_rate=0.95, min_rate=0.5):
        self.max_rate = max_rate
        self.min_rate = min_rate

    def trans_function(self, image):
        image = get_pil_image(image)
        w, h = image.size
        rate = np.random.random() * (self.max_rate - self.min_rate) + self.min_rate
        w2 = int(w * rate)
        h2 = int(h * rate)
        image = image.resize((w2, h2))
        image = image.resize((w, h))
        return image

class Crop(TransBase):
    """
    随机抠图，并且抠图区域透视变换为原图大小
    """

    def setparam(self, maxv=2):
        self.maxv = maxv

    def trans_function(self, image):
        img = get_cv_image(image)
        h, w = img.shape[:2]
        org = np.array([[0, np.random.randint(0, self.maxv)],
                        [w, np.random.randint(0, self.maxv)],
                        [0, h - np.random.randint(0, self.maxv)],
                        [w, h - np.random.randint(0, self.maxv)]], np.float32)
        dst = np.array([[0, 0], [w, 0], [0, h], [w, h]], np.float32)
        M = cv2.getPerspectiveTransform(org, dst)
        res = cv2.warpPerspective(img, M, (w, h))
        return get_pil_image(res)

class Crop2(TransBase):
    """
    随机抠图，并且抠图区域透视变换为原图大小
    """

    def setparam(self, maxv_h=4, maxv_w=4):
        self.maxv_h = maxv_h
        self.maxv_w = maxv_w

    def trans_function(self, image_and_loc):
        image, left, top, right, bottom = image_and_loc
        w, h = image.size
        left = np.clip(left, 0, w - 1)
        right = np.clip(right, 0, w - 1)
        top = np.clip(top, 0, h - 1)
        bottom = np.clip(bottom, 0, h - 1)
        img = get_cv_image(image)
        try:
            res = get_pil_image(img[top:bottom, left:right])
            return res
        except AttributeError as e:
            print('error')
            image.save('test_imgs/t.png')
            print(left, top, right, bottom)

        h = bottom - top
        w = right - left
        org = np.array(
            [[left - np.random.randint(0, self.maxv_w), top + np.random.randint(-self.maxv_h, self.maxv_h // 2)],
             [right + np.random.randint(0, self.maxv_w), top + np.random.randint(-self.maxv_h, self.maxv_h // 2)],
             [left - np.random.randint(0, self.maxv_w), bottom - np.random.randint(-self.maxv_h, self.maxv_h // 2)],
             [right + np.random.randint(0, self.maxv_w), bottom - np.random.randint(-self.maxv_h, self.maxv_h // 2)]],
            np.float32)
        dst = np.array([[0, 0], [w, 0], [0, h], [w, h]], np.float32)
        M = cv2.getPerspectiveTransform(org, dst)
        res = cv2.warpPerspective(img, M, (w, h))
        return get_pil_image(res)

class Stretch(TransBase):
    """
    随机图像横向拉伸
    """

    def setparam(self, max_rate=1.2, min_rate=0.8):
        self.max_rate = max_rate
        self.min_rate = min_rate

    def trans_function(self, image):
        image = get_pil_image(image)
        w, h = image.size
        rate = np.random.random() * (self.max_rate - self.min_rate) + self.min_rate
        w2 = int(w * rate)
        image = image.resize((w2, h))
        return image

class DataAug:
    def __init__(self):
        self.crop = Crop(probability=0.1)
        self.crop2 = Crop2(probability=1.1)
        self.random_contrast = RandomContrast(probability=0.1)
        self.random_brightness = RandomBrightness(probability=0.1)
        self.random_color = RandomColor(probability=0.1)
        self.random_sharpness = RandomSharpness(probability=0.1)
        self.compress = Compress(probability=0.3)
        self.exposure = Exposure(probability=0.1)
        self.rotate = Rotate(probability=0.1)
        self.blur = Blur(probability=0.3)
        self.motion_blur = MotionBlur(probability=0.3)
        self.salt = Salt(probability=0.1)
        self.adjust_resolution = AdjustResolution(probability=0.1)
        self.stretch = Stretch(probability=0.1)
        self.random_line = RandomLine(probability=0.3)
        self.crop.setparam()
        self.crop2.setparam()
        self.random_contrast.setparam()
        self.random_brightness.setparam()
        self.random_color.setparam()
        self.random_sharpness.setparam()
        self.compress.setparam()
        self.exposure.setparam()
        self.rotate.setparam()
        self.blur.setparam()
        self.motion_blur.setparam()
        self.salt.setparam()
        self.adjust_resolution.setparam()
        self.stretch.setparam()

    def aug_img(self, img):
        img = self.crop.process(img)
        img = self.random_contrast.process(img)
        img = self.random_brightness.process(img)
        img = self.random_color.process(img)
        img = self.random_sharpness.process(img)
        img = self.random_line.process(img)

        if img.size[1] >= 32:
            img = self.compress.process(img)
            img = self.adjust_resolution.process(img)
            img = self.motion_blur.process(img)
            img = self.blur.process(img)
        img = self.exposure.process(img)
        img = self.rotate.process(img)
        img = self.salt.process(img)
        img = self.inverse_color(img)
        img = self.stretch.process(img)
        return img

    def inverse_color(self, image):
        if np.random.random() < 0.4:
            image = ImageOps.invert(image)
        return image

# %%
'''
Dataset 和 DataLoader
'''
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

class RecTextLineDataset(Dataset):
    def __init__(self, config):
        """
        文本行 DataSet, 用于处理标注格式为 `img_path\tlabel` 的标注格式

        :param config: 相关配置，一般为 config['dataset']['train']['dataset] or config['dataset']['eval']['dataset]
                其主要应包含如下字段： file: 标注文件路径
                                    input_h: 图片的目标高
                                    mean: 归一化均值
                                    std: 归一化方差
                                    augmentation: 使用使用数据增强
        :return None
        """
        self.augmentation = config.augmentation
        self.process = RecDataProcess(config)
        self.str2idx = {c: i for i, c in enumerate(config.alphabet)}
        self.labels = []
        with open(config.file, 'r', encoding='utf-8') as f_reader:
            for m_line in f_reader.readlines():
                params = m_line.strip().split('\t')
                if len(params) == 2:
                    m_image_name, m_gt_text = params
                    print(m_gt_text)
                    if True in [c not in self.str2idx for c in m_gt_text]:
                        continue
                    self.labels.append((m_image_name, m_gt_text))

    def _find_max_length(self):
        return max({len(_[1]) for _ in self.labels})

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, index):
        # get img_path and trans
        img_path, trans = self.labels[index]
        # read img
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        # do aug
        if self.augmentation:
            img = pil2cv(self.process.aug_img(cv2pil(img)))
        return {'img': img, 'label': trans}
    

class RecDataLoader:
    def __init__(self, dataset, batch_size, shuffle, num_workers, **kwargs):
        """
        自定义 DataLoader, 主要实现数据集的按长度划分，将长度相近的放在一个 batch

        :param dataset: 继承自 torch.utils.data.DataSet的类对象
        :param batch_size: 一个 batch 的图片数量
        :param shuffle: 是否打乱数据集
        :param num_workers: 后台进程数
        :param kwargs: **
        """
        self.dataset = dataset
        self.process = dataset.process
        self.len_thresh = self.dataset._find_max_length() // 2
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.num_workers = num_workers
        self.iteration = 0
        self.dataiter = None
        self.queue_1 = list()
        self.queue_2 = list()

    def __len__(self):
        return len(self.dataset) // self.batch_size if len(self.dataset) % self.batch_size == 0 \
            else len(self.dataset) // self.batch_size + 1

    def __iter__(self):
        return self

    def pack(self, batch_data):
        batch = {'img': [], 'label': []}
        # img tensor current shape: B,H,W,C
        all_same_height_images = [self.process.resize_with_specific_height(_['img'][0].numpy()) for _ in batch_data]
        max_img_w = max({m_img.shape[1] for m_img in all_same_height_images})
        # make sure max_img_w is integral multiple of 8
        max_img_w = int(np.ceil(max_img_w / 8) * 8)
        for i in range(len(batch_data)):
            _label = batch_data[i]['label'][0]
            img = self.process.normalize_img(self.process.width_pad_img(all_same_height_images[i], max_img_w))
            img = img.transpose([2, 0, 1])
            batch['img'].append(torch.tensor(img, dtype=torch.float))
            batch['label'].append(_label)
        batch['img'] = torch.stack(batch['img'])
        return batch

    def build(self):
        self.dataiter = DataLoader(self.dataset, batch_size=1, shuffle=self.shuffle, num_workers=self.num_workers).__iter__()

    def __next__(self):
        if self.dataiter == None:
            self.build()
        if self.iteration == len(self.dataset) and len(self.queue_2):
            batch_data = self.queue_2
            self.queue_2 = list()
            return self.pack(batch_data)
        if not len(self.queue_2) and not len(self.queue_1) and self.iteration == len(self.dataset):
            self.iteration = 0
            self.dataiter = None
            raise StopIteration
        # start iteration
        try:
            while True:
                # get data from origin dataloader
                temp = self.dataiter.__next__()
                self.iteration += 1
                # to different queue
                if len(temp['label'][0]) <= self.len_thresh:
                    self.queue_1.append(temp)
                else:
                    self.queue_2.append(temp)

                # to store batch data
                batch_data = None
                # queue_1 full, push to batch_data
                if len(self.queue_1) == self.batch_size:
                    batch_data = self.queue_1
                    self.queue_1 = list()
                # or queue_2 full, push to batch_data
                elif len(self.queue_2) == self.batch_size:
                    batch_data = self.queue_2
                    self.queue_2 = list()

                # start to process batch
                if batch_data is not None:
                    return self.pack(batch_data)
        # deal with last batch
        except StopIteration:
            batch_data = self.queue_1
            self.queue_1 = list()
            return self.pack(batch_data)


class RecDataProcess:
    def __init__(self, config):
        """
        文本是被数据增广类

        :param config: 配置，主要用到的字段有 input_h, mean, std
        """
        self.config = config
        self.random_contrast = RandomContrast(probability=0.3)
        self.random_brightness = RandomBrightness(probability=0.3)
        self.random_sharpness = RandomSharpness(probability=0.3)
        self.compress = Compress(probability=0.3)
        self.rotate = Rotate(probability=0.5)
        self.blur = Blur(probability=0.3)
        self.motion_blur = MotionBlur(probability=0.3)
        self.salt = Salt(probability=0.3)
        self.adjust_resolution = AdjustResolution(probability=0.3)
        self.random_line = RandomLine(probability=0.3)
        self.random_contrast.setparam()
        self.random_brightness.setparam()
        self.random_sharpness.setparam()
        self.compress.setparam()
        self.rotate.setparam()
        self.blur.setparam()
        self.motion_blur.setparam()
        self.salt.setparam()
        self.adjust_resolution.setparam()

    def aug_img(self, img):
        img = self.random_contrast.process(img)
        img = self.random_brightness.process(img)
        img = self.random_sharpness.process(img)
        img = self.random_line.process(img)

        if img.size[1] >= 32:
            img = self.compress.process(img)
            img = self.adjust_resolution.process(img)
            img = self.motion_blur.process(img)
            img = self.blur.process(img)
        img = self.rotate.process(img)
        img = self.salt.process(img)
        return img

    def resize_with_specific_height(self, _img):
        """
        将图像resize到指定高度
        :param _img:    待resize的图像
        :return:    resize完成的图像
        """
        resize_ratio = self.config.input_h / _img.shape[0]
        return cv2.resize(_img, (0, 0), fx=resize_ratio, fy=resize_ratio, interpolation=cv2.INTER_LINEAR)

    def normalize_img(self, _img):
        """
        根据配置的均值和标准差进行归一化
        :param _img:    待归一化的图像
        :return:    归一化后的图像
        """
        return (_img.astype(np.float32) / 255 - self.config.mean) / self.config.std

    def width_pad_img(self, _img, _target_width, _pad_value=0):
        """
        将图像进行高度不变，宽度的调整的pad
        :param _img:    待pad的图像
        :param _target_width:   目标宽度
        :param _pad_value:  pad的值
        :return:    pad完成后的图像
        """
        _height, _width, _channels = _img.shape
        to_return_img = np.ones([_height, _target_width, _channels], dtype=_img.dtype) * _pad_value
        to_return_img[:_height, :_width, :] = _img
        return to_return_img


class RecCollateFn:
    def __init__(self, *args, **kwargs):
        self.process = kwargs['dataset'].process
        self.t = transforms.ToTensor()

    def __call__(self, batch):
        resize_images = []

        all_same_height_images = [self.process.resize_with_specific_height(_['img']) for _ in batch]
        max_img_w = max({m_img.shape[1] for m_img in all_same_height_images})
        # make sure max_img_w is integral multiple of 8
        max_img_w = int(np.ceil(max_img_w / 8) * 8)
        labels = []
        for i in range(len(batch)):
            _label = batch[i]['label']
            labels.append(_label)
            img = self.process.width_pad_img(all_same_height_images[i], max_img_w)
            img = self.process.normalize_img(img)
            img = img.transpose([2, 0, 1])
            resize_images.append(torch.tensor(img, dtype=torch.float))
        resize_images = torch.stack(resize_images)
        return {'img': resize_images, 'label': labels}

# %%
import os
import sys
import pathlib
import logging
logging.basicConfig(level = 20)

config_path = "/home/elimen/Data/dbnet_pytorch/config/rec_train_config.py"
module_name = os.path.basename(config_path)[:-3]
print(module_name)
config_dir = os.path.dirname(config_path)
print(config_dir)
# Out:
# rec_train_config
# /home/elimen/Data/dbnet_pytorch/config

# %%
from importlib import import_module

sys.path.insert(0, config_dir)
mod = import_module(module_name)
sys.path.pop(0)
# Out:
# '/home/elimen/Data/dbnet_pytorch/config'

# %%
cfg = mod.config
cfg.dataset.alphabet = "/home/elimen/Data/dbnet_pytorch/torchocr/datasets/alphabets/ppocr_keys_v1.txt"

# %%
cfg
# Out:
# {'exp_name': 'CRNN',
#  'train_options': {'resume_from': '',
#   'third_party_name': '',
#   'checkpoint_save_dir': './output/CRNN/checkpoint',
#   'device': 'cuda:0',
#   'epochs': 200,
#   'fine_tune_stage': ['neck', 'head'],
#   'print_interval': 10,
#   'val_interval': 300,
#   'ckpt_save_type': 'HighestAcc',
#   'ckpt_save_epoch': 4},
#  'SEED': 927,
#  'optimizer': {'type': 'Adam', 'lr': 0.001, 'weight_decay': 0.0001},
#  'lr_scheduler': {'type': 'StepLR', 'step_size': 60, 'gamma': 0.5},
#  'model': {'type': 'RecModel',
#   'backbone': {'type': 'ResNet', 'layers': 18},
#   'neck': {'type': 'PPaddleRNN'},
#   'head': {'type': 'CTC', 'n_class': 11},
#   'in_channels': 3},
#  'loss': {'type': 'CTCLoss', 'blank_idx': 0},
#  'dataset': {'alphabet': '/home/elimen/Data/dbnet_pytorch/torchocr/datasets/alphabets/ppocr_keys_v1.txt',
#   'train': {'dataset': {'type': 'RecTextLineDataset',
#     'file': '/home/elimen/Data/OCR_dataset/icdar2015/recognition/train.txt',
#     'input_h': 32,
#     'mean': 0.5,
#     'std': 0.5,
#     'augmentation': False},
#    'loader': {'type': 'DataLoader',
#     'batch_size': 16,
#     'shuffle': True,
#     'num_workers': 1,
#     'collate_fn': {'type': 'RecCollateFn', 'img_w': 120}}},
#   'eval': {'dataset': {'type': 'RecTextLineDataset',
#     'file': 'path/eval.txt',
#     'input_h': 32,
#     'mean': 0.5,
#     'std': 0.5,
#     'augmentation': False},
#    'loader': {'type': 'RecDataLoader',
#     'batch_size': 4,
#     'shuffle': False,
#     'num_workers': 1,
#     'collate_fn': {'type': 'RecCollateFn', 'img_w': 120}}}}}

# %%
with open(cfg.dataset.alphabet, 'r', encoding='utf-8') as file:
    cfg.dataset.alphabet = ''.join([s.strip('\n') for s in file.readlines()])
cfg.dataset.alphabet
# Out:
# '\'疗绚诚娇溜题贿者廖更纳加奉公一就汴计与路房原妇208-7其>:],，骑刈全消昏傈安久钟嗅不影处驽蜿资关椤地瘸专问忖票嫉炎韵要月田节陂鄙捌备拳伺眼网盎大傍心东愉汇蹿科每业里航晏字平录先13彤鲶产稍督腴有象岳注绍在泺文定核名水过理让偷率等这发”为含肥酉相鄱七编猥锛日镀蒂掰倒辆栾栗综涩州雌滑馀了机块司宰甙兴矽抚保用沧秩如收息滥页疑埠!！姥异橹钇向下跄的椴沫国绥獠报开民蜇何分凇长讥藏掏施羽中讲派嘟人提浼间世而古多倪唇饯控庚首赛蜓味断制觉技替艰溢潮夕钺外摘枋动双单啮户枇确锦曜杜或能效霜盒然侗电晁放步鹃新杖蜂吒濂瞬评总隍对独合也是府青天诲墙组滴级邀帘示已时骸仄泅和遨店雇疫持巍踮境只亨目鉴崤闲体泄杂作般轰化解迂诿蛭璀腾告版服省师小规程线海办引二桧牌砺洄裴修图痫胡许犊事郛基柴呼食研奶律蛋因葆察戏褒戒再李骁工貂油鹅章啄休场给睡纷豆器捎说敏学会浒设诊格廓查来霓室溆￠诡寥焕舜柒狐回戟砾厄实翩尿五入径惭喹股宇篝|;美期云九祺扮靠锝槌系企酰阊暂蚕忻豁本羹执条钦H獒限进季楦于芘玖铋茯未答粘括样精欠矢甥帷嵩扣令仔风皈行支部蓉刮站蜡救钊汗松嫌成可.鹤院从交政怕活调球局验髌第韫谗串到圆年米/*友忿检区看自敢刃个兹弄流留同没齿星聆轼湖什三建蛔儿椋汕震颧鲤跟力情璺铨陪务指族训滦鄣濮扒商箱十召慷辗所莞管护臭横硒嗓接侦六露党馋驾剖高侬妪幂猗绺骐央酐孝筝课徇缰门男西项句谙瞒秃篇教碲罚声呐景前富嘴鳌稀免朋啬睐去赈鱼住肩愕速旁波厅健茼厥鲟谅投攸炔数方击呋谈绩别愫僚躬鹧胪炳招喇膨泵蹦毛结54谱识陕粽婚拟构且搜任潘比郢妨醪陀桔碘扎选哈骷楷亿明缆脯监睫逻婵共赴淝凡惦及达揖谩澹减焰蛹番祁柏员禄怡峤龙白叽生闯起细装谕竟聚钙上导渊按艾辘挡耒盹饪臀记邮蕙受各医搂普滇朗茸带翻酚(光堤墟蔷万幻〓瑙辈昧盏亘蛀吉铰请子假闻税井诩哨嫂好面琐校馊鬣缂营访炖占农缀否经钚棵趟张亟吏茶谨捻论迸堂玉信吧瞠乡姬寺咬溏苄皿意赉宝尔钰艺特唳踉都荣倚登荐丧奇涵批炭近符傩感道着菊虹仲众懈濯颞眺南释北缝标既茗整撼迤贲挎耱拒某妍卫哇英矶藩治他元领膜遮穗蛾飞荒棺劫么市火温拈棚洼转果奕卸迪伸泳斗邡侄涨屯萋胭氡崮枞惧冒彩斜手豚随旭淑妞形菌吲沱争驯歹挟兆柱传至包内响临红功弩衡寂禁老棍耆渍织害氵渑布载靥嗬虽苹咨娄库雉榜帜嘲套瑚亲簸欧边6腿旮抛吹瞳得镓梗厨继漾愣憨士策窑抑躯襟脏参贸言干绸鳄穷藜音折详)举悍甸癌黎谴死罩迁寒驷袖媒蒋掘模纠恣观祖蛆碍位稿主澧跌筏京锏帝贴证糠才黄鲸略炯饱四出园犀牧容汉杆浈汰瑷造虫瘩怪驴济应花沣谔夙旅价矿以考su呦晒巡茅准肟瓴詹仟褂译桌混宁怦郑抿些余鄂饴攒珑群阖岔琨藓预环洮岌宀杲瀵最常囡周踊女鼓袭喉简范薯遐疏粱黜禧法箔斤遥汝奥直贞撑置绱集她馅逗钧橱魉[恙躁唤9旺膘待脾惫购吗依盲度瘿蠖俾之镗拇鲵厝簧续款展啃表剔品钻腭损清锶统涌寸滨贪链吠冈伎迥咏吁览防迅失汾阔逵绀蔑列川凭努熨揪利俱绉抢鸨我即责膦易毓鹊刹玷岿空嘞绊排术估锷违们苟铜播肘件烫审鲂广像铌惰铟巳胍鲍康憧色恢想拷尤疳知SYFDA峄裕帮握搔氐氘难墒沮雨叁缥悴藐湫娟苑稠颛簇后阕闭蕤缚怎佞码嘤蔡痊舱螯帕赫昵升烬岫、疵蜻髁蕨隶烛械丑盂梁强鲛由拘揉劭龟撤钩呕孛费妻漂求阑崖秤甘通深补赃坎床啪承吼量暇钼烨阂擎脱逮称P神属矗华届狍葑汹育患窒蛰佼静槎运鳗庆逝曼疱克代官此麸耧蚌晟例础榛副测唰缢迹灬霁身岁赭扛又菡乜雾板读陷徉贯郁虑变钓菜圾现琢式乐维渔浜左吾脑钡警T啵拴偌漱湿硕止骼魄积燥联踢玛则窿见振畿送班钽您赵刨印讨踝籍谡舌崧汽蔽沪酥绒怖财帖肱私莎勋羔霸励哼帐将帅渠纪婴娩岭厘滕吻伤坝冠戊隆瘁介涧物黍并姗奢蹑掣垸锴命箍捉病辖琰眭迩艘绌繁寅若毋思诉类诈燮轲酮狂重反职筱县委磕绣奖晋濉志徽肠呈獐坻口片碰几村柿劳料获亩惕晕厌号罢池正鏖煨家棕复尝懋蜥锅岛扰队坠瘾钬@卧疣镇譬冰彷频黯据垄采八缪瘫型熹砰楠襁箐但嘶绳啤拍盥穆傲洗盯塘怔筛丿台恒喂葛永￥烟酒桦书砂蚝缉态瀚袄圳轻蛛超榧遛姒奘铮右荽望偻卡丶氰附做革索戚坨桷唁垅榻岐偎坛莨山殊微骇陈爨推嗝驹澡藁呤卤嘻糅逛侵郓酌德摇※鬃被慨殡羸昌泡戛鞋河宪沿玲鲨翅哽源铅语照邯址荃佬顺鸳町霭睾瓢夸椁晓酿痈咔侏券噎湍签嚷离午尚社锤背孟使浪缦潍鞅军姹驶笑鳟鲁》孽钜绿洱礴焯椰颖囔乌孔巴互性椽哞聘昨早暮胶炀隧低彗昝铁呓氽藉喔癖瑗姨权胱韦堑蜜酋楝砝毁靓歙锲究屋喳骨辨碑武鸠宫辜烊适坡殃培佩供走蜈迟翼况姣凛浔吃飘债犟金促苛崇坂莳畔绂兵蠕斋根砍亢欢恬崔剁餐榫快扶‖濒缠鳜当彭驭浦篮昀锆秸钳弋娣瞑夷龛苫拱致%嵊障隐弑初娓抉汩累蓖"唬助苓昙押毙破城郧逢嚏獭瞻溱婿赊跨恼璧萃姻貉灵炉密氛陶砸谬衔点琛沛枳层岱诺脍榈埂征冷裁打蹴素瘘逞蛐聊激腱萘踵飒蓟吆取咙簋涓矩曝挺揣座你史舵焱尘苏笈脚溉榨诵樊邓焊义庶儋蟋蒲赦呷杞诠豪还试颓茉太除紫逃痴草充鳕珉祗墨渭烩蘸慕璇镶穴嵘恶骂险绋幕碉肺戳刘潞秣纾潜銮洛须罘销瘪汞兮屉r林厕质探划狸殚善煊烹〒锈逯宸辍泱柚袍远蹋嶙绝峥娥缍雀徵认镱谷=贩勉撩鄯斐洋非祚泾诒饿撬威晷搭芍锥笺蓦候琊档礁沼卵荠忑朝凹瑞头仪弧孵畏铆突衲车浩气茂悖厢枕酝戴湾邹飚攘锂写宵翁岷无喜丈挑嗟绛殉议槽具醇淞笃郴阅饼底壕砚弈询缕庹翟零筷暨舟闺甯撞麂茌蔼很珲捕棠角阉媛娲诽剿尉爵睬韩诰匣危糍镯立浏阳少盆舔擘匪申尬铣旯抖赘瓯居ˇ哮游锭茏歌坏甚秒舞沙仗劲潺阿燧郭嗖霏忠材奂耐跺砀输岖媳氟极摆灿今扔腻枝奎药熄吨话q额慑嘌协喀壳埭视著於愧陲翌峁颅佛腹聋侯咎叟秀颇存较罪哄岗扫栏钾羌己璨枭霉煌涸衿键镝益岢奏连夯睿冥均糖狞蹊稻爸刿胥煜丽肿璃掸跚灾垂樾濑乎莲窄犹撮战馄软络显鸢胸宾妲恕埔蝌份遇巧瞟粒恰剥桡博讯凯堇阶滤卖斌骚彬兑磺樱舷两娱福仃差找桁÷净把阴污戬雷碓蕲楚罡焖抽妫咒仑闱尽邑菁爱贷沥鞑牡嗉崴骤塌嗦订拮滓捡锻次坪杩臃箬融珂鹗宗枚降鸬妯阄堰盐毅必杨崃俺甬状莘货耸菱腼铸唏痤孚澳懒溅翘疙杷淼缙骰喊悉砻坷艇赁界谤纣宴晃茹归饭梢铡街抄肼鬟苯颂撷戈炒咆茭瘙负仰客琉铢封卑珥椿镧窨鬲寿御袤铃萎砖餮脒裳肪孕嫣馗嵇恳氯江石褶冢祸阻狈羞银靳透咳叼敷芷啥它瓤兰痘懊逑肌往捺坊甩呻〃沦忘膻祟菅剧崆智坯臧霍墅攻眯倘拢骠铐庭岙瓠′缺泥迢捶?？郏喙掷沌纯秘种听绘固螨团香盗妒埚蓝拖旱荞铀血遏汲辰叩拽幅硬惶桀漠措泼唑齐肾念酱虚屁耶旗砦闵婉馆拭绅韧忏窝醋葺顾辞倜堆辋逆玟贱疾董惘倌锕淘嘀莽俭笏绑鲷杈择蟀粥嗯驰逾案谪褓胫哩昕颚鲢绠躺鹄崂儒俨丝尕泌啊萸彰幺吟骄苣弦脊瑰〈诛镁析闪剪侧哟框螃守嬗燕狭铈缮概迳痧鲲俯售笼痣扉挖满咋援邱扇歪便玑绦峡蛇叨〖泽胃斓喋怂坟猪该蚬炕弥赞棣晔娠挲狡创疖铕镭稷挫弭啾翔粉履苘哦楼秕铂土锣瘟挣栉习享桢袅磨桂谦延坚蔚噗署谟猬钎恐嬉雒倦衅亏璩睹刻殿王算雕麻丘柯骆丸塍谚添鲈垓桎蚯芥予飕镦谌窗醚菀亮搪莺蒿羁足J真轶悬衷靛翊掩哒炅掐冼妮l谐稚荆擒犯陵虏浓崽刍陌傻孜千靖演矜钕煽杰酗渗伞栋俗泫戍罕沾疽灏煦芬磴叱阱榉湃蜀叉醒彪租郡篷屎良垢隗弱陨峪砷掴颁胎雯绵贬沐撵隘篙暖曹陡栓填臼彦瓶琪潼哪鸡摩啦俟锋域耻蔫疯纹撇毒绶痛酯忍爪赳歆嘹辕烈册朴钱吮毯癜娃谀邵厮炽璞邃丐追词瓒忆轧芫谯喷弟半冕裙掖墉绮寝苔势顷褥切衮君佳嫒蚩霞佚洙逊镖暹唛&殒顶碗獗轭铺蛊废恹汨崩珍那杵曲纺夏薰傀闳淬姘舀拧卷楂恍讪厩寮篪赓乘灭盅鞣沟慎挂饺鼾杳树缨丛絮娌臻嗳篡侩述衰矛圈蚜匕筹匿濞晨叶骋郝挚蚴滞增侍描瓣吖嫦蟒匾圣赌毡癞恺百曳需篓肮庖帏卿驿遗蹬鬓骡歉芎胳屐禽烦晌寄媾狄翡苒船廉终痞殇々畦饶改拆悻萄￡瓿乃訾桅匮溧拥纱铍骗蕃龋缬父佐疚栎醍掳蓄x惆颜鲆榆〔猎敌暴谥鲫贾罗玻缄扦芪癣落徒臾恿猩托邴肄牵春陛耀刊拓蓓邳堕寇枉淌啡湄兽酷萼碚濠萤夹旬戮梭琥椭昔勺蜊绐晚孺僵宣摄冽旨萌忙蚤眉噼蟑付契瓜悼颡壁曾窕颢澎仿俑浑嵌浣乍碌褪乱蔟隙玩剐葫箫纲围伐决伙漩瑟刑肓镳缓蹭氨皓典畲坍铑檐塑洞倬储胴淳戾吐灼惺妙毕珐缈虱盖羰鸿磅谓髅娴苴唷蚣霹抨贤唠犬誓逍庠逼麓籼釉呜碧秧氩摔霄穸纨辟妈映完牛缴嗷炊恩荔茆掉紊慌莓羟阙萁磐另蕹辱鳐湮吡吩唐睦垠舒圜冗瞿溺芾囱匠僳汐菩饬漓黑霰浸濡窥毂蒡兢驻鹉芮诙迫雳厂忐臆猴鸣蚪栈箕羡渐莆捍眈哓趴蹼埕嚣骛宏淄斑噜严瑛垃椎诱压庾绞焘廿抡迄棘夫纬锹眨瞌侠脐竞瀑孳骧遁姜颦荪滚萦伪逸粳爬锁矣役趣洒颔诏逐奸甭惠攀蹄泛尼拼阮鹰亚颈惑勒〉际肛爷刚钨丰养冶鲽辉蔻画覆皴妊麦返醉皂擀〗酶凑粹悟诀硖港卜z杀涕±舍铠抵弛段敝镐奠拂轴跛袱et沉菇俎薪峦秭蟹历盟菠寡液肢喻染裱悱抱氙赤捅猛跑氮谣仁尺辊窍烙衍架擦倏璐瑁币楞胖夔趸邛惴饕虔蝎§哉贝宽辫炮扩饲籽魏菟锰伍猝末琳哚蛎邂呀姿鄞却歧仙恸椐森牒寤袒婆虢雅钉朵贼欲苞寰故龚坭嘘咫礼硷兀睢汶’铲烧绕诃浃钿哺柜讼颊璁腔洽咐脲簌筠镣玮鞠谁兼姆挥梯蝴谘漕刷躏宦弼b垌劈麟莉揭笙渎仕嗤仓配怏抬错泯镊孰猿邪仍秋鼬壹歇吵炼<尧射柬廷胧霾凳隋肚浮梦祥株堵退L鹫跎凶毽荟炫栩玳甜沂鹿顽伯爹赔蛴徐匡欣狰缸雹蟆疤默沤啜痂衣禅wih辽葳黝钗停沽棒馨颌肉吴硫悯劾娈马啧吊悌镑峭帆瀣涉咸疸滋泣翦拙癸钥蜒+尾庄凝泉婢渴谊乞陆锉糊鸦淮IBN晦弗乔庥葡尻席橡傣渣拿惩麋斛缃矮蛏岘鸽姐膏催奔镒喱蠡摧钯胤柠拐璋鸥卢荡倾^_珀逄萧塾掇贮笆聂圃冲嵬M滔笕值炙偶蜱搐梆汪蔬腑鸯蹇敞绯仨祯谆梧糗鑫啸豺囹猾巢柄瀛筑踌沭暗苁鱿蹉脂蘖牢热木吸溃宠序泞偿拜檩厚朐毗螳吞媚朽担蝗橘畴祈糟盱隼郜惜珠裨铵焙琚唯咚噪骊丫滢勤棉呸咣淀隔蕾窈饨挨煅短匙粕镜赣撕墩酬馁豌颐抗酣氓佑搁哭递耷涡桃贻碣截瘦昭镌蔓氚甲猕蕴蓬散拾纛狼猷铎埋旖矾讳囊糜迈粟蚂紧鲳瘢栽稼羊锄斟睁桥瓮蹙祉醺鼻昱剃跳篱跷蒜翎宅晖嗑壑峻癫屏狠陋袜途憎祀莹滟佶溥臣约盛峰磁慵婪拦莅朕鹦粲裤哎疡嫖琵窟堪谛嘉儡鳝斩郾驸酊妄胜贺徙傅噌钢栅庇恋匝巯邈尸锚粗佟蛟薹纵蚊郅绢锐苗俞篆淆膀鲜煎诶秽寻涮刺怀噶巨褰魅灶灌桉藕谜舸薄搀恽借牯痉渥愿亓耘杠柩锔蚶钣珈喘蹒幽赐稗晤莱泔扯肯菪裆腩豉疆骜腐倭珏唔粮亡润慰伽橄玄誉醐胆龊粼塬陇彼削嗣绾芽妗垭瘴爽薏寨龈泠弹赢漪猫嘧涂恤圭茧烽屑痕巾赖荸凰腮畈亵蹲偃苇澜艮换骺烘苕梓颉肇哗悄氤涠葬屠鹭植竺佯诣鲇瘀鲅邦移滁 ...

# %%
cfg.dataset.train.dataset.alphabet = cfg.dataset.alphabet

# %%
cfg
# Out:
# {'exp_name': 'CRNN',
#  'train_options': {'resume_from': '',
#   'third_party_name': '',
#   'checkpoint_save_dir': './output/CRNN/checkpoint',
#   'device': 'cuda:0',
#   'epochs': 200,
#   'fine_tune_stage': ['neck', 'head'],
#   'print_interval': 10,
#   'val_interval': 300,
#   'ckpt_save_type': 'HighestAcc',
#   'ckpt_save_epoch': 4},
#  'SEED': 927,
#  'optimizer': {'type': 'Adam', 'lr': 0.001, 'weight_decay': 0.0001},
#  'lr_scheduler': {'type': 'StepLR', 'step_size': 60, 'gamma': 0.5},
#  'model': {'type': 'RecModel',
#   'backbone': {'type': 'ResNet', 'layers': 18},
#   'neck': {'type': 'PPaddleRNN'},
#   'head': {'type': 'CTC', 'n_class': 11},
#   'in_channels': 3},
#  'loss': {'type': 'CTCLoss', 'blank_idx': 0},
#  'dataset': {'alphabet': '\'疗绚诚娇溜题贿者廖更纳加奉公一就汴计与路房原妇208-7其>:],，骑刈全消昏傈安久钟嗅不影处驽蜿资关椤地瘸专问忖票嫉炎韵要月田节陂鄙捌备拳伺眼网盎大傍心东愉汇蹿科每业里航晏字平录先13彤鲶产稍督腴有象岳注绍在泺文定核名水过理让偷率等这发”为含肥酉相鄱七编猥锛日镀蒂掰倒辆栾栗综涩州雌滑馀了机块司宰甙兴矽抚保用沧秩如收息滥页疑埠!！姥异橹钇向下跄的椴沫国绥獠报开民蜇何分凇长讥藏掏施羽中讲派嘟人提浼间世而古多倪唇饯控庚首赛蜓味断制觉技替艰溢潮夕钺外摘枋动双单啮户枇确锦曜杜或能效霜盒然侗电晁放步鹃新杖蜂吒濂瞬评总隍对独合也是府青天诲墙组滴级邀帘示已时骸仄泅和遨店雇疫持巍踮境只亨目鉴崤闲体泄杂作般轰化解迂诿蛭璀腾告版服省师小规程线海办引二桧牌砺洄裴修图痫胡许犊事郛基柴呼食研奶律蛋因葆察戏褒戒再李骁工貂油鹅章啄休场给睡纷豆器捎说敏学会浒设诊格廓查来霓室溆￠诡寥焕舜柒狐回戟砾厄实翩尿五入径惭喹股宇篝|;美期云九祺扮靠锝槌系企酰阊暂蚕忻豁本羹执条钦H獒限进季楦于芘玖铋茯未答粘括样精欠矢甥帷嵩扣令仔风皈行支部蓉刮站蜡救钊汗松嫌成可.鹤院从交政怕活调球局验髌第韫谗串到圆年米/*友忿检区看自敢刃个兹弄流留同没齿星聆轼湖什三建蛔儿椋汕震颧鲤跟力情璺铨陪务指族训滦鄣濮扒商箱十召慷辗所莞管护臭横硒嗓接侦六露党馋驾剖高侬妪幂猗绺骐央酐孝筝课徇缰门男西项句谙瞒秃篇教碲罚声呐景前富嘴鳌稀免朋啬睐去赈鱼住肩愕速旁波厅健茼厥鲟谅投攸炔数方击呋谈绩别愫僚躬鹧胪炳招喇膨泵蹦毛结54谱识陕粽婚拟构且搜任潘比郢妨醪陀桔碘扎选哈骷楷亿明缆脯监睫逻婵共赴淝凡惦及达揖谩澹减焰蛹番祁柏员禄怡峤龙白叽生闯起细装谕竟聚钙上导渊按艾辘挡耒盹饪臀记邮蕙受各医搂普滇朗茸带翻酚(光堤墟蔷万幻〓瑙辈昧盏亘蛀吉铰请子假闻税井诩哨嫂好面琐校馊鬣缂营访炖占农缀否经钚棵趟张亟吏茶谨捻论迸堂玉信吧瞠乡姬寺咬溏苄皿意赉宝尔钰艺特唳踉都荣倚登荐丧奇涵批炭近符傩感道着菊虹仲众懈濯颞眺南释北缝标既茗整撼迤贲挎耱拒某妍卫哇英矶藩治他元领膜遮穗蛾飞荒棺劫么市火温拈棚洼转果奕卸迪伸泳斗邡侄涨屯萋胭氡崮枞惧冒彩斜手豚随旭淑妞形菌吲沱争驯歹挟兆柱传至包内响临红功弩衡寂禁老棍耆渍织害氵渑布载靥嗬虽苹咨娄库雉榜帜嘲套瑚亲簸欧边6腿旮抛吹瞳得镓梗厨继漾愣憨士策窑抑躯襟脏参贸言干绸鳄穷藜音折详)举悍甸癌黎谴死罩迁寒驷袖媒蒋掘模纠恣观祖蛆碍位稿主澧跌筏京锏帝贴证糠才黄鲸略炯饱四出园犀牧容汉杆浈汰瑷造虫瘩怪驴济应花沣谔夙旅价矿以考su呦晒巡茅准肟瓴詹仟褂译桌混宁怦郑抿些余鄂饴攒珑群阖岔琨藓预环洮岌宀杲瀵最常囡周踊女鼓袭喉简范薯遐疏粱黜禧法箔斤遥汝奥直贞撑置绱集她馅逗钧橱魉[恙躁唤9旺膘待脾惫购吗依盲度瘿蠖俾之镗拇鲵厝簧续款展啃表剔品钻腭损清锶统涌寸滨贪链吠冈伎迥咏吁览防迅失汾阔逵绀蔑列川凭努熨揪利俱绉抢鸨我即责膦易毓鹊刹玷岿空嘞绊排术估锷违们苟铜播肘件烫审鲂广像铌惰铟巳胍鲍康憧色恢想拷尤疳知SYFDA峄裕帮握搔氐氘难墒沮雨叁缥悴藐湫娟苑稠颛簇后阕闭蕤缚怎佞码嘤蔡痊舱螯帕赫昵升烬岫、疵蜻髁蕨隶烛械丑盂梁强鲛由拘揉劭龟撤钩呕孛费妻漂求阑崖秤甘通深补赃坎床啪承吼量暇钼烨阂擎脱逮称P神属矗华届狍葑汹育患窒蛰佼静槎运鳗庆逝曼疱克代官此麸耧蚌晟例础榛副测唰缢迹灬霁身岁赭扛又菡乜雾板读陷徉贯郁虑变钓菜圾现琢式乐维渔浜左吾脑钡警T啵拴偌漱湿硕止骼魄积燥联踢玛则窿见振畿送班钽您赵刨印讨踝籍谡舌崧汽蔽沪酥绒怖财帖肱私莎勋羔霸励哼帐将帅渠纪婴娩岭厘滕吻伤坝冠戊隆瘁介涧物黍并姗奢蹑掣垸锴命箍捉病辖琰眭迩艘绌繁寅若毋思诉类诈燮轲酮狂重反职筱县委磕绣奖晋濉志徽肠呈獐坻口片碰几村柿劳料获亩惕晕厌号罢池正鏖煨家棕复尝懋蜥锅岛扰队坠瘾钬@卧疣镇譬冰彷频黯据垄采八缪瘫型熹砰楠襁箐但嘶绳啤拍盥穆傲洗盯塘怔筛丿台恒喂葛永￥烟酒桦书砂蚝缉态瀚袄圳轻蛛超榧遛姒奘铮右荽望偻卡丶氰附做革索戚坨桷唁垅榻岐偎坛莨山殊微骇陈爨推嗝驹澡藁呤卤嘻糅逛侵郓酌德摇※鬃被慨殡羸昌泡戛鞋河宪沿玲鲨翅哽源铅语照邯址荃佬顺鸳町霭睾瓢夸椁晓酿痈咔侏券噎湍签嚷离午尚社锤背孟使浪缦潍鞅军姹驶笑鳟鲁》孽钜绿洱礴焯椰颖囔乌孔巴互性椽哞聘昨早暮胶炀隧低彗昝铁呓氽藉喔癖瑗姨权胱韦堑蜜酋楝砝毁靓歙锲究屋喳骨辨碑武鸠宫辜烊适坡殃培佩供走蜈迟翼况姣凛浔吃飘债犟金促苛崇坂莳畔绂兵蠕斋根砍亢欢恬崔剁餐榫快扶‖濒缠鳜当彭驭浦篮昀锆秸钳弋娣瞑夷龛苫拱致%嵊障隐弑初娓抉汩累蓖"唬助苓昙押毙破城郧逢嚏獭瞻溱婿赊跨恼璧萃姻貉灵炉密氛陶砸谬衔点琛沛枳层岱诺脍榈埂征冷裁打蹴素瘘逞蛐聊激腱萘踵飒蓟吆取咙簋涓矩曝挺揣座你史舵焱尘苏笈脚溉榨诵樊邓焊义庶儋蟋蒲赦呷杞诠豪还试颓茉太除紫逃痴草充鳕珉祗墨渭烩蘸慕璇镶穴嵘恶骂险绋幕碉肺戳刘潞秣纾潜銮洛须罘销瘪汞兮屉r林厕质探划狸殚善煊烹〒锈逯宸辍泱柚袍远蹋嶙绝峥娥缍雀徵认镱谷=贩勉撩鄯斐洋非祚泾诒饿撬威晷搭芍锥笺蓦候琊档礁沼卵荠忑朝凹瑞头仪弧孵畏铆突衲车浩气茂悖厢枕酝戴湾邹飚攘锂写宵翁岷无喜丈挑嗟绛殉议槽具醇淞笃郴阅饼底壕砚弈询缕庹翟零筷暨舟闺甯撞麂茌蔼很珲捕棠角阉媛娲诽剿尉爵睬韩诰匣危糍镯立浏阳少盆舔擘匪申尬铣旯抖赘瓯居ˇ哮游锭茏歌坏甚秒舞沙仗劲潺阿燧郭嗖霏忠材奂耐跺砀输岖媳氟极摆灿今扔腻枝奎药熄吨话q额慑嘌协喀壳埭视著於愧陲翌峁颅佛腹聋侯咎叟秀颇存较罪哄岗扫栏钾羌己璨枭霉煌涸衿键镝益岢奏连夯睿冥均糖狞蹊稻爸刿胥煜丽肿璃掸跚灾垂樾濑乎莲窄犹撮战馄软络显鸢胸宾妲恕埔蝌份遇巧瞟粒恰剥桡博讯凯堇阶滤卖斌骚彬兑磺樱舷两娱福仃差找桁÷净把阴污戬雷碓蕲楚罡焖抽妫咒仑闱尽邑菁爱贷沥鞑牡嗉崴骤塌嗦订拮滓捡锻次坪杩臃箬融珂鹗宗枚降鸬妯阄堰盐毅必杨崃俺甬状莘货耸菱腼铸唏痤孚澳懒溅翘疙杷淼缙骰喊悉砻坷艇赁界谤纣宴晃茹归饭梢铡街抄肼鬟苯颂撷戈炒咆茭瘙负仰客琉铢封卑珥椿镧窨鬲寿御袤铃萎砖餮脒裳肪孕嫣馗嵇恳氯江石褶冢祸阻狈羞银靳透咳叼敷芷啥它瓤兰痘懊逑肌往捺坊甩呻〃沦忘膻祟菅剧崆智坯臧霍墅攻眯倘拢骠铐庭岙瓠′缺泥迢捶?？郏喙掷沌纯秘种听绘固螨团香盗妒埚蓝拖旱荞铀血遏汲辰叩拽幅硬惶桀漠措泼唑齐肾念酱虚屁耶旗砦闵婉馆拭绅韧忏窝醋葺顾辞倜堆辋逆玟贱疾董惘倌锕淘嘀莽俭笏绑鲷杈择蟀粥嗯驰逾案谪褓胫哩昕颚鲢绠躺鹄崂儒俨丝尕泌啊萸彰幺吟骄苣弦脊瑰〈诛镁析闪剪侧哟框螃守嬗燕狭铈缮概迳痧鲲俯售笼痣扉挖满咋援邱扇歪便玑绦峡蛇叨〖泽胃斓喋怂坟猪该蚬炕弥赞棣晔娠挲狡创疖铕镭稷挫弭啾翔粉履苘哦楼秕铂土锣瘟挣栉习享桢袅磨桂谦延坚蔚噗署谟猬钎恐嬉雒倦衅亏璩睹刻殿王算雕麻丘柯骆丸塍谚添鲈垓桎蚯芥予飕镦谌窗醚菀亮搪莺蒿羁足J真轶悬衷靛翊掩哒炅掐冼妮l谐稚荆擒犯陵虏浓崽刍陌傻孜千靖演矜钕煽杰酗渗伞栋俗泫戍罕沾疽灏煦芬磴叱阱榉湃蜀叉醒彪租郡篷屎良垢隗弱陨峪砷掴颁胎雯绵贬沐撵隘篙暖曹陡栓填臼彦瓶琪潼哪鸡摩啦俟锋域耻蔫疯纹撇毒绶痛酯忍爪赳歆嘹辕烈册朴钱吮毯癜娃谀邵厮炽璞邃丐追词瓒忆轧芫谯喷弟半冕裙掖墉绮寝苔势顷褥切衮君佳嫒蚩霞佚洙逊镖暹唛&殒顶碗獗轭铺蛊废恹汨崩珍那杵曲纺夏薰傀闳淬姘舀拧卷楂恍讪厩寮篪赓乘灭盅鞣沟慎挂饺鼾杳树缨丛絮娌臻嗳篡侩述衰矛圈蚜匕筹匿濞晨叶骋郝挚蚴滞增侍描瓣吖嫦蟒匾圣赌毡癞恺百曳需篓肮庖帏卿驿遗蹬鬓骡歉芎胳屐禽烦晌寄媾狄翡苒船廉终痞殇々畦饶改拆悻萄￡瓿乃訾桅匮溧拥纱铍骗蕃龋缬父佐疚栎醍掳蓄x惆颜鲆榆〔猎敌暴谥鲫贾罗玻缄扦芪癣落徒臾恿猩托邴肄牵春陛耀刊拓蓓邳堕寇枉淌啡湄兽酷萼碚濠萤夹旬戮梭琥椭昔勺蜊绐晚孺僵宣摄冽旨萌忙蚤眉噼蟑付契瓜悼颡壁曾窕颢澎仿俑浑嵌浣乍碌褪乱蔟隙玩剐葫箫纲围伐决伙漩瑟刑肓镳缓蹭氨皓典畲坍铑檐塑洞倬储胴淳戾吐灼惺妙毕珐缈虱盖羰鸿磅谓髅娴苴唷蚣霹抨贤唠犬誓逍庠逼麓籼釉呜碧秧氩摔霄穸纨辟妈映完牛缴嗷炊恩荔茆掉紊慌莓羟阙萁磐另蕹辱鳐湮吡吩唐睦垠舒圜冗瞿溺芾囱匠僳汐菩饬漓黑霰浸濡窥毂蒡兢驻鹉芮诙迫雳厂忐臆猴鸣蚪栈箕羡渐莆捍眈哓趴蹼埕嚣骛宏淄斑噜严瑛垃椎诱压庾绞焘廿抡迄棘夫纬锹眨瞌侠脐竞瀑孳骧遁姜颦荪滚萦伪逸粳爬锁矣役趣洒颔诏逐奸甭惠攀蹄泛尼拼阮鹰亚颈惑勒〉际肛爷刚钨丰养冶鲽辉蔻画覆皴妊麦返醉皂擀〗酶凑粹悟诀硖港卜z杀涕±舍铠抵弛段敝镐奠拂轴跛袱et沉菇俎薪峦秭蟹历盟菠寡液肢喻染裱悱抱氙赤捅猛跑氮谣仁尺辊窍烙衍架擦倏璐瑁币楞胖夔趸邛惴饕虔蝎§哉贝宽辫炮扩饲籽魏菟锰伍猝末琳哚蛎邂呀姿鄞却歧仙恸椐森牒寤袒婆虢雅钉朵贼欲苞寰故龚坭嘘咫礼硷兀睢汶’铲烧绕诃浃钿哺柜讼颊璁腔洽咐脲簌筠镣玮鞠谁兼姆挥梯蝴谘漕刷躏宦弼b垌劈麟莉揭笙渎仕嗤仓配怏抬错泯镊孰猿邪仍秋鼬壹歇吵炼<尧射柬廷胧霾凳隋肚浮梦祥株堵退L鹫跎凶毽荟炫栩玳甜沂鹿顽伯爹赔蛴徐匡欣狰缸雹蟆疤默沤啜痂衣禅wih辽葳黝钗停沽棒馨颌肉吴硫悯劾娈马啧吊悌镑峭帆瀣涉咸疸滋泣翦拙癸钥蜒+尾庄凝泉婢渴谊乞陆锉糊鸦淮IBN晦弗乔庥葡尻席橡傣渣拿惩麋斛缃矮蛏岘鸽姐膏催奔镒喱蠡摧钯胤柠拐璋鸥卢荡倾^_珀逄萧塾掇贮笆聂圃冲嵬M滔笕值炙偶蜱搐梆汪蔬腑鸯蹇敞绯仨祯谆梧糗鑫啸豺囹猾巢柄瀛筑踌沭暗苁鱿蹉脂蘖牢热木吸溃宠序泞偿拜檩厚朐毗螳吞媚朽担蝗橘畴祈糟盱隼郜惜珠裨铵焙琚唯咚噪骊丫滢勤棉呸咣淀隔蕾窈饨挨煅短匙粕镜赣撕墩酬馁豌颐抗酣氓佑搁哭递耷涡桃贻碣截瘦昭镌蔓氚甲猕蕴蓬散拾纛狼猷铎埋旖矾讳囊糜迈粟蚂紧鲳瘢栽稼羊锄斟睁桥瓮蹙祉醺鼻昱剃跳篱跷蒜翎宅晖嗑壑峻癫屏狠陋袜途憎祀莹滟佶溥臣约盛峰磁慵婪拦莅朕鹦粲裤哎疡嫖琵窟堪谛嘉儡鳝斩郾驸酊妄胜贺徙傅噌钢栅庇恋匝巯邈尸锚粗佟蛟薹纵蚊郅绢锐苗俞篆淆膀鲜煎诶秽寻涮刺怀噶巨褰魅灶灌桉藕谜舸薄搀恽借牯痉渥愿亓耘杠柩锔蚶钣珈喘蹒幽赐稗晤莱泔扯肯菪裆腩豉疆骜腐倭珏唔粮亡润慰伽橄玄誉醐胆龊粼塬陇彼削嗣绾芽妗垭瘴爽薏寨龈泠弹赢漪猫嘧涂恤圭茧烽屑痕巾赖荸凰腮畈亵蹲偃苇澜 ...
#   'train': {'dataset': {'type': 'RecTextLineDataset',
#     'file': '/home/elimen/Data/OCR_dataset/icdar2015/recognition/train.txt',
#     'input_h': 32,
#     'mean': 0.5,
#     'std': 0.5,
#     'augmentation': False,
#     'alphabet': '\'疗绚诚娇溜题贿者廖更纳加奉公一就汴计与路房原妇208-7其>:],，骑刈全消昏傈安久钟嗅不影处驽蜿资关椤地瘸专问忖票嫉炎韵要月田节陂鄙捌备拳伺眼网盎大傍心东愉汇蹿科每业里航晏字平录先13彤鲶产稍督腴有象岳注绍在泺文定核名水过理让偷率等这发”为含肥酉相鄱七编猥锛日镀蒂掰倒辆栾栗综涩州雌滑馀了机块司宰甙兴矽抚保用沧秩如收息滥页疑埠!！姥异橹钇向下跄的椴沫国绥獠报开民蜇何分凇长讥藏掏施羽中讲派嘟人提浼间世而古多倪唇饯控庚首赛蜓味断制觉技替艰溢潮夕钺外摘枋动双单啮户枇确锦曜杜或能效霜盒然侗电晁放步鹃新杖蜂吒濂瞬评总隍对独合也是府青天诲墙组滴级邀帘示已时骸仄泅和遨店雇疫持巍踮境只亨目鉴崤闲体泄杂作般轰化解迂诿蛭璀腾告版服省师小规程线海办引二桧牌砺洄裴修图痫胡许犊事郛基柴呼食研奶律蛋因葆察戏褒戒再李骁工貂油鹅章啄休场给睡纷豆器捎说敏学会浒设诊格廓查来霓室溆￠诡寥焕舜柒狐回戟砾厄实翩尿五入径惭喹股宇篝|;美期云九祺扮靠锝槌系企酰阊暂蚕忻豁本羹执条钦H獒限进季楦于芘玖铋茯未答粘括样精欠矢甥帷嵩扣令仔风皈行支部蓉刮站蜡救钊汗松嫌成可.鹤院从交政怕活调球局验髌第韫谗串到圆年米/*友忿检区看自敢刃个兹弄流留同没齿星聆轼湖什三建蛔儿椋汕震颧鲤跟力情璺铨陪务指族训滦鄣濮扒商箱十召慷辗所莞管护臭横硒嗓接侦六露党馋驾剖高侬妪幂猗绺骐央酐孝筝课徇缰门男西项句谙瞒秃篇教碲罚声呐景前富嘴鳌稀免朋啬睐去赈鱼住肩愕速旁波厅健茼厥鲟谅投攸炔数方击呋谈绩别愫僚躬鹧胪炳招喇膨泵蹦毛结54谱识陕粽婚拟构且搜任潘比郢妨醪陀桔碘扎选哈骷楷亿明缆脯监睫逻婵共赴淝凡惦及达揖谩澹减焰蛹番祁柏员禄怡峤龙白叽生闯起细装谕竟聚钙上导渊按艾辘挡耒盹饪臀记邮蕙受各医搂普滇朗茸带翻酚(光堤墟蔷万幻〓瑙辈昧盏亘蛀吉铰请子假闻税井诩哨嫂好面琐校馊鬣缂营访炖占农缀否经钚棵趟张亟吏茶谨捻论迸堂玉信吧瞠乡姬寺咬溏苄皿意赉宝尔钰艺特唳踉都荣倚登荐丧奇涵批炭近符傩感道着菊虹仲众懈濯颞眺南释北缝标既茗整撼迤贲挎耱拒某妍卫哇英矶藩治他元领膜遮穗蛾飞荒棺劫么市火温拈棚洼转果奕卸迪伸泳斗邡侄涨屯萋胭氡崮枞惧冒彩斜手豚随旭淑妞形菌吲沱争驯歹挟兆柱传至包内响临红功弩衡寂禁老棍耆渍织害氵渑布载靥嗬虽苹咨娄库雉榜帜嘲套瑚亲簸欧边6腿旮抛吹瞳得镓梗厨继漾愣憨士策窑抑躯襟脏参贸言干绸鳄穷藜音折详)举悍甸癌黎谴死罩迁寒驷袖媒蒋掘模纠恣观祖蛆碍位稿主澧跌筏京锏帝贴证糠才黄鲸略炯饱四出园犀牧容汉杆浈汰瑷造虫瘩怪驴济应花沣谔夙旅价矿以考su呦晒巡茅准肟瓴詹仟褂译桌混宁怦郑抿些余鄂饴攒珑群阖岔琨藓预环洮岌宀杲瀵最常囡周踊女鼓袭喉简范薯遐疏粱黜禧法箔斤遥汝奥直贞撑置绱集她馅逗钧橱魉[恙躁唤9旺膘待脾惫购吗依盲度瘿蠖俾之镗拇鲵厝簧续款展啃表剔品钻腭损清锶统涌寸滨贪链吠冈伎迥咏吁览防迅失汾阔逵绀蔑列川凭努熨揪利俱绉抢鸨我即责膦易毓鹊刹玷岿空嘞绊排术估锷违们苟铜播肘件烫审鲂广像铌惰铟巳胍鲍康憧色恢想拷尤疳知SYFDA峄裕帮握搔氐氘难墒沮雨叁缥悴藐湫娟苑稠颛簇后阕闭蕤缚怎佞码嘤蔡痊舱螯帕赫昵升烬岫、疵蜻髁蕨隶烛械丑盂梁强鲛由拘揉劭龟撤钩呕孛费妻漂求阑崖秤甘通深补赃坎床啪承吼量暇钼烨阂擎脱逮称P神属矗华届狍葑汹育患窒蛰佼静槎运鳗庆逝曼疱克代官此麸耧蚌晟例础榛副测唰缢迹灬霁身岁赭扛又菡乜雾板读陷徉贯郁虑变钓菜圾现琢式乐维渔浜左吾脑钡警T啵拴偌漱湿硕止骼魄积燥联踢玛则窿见振畿送班钽您赵刨印讨踝籍谡舌崧汽蔽沪酥绒怖财帖肱私莎勋羔霸励哼帐将帅渠纪婴娩岭厘滕吻伤坝冠戊隆瘁介涧物黍并姗奢蹑掣垸锴命箍捉病辖琰眭迩艘绌繁寅若毋思诉类诈燮轲酮狂重反职筱县委磕绣奖晋濉志徽肠呈獐坻口片碰几村柿劳料获亩惕晕厌号罢池正鏖煨家棕复尝懋蜥锅岛扰队坠瘾钬@卧疣镇譬冰彷频黯据垄采八缪瘫型熹砰楠襁箐但嘶绳啤拍盥穆傲洗盯塘怔筛丿台恒喂葛永￥烟酒桦书砂蚝缉态瀚袄圳轻蛛超榧遛姒奘铮右荽望偻卡丶氰附做革索戚坨桷唁垅榻岐偎坛莨山殊微骇陈爨推嗝驹澡藁呤卤嘻糅逛侵郓酌德摇※鬃被慨殡羸昌泡戛鞋河宪沿玲鲨翅哽源铅语照邯址荃佬顺鸳町霭睾瓢夸椁晓酿痈咔侏券噎湍签嚷离午尚社锤背孟使浪缦潍鞅军姹驶笑鳟鲁》孽钜绿洱礴焯椰颖囔乌孔巴互性椽哞聘昨早暮胶炀隧低彗昝铁呓氽藉喔癖瑗姨权胱韦堑蜜酋楝砝毁靓歙锲究屋喳骨辨碑武鸠宫辜烊适坡殃培佩供走蜈迟翼况姣凛浔吃飘债犟金促苛崇坂莳畔绂兵蠕斋根砍亢欢恬崔剁餐榫快扶‖濒缠鳜当彭驭浦篮昀锆秸钳弋娣瞑夷龛苫拱致%嵊障隐弑初娓抉汩累蓖"唬助苓昙押毙破城郧逢嚏獭瞻溱婿赊跨恼璧萃姻貉灵炉密氛陶砸谬衔点琛沛枳层岱诺脍榈埂征冷裁打蹴素瘘逞蛐聊激腱萘踵飒蓟吆取咙簋涓矩曝挺揣座你史舵焱尘苏笈脚溉榨诵樊邓焊义庶儋蟋蒲赦呷杞诠豪还试颓茉太除紫逃痴草充鳕珉祗墨渭烩蘸慕璇镶穴嵘恶骂险绋幕碉肺戳刘潞秣纾潜銮洛须罘销瘪汞兮屉r林厕质探划狸殚善煊烹〒锈逯宸辍泱柚袍远蹋嶙绝峥娥缍雀徵认镱谷=贩勉撩鄯斐洋非祚泾诒饿撬威晷搭芍锥笺蓦候琊档礁沼卵荠忑朝凹瑞头仪弧孵畏铆突衲车浩气茂悖厢枕酝戴湾邹飚攘锂写宵翁岷无喜丈挑嗟绛殉议槽具醇淞笃郴阅饼底壕砚弈询缕庹翟零筷暨舟闺甯撞麂茌蔼很珲捕棠角阉媛娲诽剿尉爵睬韩诰匣危糍镯立浏阳少盆舔擘匪申尬铣旯抖赘瓯居ˇ哮游锭茏歌坏甚秒舞沙仗劲潺阿燧郭嗖霏忠材奂耐跺砀输岖媳氟极摆灿今扔腻枝奎药熄吨话q额慑嘌协喀壳埭视著於愧陲翌峁颅佛腹聋侯咎叟秀颇存较罪哄岗扫栏钾羌己璨枭霉煌涸衿键镝益岢奏连夯睿冥均糖狞蹊稻爸刿胥煜丽肿璃掸跚灾垂樾濑乎莲窄犹撮战馄软络显鸢胸宾妲恕埔蝌份遇巧瞟粒恰剥桡博讯凯堇阶滤卖斌骚彬兑磺樱舷两娱福仃差找桁÷净把阴污戬雷碓蕲楚罡焖抽妫咒仑闱尽邑菁爱贷沥鞑牡嗉崴骤塌嗦订拮滓捡锻次坪杩臃箬融珂鹗宗枚降鸬妯阄堰盐毅必杨崃俺甬状莘货耸菱腼铸唏痤孚澳懒溅翘疙杷淼缙骰喊悉砻坷艇赁界谤纣宴晃茹归饭梢铡街抄肼鬟苯颂撷戈炒咆茭瘙负仰客琉铢封卑珥椿镧窨鬲寿御袤铃萎砖餮脒裳肪孕嫣馗嵇恳氯江石褶冢祸阻狈羞银靳透咳叼敷芷啥它瓤兰痘懊逑肌往捺坊甩呻〃沦忘膻祟菅剧崆智坯臧霍墅攻眯倘拢骠铐庭岙瓠′缺泥迢捶?？郏喙掷沌纯秘种听绘固螨团香盗妒埚蓝拖旱荞铀血遏汲辰叩拽幅硬惶桀漠措泼唑齐肾念酱虚屁耶旗砦闵婉馆拭绅韧忏窝醋葺顾辞倜堆辋逆玟贱疾董惘倌锕淘嘀莽俭笏绑鲷杈择蟀粥嗯驰逾案谪褓胫哩昕颚鲢绠躺鹄崂儒俨丝尕泌啊萸彰幺吟骄苣弦脊瑰〈诛镁析闪剪侧哟框螃守嬗燕狭铈缮概迳痧鲲俯售笼痣扉挖满咋援邱扇歪便玑绦峡蛇叨〖泽胃斓喋怂坟猪该蚬炕弥赞棣晔娠挲狡创疖铕镭稷挫弭啾翔粉履苘哦楼秕铂土锣瘟挣栉习享桢袅磨桂谦延坚蔚噗署谟猬钎恐嬉雒倦衅亏璩睹刻殿王算雕麻丘柯骆丸塍谚添鲈垓桎蚯芥予飕镦谌窗醚菀亮搪莺蒿羁足J真轶悬衷靛翊掩哒炅掐冼妮l谐稚荆擒犯陵虏浓崽刍陌傻孜千靖演矜钕煽杰酗渗伞栋俗泫戍罕沾疽灏煦芬磴叱阱榉湃蜀叉醒彪租郡篷屎良垢隗弱陨峪砷掴颁胎雯绵贬沐撵隘篙暖曹陡栓填臼彦瓶琪潼哪鸡摩啦俟锋域耻蔫疯纹撇毒绶痛酯忍爪赳歆嘹辕烈册朴钱吮毯癜娃谀邵厮炽璞邃丐追词瓒忆轧芫谯喷弟半冕裙掖墉绮寝苔势顷褥切衮君佳嫒蚩霞佚洙逊镖暹唛&殒顶碗獗轭铺蛊废恹汨崩珍那杵曲纺夏薰傀闳淬姘舀拧卷楂恍讪厩寮篪赓乘灭盅鞣沟慎挂饺鼾杳树缨丛絮娌臻嗳篡侩述衰矛圈蚜匕筹匿濞晨叶骋郝挚蚴滞增侍描瓣吖嫦蟒匾圣赌毡癞恺百曳需篓肮庖帏卿驿遗蹬鬓骡歉芎胳屐禽烦晌寄媾狄翡苒船廉终痞殇々畦饶改拆悻萄￡瓿乃訾桅匮溧拥纱铍骗蕃龋缬父佐疚栎醍掳蓄x惆颜鲆榆〔猎敌暴谥鲫贾罗玻缄扦芪癣落徒臾恿猩托邴肄牵春陛耀刊拓蓓邳堕寇枉淌啡湄兽酷萼碚濠萤夹旬戮梭琥椭昔勺蜊绐晚孺僵宣摄冽旨萌忙蚤眉噼蟑付契瓜悼颡壁曾窕颢澎仿俑浑嵌浣乍碌褪乱蔟隙玩剐葫箫纲围伐决伙漩瑟刑肓镳缓蹭氨皓典畲坍铑檐塑洞倬储胴淳戾吐灼惺妙毕珐缈虱盖羰鸿磅谓髅娴苴唷蚣霹抨贤唠犬誓逍庠逼麓籼釉呜碧秧氩摔霄穸纨辟妈映完牛缴嗷炊恩荔茆掉紊慌莓羟阙萁磐另蕹辱鳐湮吡吩唐睦垠舒圜冗瞿溺芾囱匠僳汐菩饬漓黑霰浸濡窥毂蒡兢驻鹉芮诙迫雳厂忐臆猴鸣蚪栈箕羡渐莆捍眈哓趴蹼埕嚣骛宏淄斑噜严瑛垃椎诱压庾绞焘廿抡迄棘夫纬锹眨瞌侠脐竞瀑孳骧遁姜颦荪滚萦伪逸粳爬锁矣役趣洒颔诏逐奸甭惠攀蹄泛尼拼阮鹰亚颈惑勒〉际肛爷刚钨丰养冶鲽辉蔻画覆皴妊麦返醉皂擀〗酶凑粹悟诀硖港卜z杀涕±舍铠抵弛段敝镐奠拂轴跛袱et沉菇俎薪峦秭蟹历盟菠寡液肢喻染裱悱抱氙赤捅猛跑氮谣仁尺辊窍烙衍架擦倏璐瑁币楞胖夔趸邛惴饕虔蝎§哉贝宽辫炮扩饲籽魏菟锰伍猝末琳哚蛎邂呀姿鄞却歧仙恸椐森牒寤袒婆虢雅钉朵贼欲苞寰故龚坭嘘咫礼硷兀睢汶’铲烧绕诃浃钿哺柜讼颊璁腔洽咐脲簌筠镣玮鞠谁兼姆挥梯蝴谘漕刷躏宦弼b垌劈麟莉揭笙渎仕嗤仓配怏抬错泯镊孰猿邪仍秋鼬壹歇吵炼<尧射柬廷胧霾凳隋肚浮梦祥株堵退L鹫跎凶毽荟炫栩玳甜沂鹿顽伯爹赔蛴徐匡欣狰缸雹蟆疤默沤啜痂衣禅wih辽葳黝钗停沽棒馨颌肉吴硫悯劾娈马啧吊悌镑峭帆瀣涉咸疸滋泣翦拙癸钥蜒+尾庄凝泉婢渴谊乞陆锉糊鸦淮IBN晦弗乔庥葡尻席橡傣渣拿惩麋斛缃矮蛏岘鸽姐膏催奔镒喱蠡摧钯胤柠拐璋鸥卢荡倾^_珀逄萧塾掇贮笆聂圃冲嵬M滔笕值炙偶蜱搐梆汪蔬腑鸯蹇敞绯仨祯谆梧糗鑫啸豺囹猾巢柄瀛筑踌沭暗苁鱿蹉脂蘖牢热木吸溃宠序泞偿拜檩厚朐毗螳吞媚朽担蝗橘畴祈糟盱隼郜惜珠裨铵焙琚唯咚噪骊丫滢勤棉呸咣淀隔蕾窈饨挨煅短匙粕镜赣撕墩酬馁豌颐抗酣氓佑搁哭递耷涡桃贻碣截瘦昭镌蔓氚甲猕蕴蓬散拾纛狼猷铎埋旖矾讳囊糜迈粟蚂紧鲳瘢栽稼羊锄斟睁桥瓮蹙祉醺鼻昱剃跳篱跷蒜翎宅晖嗑壑峻癫屏狠陋袜途憎祀莹滟佶溥臣约盛峰磁慵婪拦莅朕鹦粲裤哎疡嫖琵窟堪谛嘉儡鳝斩郾驸酊妄胜贺徙傅噌钢栅庇恋匝巯邈尸锚粗佟蛟薹纵蚊郅绢锐苗俞篆淆膀鲜煎诶秽寻涮刺怀噶巨褰魅灶灌桉藕谜舸薄搀恽借牯痉渥愿亓耘杠柩锔蚶钣珈喘蹒幽赐稗晤莱泔扯肯菪裆腩豉疆骜腐倭珏唔粮亡润慰伽橄玄誉醐胆龊粼塬陇彼削嗣绾芽妗垭瘴爽薏寨龈泠弹赢漪猫嘧涂恤圭茧烽屑痕巾赖荸凰腮畈亵蹲偃苇澜艮换骺烘苕梓颉肇哗 ...
#    'loader': {'type': 'DataLoader',
#     'batch_size': 16,
#     'shuffle': True,
#     'num_workers': 1,
#     'collate_fn': {'type': 'RecCollateFn', 'img_w': 120}}},
#   'eval': {'dataset': {'type': 'RecTextLineDataset',
#     'file': 'path/eval.txt',
#     'input_h': 32,
#     'mean': 0.5,
#     'std': 0.5,
#     'augmentation': False},
#    'loader': {'type': 'RecDataLoader',
#     'batch_size': 4,
#     'shuffle': False,
#     'num_workers': 1,
#     'collate_fn': {'type': 'RecCollateFn', 'img_w': 120}}}}}

# %%
import copy
from addict import Dict
train_config = cfg.dataset.train
train_config_copy = copy.deepcopy(train_config)
print(train_config_copy)
# Out:
# {'dataset': {'type': 'RecTextLineDataset', 'file': '/home/elimen/Data/OCR_dataset/icdar2015/recognition/train.txt', 'input_h': 32, 'mean': 0.5, 'std': 0.5, 'augmentation': False, 'alphabet': '\'疗绚诚娇溜题贿者廖更纳加奉公一就汴计与路房原妇208-7其>:],，骑刈全消昏傈安久钟嗅不影处驽蜿资关椤地瘸专问忖票嫉炎韵要月田节陂鄙捌备拳伺眼网盎大傍心东愉汇蹿科每业里航晏字平录先13彤鲶产稍督腴有象岳注绍在泺文定核名水过理让偷率等这发”为含肥酉相鄱七编猥锛日镀蒂掰倒辆栾栗综涩州雌滑馀了机块司宰甙兴矽抚保用沧秩如收息滥页疑埠!！姥异橹钇向下跄的椴沫国绥獠报开民蜇何分凇长讥藏掏施羽中讲派嘟人提浼间世而古多倪唇饯控庚首赛蜓味断制觉技替艰溢潮夕钺外摘枋动双单啮户枇确锦曜杜或能效霜盒然侗电晁放步鹃新杖蜂吒濂瞬评总隍对独合也是府青天诲墙组滴级邀帘示已时骸仄泅和遨店雇疫持巍踮境只亨目鉴崤闲体泄杂作般轰化解迂诿蛭璀腾告版服省师小规程线海办引二桧牌砺洄裴修图痫胡许犊事郛基柴呼食研奶律蛋因葆察戏褒戒再李骁工貂油鹅章啄休场给睡纷豆器捎说敏学会浒设诊格廓查来霓室溆￠诡寥焕舜柒狐回戟砾厄实翩尿五入径惭喹股宇篝|;美期云九祺扮靠锝槌系企酰阊暂蚕忻豁本羹执条钦H獒限进季楦于芘玖铋茯未答粘括样精欠矢甥帷嵩扣令仔风皈行支部蓉刮站蜡救钊汗松嫌成可.鹤院从交政怕活调球局验髌第韫谗串到圆年米/*友忿检区看自敢刃个兹弄流留同没齿星聆轼湖什三建蛔儿椋汕震颧鲤跟力情璺铨陪务指族训滦鄣濮扒商箱十召慷辗所莞管护臭横硒嗓接侦六露党馋驾剖高侬妪幂猗绺骐央酐孝筝课徇缰门男西项句谙瞒秃篇教碲罚声呐景前富嘴鳌稀免朋啬睐去赈鱼住肩愕速旁波厅健茼厥鲟谅投攸炔数方击呋谈绩别愫僚躬鹧胪炳招喇膨泵蹦毛结54谱识陕粽婚拟构且搜任潘比郢妨醪陀桔碘扎选哈骷楷亿明缆脯监睫逻婵共赴淝凡惦及达揖谩澹减焰蛹番祁柏员禄怡峤龙白叽生闯起细装谕竟聚钙上导渊按艾辘挡耒盹饪臀记邮蕙受各医搂普滇朗茸带翻酚(光堤墟蔷万幻〓瑙辈昧盏亘蛀吉铰请子假闻税井诩哨嫂好面琐校馊鬣缂营访炖占农缀否经钚棵趟张亟吏茶谨捻论迸堂玉信吧瞠乡姬寺咬溏苄皿意赉宝尔钰艺特唳踉都荣倚登荐丧奇涵批炭近符傩感道着菊虹仲众懈濯颞眺南释北缝标既茗整撼迤贲挎耱拒某妍卫哇英矶藩治他元领膜遮穗蛾飞荒棺劫么市火温拈棚洼转果奕卸迪伸泳斗邡侄涨屯萋胭氡崮枞惧冒彩斜手豚随旭淑妞形菌吲沱争驯歹挟兆柱传至包内响临红功弩衡寂禁老棍耆渍织害氵渑布载靥嗬虽苹咨娄库雉榜帜嘲套瑚亲簸欧边6腿旮抛吹瞳得镓梗厨继漾愣憨士策窑抑躯襟脏参贸言干绸鳄穷藜音折详)举悍甸癌黎谴死罩迁寒驷袖媒蒋掘模纠恣观祖蛆碍位稿主澧跌筏京锏帝贴证糠才黄鲸略炯饱四出园犀牧容汉杆浈汰瑷造虫瘩怪驴济应花沣谔夙旅价矿以考su呦晒巡茅准肟瓴詹仟褂译桌混宁怦郑抿些余鄂饴攒珑群阖岔琨藓预环洮岌宀杲瀵最常囡周踊女鼓袭喉简范薯遐疏粱黜禧法箔斤遥汝奥直贞撑置绱集她馅逗钧橱魉[恙躁唤9旺膘待脾惫购吗依盲度瘿蠖俾之镗拇鲵厝簧续款展啃表剔品钻腭损清锶统涌寸滨贪链吠冈伎迥咏吁览防迅失汾阔逵绀蔑列川凭努熨揪利俱绉抢鸨我即责膦易毓鹊刹玷岿空嘞绊排术估锷违们苟铜播肘件烫审鲂广像铌惰铟巳胍鲍康憧色恢想拷尤疳知SYFDA峄裕帮握搔氐氘难墒沮雨叁缥悴藐湫娟苑稠颛簇后阕闭蕤缚怎佞码嘤蔡痊舱螯帕赫昵升烬岫、疵蜻髁蕨隶烛械丑盂梁强鲛由拘揉劭龟撤钩呕孛费妻漂求阑崖秤甘通深补赃坎床啪承吼量暇钼烨阂擎脱逮称P神属矗华届狍葑汹育患窒蛰佼静槎运鳗庆逝曼疱克代官此麸耧蚌晟例础榛副测唰缢迹灬霁身岁赭扛又菡乜雾板读陷徉贯郁虑变钓菜圾现琢式乐维渔浜左吾脑钡警T啵拴偌漱湿硕止骼魄积燥联踢玛则窿见振畿送班钽您赵刨印讨踝籍谡舌崧汽蔽沪酥绒怖财帖肱私莎勋羔霸励哼帐将帅渠纪婴娩岭厘滕吻伤坝冠戊隆瘁介涧物黍并姗奢蹑掣垸锴命箍捉病辖琰眭迩艘绌繁寅若毋思诉类诈燮轲酮狂重反职筱县委磕绣奖晋濉志徽肠呈獐坻口片碰几村柿劳料获亩惕晕厌号罢池正鏖煨家棕复尝懋蜥锅岛扰队坠瘾钬@卧疣镇譬冰彷频黯据垄采八缪瘫型熹砰楠襁箐但嘶绳啤拍盥穆傲洗盯塘怔筛丿台恒喂葛永￥烟酒桦书砂蚝缉态瀚袄圳轻蛛超榧遛姒奘铮右荽望偻卡丶氰附做革索戚坨桷唁垅榻岐偎坛莨山殊微骇陈爨推嗝驹澡藁呤卤嘻糅逛侵郓酌德摇※鬃被慨殡羸昌泡戛鞋河宪沿玲鲨翅哽源铅语照邯址荃佬顺鸳町霭睾瓢夸椁晓酿痈咔侏券噎湍签嚷离午尚社锤背孟使浪缦潍鞅军姹驶笑鳟鲁》孽钜绿洱礴焯椰颖囔乌孔巴互性椽哞聘昨早暮胶炀隧低彗昝铁呓氽藉喔癖瑗姨权胱韦堑蜜酋楝砝毁靓歙锲究屋喳骨辨碑武鸠宫辜烊适坡殃培佩供走蜈迟翼况姣凛浔吃飘债犟金促苛崇坂莳畔绂兵蠕斋根砍亢欢恬崔剁餐榫快扶‖濒缠鳜当彭驭浦篮昀锆秸钳弋娣瞑夷龛苫拱致%嵊障隐弑初娓抉汩累蓖"唬助苓昙押毙破城郧逢嚏獭瞻溱婿赊跨恼璧萃姻貉灵炉密氛陶砸谬衔点琛沛枳层岱诺脍榈埂征冷裁打蹴素瘘逞蛐聊激腱萘踵飒蓟吆取咙簋涓矩曝挺揣座你史舵焱尘苏笈脚溉榨诵樊邓焊义庶儋蟋蒲赦呷杞诠豪还试颓茉太除紫逃痴草充鳕珉祗墨渭烩蘸慕璇镶穴嵘恶骂险绋幕碉肺戳刘潞秣纾潜銮洛须罘销瘪汞兮屉r林厕质探划狸殚善煊烹〒锈逯宸辍泱柚袍远蹋嶙绝峥娥缍雀徵认镱谷=贩勉撩鄯斐洋非祚泾诒饿撬威晷搭芍锥笺蓦候琊档礁沼卵荠忑朝凹瑞头仪弧孵畏铆突衲车浩气茂悖厢枕酝戴湾邹飚攘锂写宵翁岷无喜丈挑嗟绛殉议槽具醇淞笃郴阅饼底壕砚弈询缕庹翟零筷暨舟闺甯撞麂茌蔼很珲捕棠角阉媛娲诽剿尉爵睬韩诰匣危糍镯立浏阳少盆舔擘匪申尬铣旯抖赘瓯居ˇ哮游锭茏歌坏甚秒舞沙仗劲潺阿燧郭嗖霏忠材奂耐跺砀输岖媳氟极摆灿今扔腻枝奎药熄吨话q额慑嘌协喀壳埭视著於愧陲翌峁颅佛腹聋侯咎叟秀颇存较罪哄岗扫栏钾羌己璨枭霉煌涸衿键镝益岢奏连夯睿冥均糖狞蹊稻爸刿胥煜丽肿璃掸跚灾垂樾濑乎莲窄犹撮战馄软络显鸢胸宾妲恕埔蝌份遇巧瞟粒恰剥桡博讯凯堇阶滤卖斌骚彬兑磺樱舷两娱福仃差找桁÷净把阴污戬雷碓蕲楚罡焖抽妫咒仑闱尽邑菁爱贷沥鞑牡嗉崴骤塌嗦订拮滓捡锻次坪杩臃箬融珂鹗宗枚降鸬妯阄堰盐毅必杨崃俺甬状莘货耸菱腼铸唏痤孚澳懒溅翘疙杷淼缙骰喊悉砻坷艇赁界谤纣宴晃茹归饭梢铡街抄肼鬟苯颂撷戈炒咆茭瘙负仰客琉铢封卑珥椿镧窨鬲寿御袤铃萎砖餮脒裳肪孕嫣馗嵇恳氯江石褶冢祸阻狈羞银靳透咳叼敷芷啥它瓤兰痘懊逑肌往捺坊甩呻〃沦忘膻祟菅剧崆智坯臧霍墅攻眯倘拢骠铐庭岙瓠′缺泥迢捶?？郏喙掷沌纯秘种听绘固螨团香盗妒埚蓝拖旱荞铀血遏汲辰叩拽幅硬惶桀漠措泼唑齐肾念酱虚屁耶旗砦闵婉馆拭绅韧忏窝醋葺顾辞倜堆辋逆玟贱疾董惘倌锕淘嘀莽俭笏绑鲷杈择蟀粥嗯驰逾案谪褓胫哩昕颚鲢绠躺鹄崂儒俨丝尕泌啊萸彰幺吟骄苣弦脊瑰〈诛镁析闪剪侧哟框螃守嬗燕狭铈缮概迳痧鲲俯售笼痣扉挖满咋援邱扇歪便玑绦峡蛇叨〖泽胃斓喋怂坟猪该蚬炕弥赞棣晔娠挲狡创疖铕镭稷挫弭啾翔粉履苘哦楼秕铂土锣瘟挣栉习享桢袅磨桂谦延坚蔚噗署谟猬钎恐嬉雒倦衅亏璩睹刻殿王算雕麻丘柯骆丸塍谚添鲈垓桎蚯芥予飕镦谌窗醚菀亮搪莺蒿羁足J真轶悬衷靛翊掩哒炅掐冼妮l谐稚荆擒犯陵虏浓崽刍陌傻孜千靖演矜钕煽杰酗渗伞栋俗泫戍罕沾疽灏煦芬磴叱阱榉湃蜀叉醒彪租郡篷屎良垢隗弱陨峪砷掴颁胎雯绵贬沐撵隘篙暖曹陡栓填臼彦瓶琪潼哪鸡摩啦俟锋域耻蔫疯纹撇毒绶痛酯忍爪赳歆嘹辕烈册朴钱吮毯癜娃谀邵厮炽璞邃丐追词瓒忆轧芫谯喷弟半冕裙掖墉绮寝苔势顷褥切衮君佳嫒蚩霞佚洙逊镖暹唛&殒顶碗獗轭铺蛊废恹汨崩珍那杵曲纺夏薰傀闳淬姘舀拧卷楂恍讪厩寮篪赓乘灭盅鞣沟慎挂饺鼾杳树缨丛絮娌臻嗳篡侩述衰矛圈蚜匕筹匿濞晨叶骋郝挚蚴滞增侍描瓣吖嫦蟒匾圣赌毡癞恺百曳需篓肮庖帏卿驿遗蹬鬓骡歉芎胳屐禽烦晌寄媾狄翡苒船廉终痞殇々畦饶改拆悻萄￡瓿乃訾桅匮溧拥纱铍骗蕃龋缬父佐疚栎醍掳蓄x惆颜鲆榆〔猎敌暴谥鲫贾罗玻缄扦芪癣落徒臾恿猩托邴肄牵春陛耀刊拓蓓邳堕寇枉淌啡湄兽酷萼碚濠萤夹旬戮梭琥椭昔勺蜊绐晚孺僵宣摄冽旨萌忙蚤眉噼蟑付契瓜悼颡壁曾窕颢澎仿俑浑嵌浣乍碌褪乱蔟隙玩剐葫箫纲围伐决伙漩瑟刑肓镳缓蹭氨皓典畲坍铑檐塑洞倬储胴淳戾吐灼惺妙毕珐缈虱盖羰鸿磅谓髅娴苴唷蚣霹抨贤唠犬誓逍庠逼麓籼釉呜碧秧氩摔霄穸纨辟妈映完牛缴嗷炊恩荔茆掉紊慌莓羟阙萁磐另蕹辱鳐湮吡吩唐睦垠舒圜冗瞿溺芾囱匠僳汐菩饬漓黑霰浸濡窥毂蒡兢驻鹉芮诙迫雳厂忐臆猴鸣蚪栈箕羡渐莆捍眈哓趴蹼埕嚣骛宏淄斑噜严瑛垃椎诱压庾绞焘廿抡迄棘夫纬锹眨瞌侠脐竞瀑孳骧遁姜颦荪滚萦伪逸粳爬锁矣役趣洒颔诏逐奸甭惠攀蹄泛尼拼阮鹰亚颈惑勒〉际肛爷刚钨丰养冶鲽辉蔻画覆皴妊麦返醉皂擀〗酶凑粹悟诀硖港卜z杀涕±舍铠抵弛段敝镐奠拂轴跛袱et沉菇俎薪峦秭蟹历盟菠寡液肢喻染裱悱抱氙赤捅猛跑氮谣仁尺辊窍烙衍架擦倏璐瑁币楞胖夔趸邛惴饕虔蝎§哉贝宽辫炮扩饲籽魏菟锰伍猝末琳哚蛎邂呀姿鄞却歧仙恸椐森牒寤袒婆虢雅钉朵贼欲苞寰故龚坭嘘咫礼硷兀睢汶’铲烧绕诃浃钿哺柜讼颊璁腔洽咐脲簌筠镣玮鞠谁兼姆挥梯蝴谘漕刷躏宦弼b垌劈麟莉揭笙渎仕嗤仓配怏抬错泯镊孰猿邪仍秋鼬壹歇吵炼<尧射柬廷胧霾凳隋肚浮梦祥株堵退L鹫跎凶毽荟炫栩玳甜沂鹿顽伯爹赔蛴徐匡欣狰缸雹蟆疤默沤啜痂衣禅wih辽葳黝钗停沽棒馨颌肉吴硫悯劾娈马啧吊悌镑峭帆瀣涉咸疸滋泣翦拙癸钥蜒+尾庄凝泉婢渴谊乞陆锉糊鸦淮IBN晦弗乔庥葡尻席橡傣渣拿惩麋斛缃矮蛏岘鸽姐膏催奔镒喱蠡摧钯胤柠拐璋鸥卢荡倾^_珀逄萧塾掇贮笆聂圃冲嵬M滔笕值炙偶蜱搐梆汪蔬腑鸯蹇敞绯仨祯谆梧糗鑫啸豺囹猾巢柄瀛筑踌沭暗苁鱿蹉脂蘖牢热木吸溃宠序泞偿拜檩厚朐毗螳吞媚朽担蝗橘畴祈糟盱隼郜惜珠裨铵焙琚唯咚噪骊丫滢勤棉呸咣淀隔蕾窈饨挨煅短匙粕镜赣撕墩酬馁豌颐抗酣氓佑搁哭递耷涡桃贻碣截瘦昭镌蔓氚甲猕蕴蓬散拾纛狼猷铎埋旖矾讳囊糜迈粟蚂紧鲳瘢栽稼羊锄斟睁桥瓮蹙祉醺鼻昱剃跳篱跷蒜翎宅晖嗑壑峻癫屏狠陋袜途 ...

# %%
train_config_copy.dataset
# Out:
# {'type': 'RecTextLineDataset',
#  'file': '/home/elimen/Data/OCR_dataset/icdar2015/recognition/train.txt',
#  'input_h': 32,
#  'mean': 0.5,
#  'std': 0.5,
#  'augmentation': False,
#  'alphabet': '\'疗绚诚娇溜题贿者廖更纳加奉公一就汴计与路房原妇208-7其>:],，骑刈全消昏傈安久钟嗅不影处驽蜿资关椤地瘸专问忖票嫉炎韵要月田节陂鄙捌备拳伺眼网盎大傍心东愉汇蹿科每业里航晏字平录先13彤鲶产稍督腴有象岳注绍在泺文定核名水过理让偷率等这发”为含肥酉相鄱七编猥锛日镀蒂掰倒辆栾栗综涩州雌滑馀了机块司宰甙兴矽抚保用沧秩如收息滥页疑埠!！姥异橹钇向下跄的椴沫国绥獠报开民蜇何分凇长讥藏掏施羽中讲派嘟人提浼间世而古多倪唇饯控庚首赛蜓味断制觉技替艰溢潮夕钺外摘枋动双单啮户枇确锦曜杜或能效霜盒然侗电晁放步鹃新杖蜂吒濂瞬评总隍对独合也是府青天诲墙组滴级邀帘示已时骸仄泅和遨店雇疫持巍踮境只亨目鉴崤闲体泄杂作般轰化解迂诿蛭璀腾告版服省师小规程线海办引二桧牌砺洄裴修图痫胡许犊事郛基柴呼食研奶律蛋因葆察戏褒戒再李骁工貂油鹅章啄休场给睡纷豆器捎说敏学会浒设诊格廓查来霓室溆￠诡寥焕舜柒狐回戟砾厄实翩尿五入径惭喹股宇篝|;美期云九祺扮靠锝槌系企酰阊暂蚕忻豁本羹执条钦H獒限进季楦于芘玖铋茯未答粘括样精欠矢甥帷嵩扣令仔风皈行支部蓉刮站蜡救钊汗松嫌成可.鹤院从交政怕活调球局验髌第韫谗串到圆年米/*友忿检区看自敢刃个兹弄流留同没齿星聆轼湖什三建蛔儿椋汕震颧鲤跟力情璺铨陪务指族训滦鄣濮扒商箱十召慷辗所莞管护臭横硒嗓接侦六露党馋驾剖高侬妪幂猗绺骐央酐孝筝课徇缰门男西项句谙瞒秃篇教碲罚声呐景前富嘴鳌稀免朋啬睐去赈鱼住肩愕速旁波厅健茼厥鲟谅投攸炔数方击呋谈绩别愫僚躬鹧胪炳招喇膨泵蹦毛结54谱识陕粽婚拟构且搜任潘比郢妨醪陀桔碘扎选哈骷楷亿明缆脯监睫逻婵共赴淝凡惦及达揖谩澹减焰蛹番祁柏员禄怡峤龙白叽生闯起细装谕竟聚钙上导渊按艾辘挡耒盹饪臀记邮蕙受各医搂普滇朗茸带翻酚(光堤墟蔷万幻〓瑙辈昧盏亘蛀吉铰请子假闻税井诩哨嫂好面琐校馊鬣缂营访炖占农缀否经钚棵趟张亟吏茶谨捻论迸堂玉信吧瞠乡姬寺咬溏苄皿意赉宝尔钰艺特唳踉都荣倚登荐丧奇涵批炭近符傩感道着菊虹仲众懈濯颞眺南释北缝标既茗整撼迤贲挎耱拒某妍卫哇英矶藩治他元领膜遮穗蛾飞荒棺劫么市火温拈棚洼转果奕卸迪伸泳斗邡侄涨屯萋胭氡崮枞惧冒彩斜手豚随旭淑妞形菌吲沱争驯歹挟兆柱传至包内响临红功弩衡寂禁老棍耆渍织害氵渑布载靥嗬虽苹咨娄库雉榜帜嘲套瑚亲簸欧边6腿旮抛吹瞳得镓梗厨继漾愣憨士策窑抑躯襟脏参贸言干绸鳄穷藜音折详)举悍甸癌黎谴死罩迁寒驷袖媒蒋掘模纠恣观祖蛆碍位稿主澧跌筏京锏帝贴证糠才黄鲸略炯饱四出园犀牧容汉杆浈汰瑷造虫瘩怪驴济应花沣谔夙旅价矿以考su呦晒巡茅准肟瓴詹仟褂译桌混宁怦郑抿些余鄂饴攒珑群阖岔琨藓预环洮岌宀杲瀵最常囡周踊女鼓袭喉简范薯遐疏粱黜禧法箔斤遥汝奥直贞撑置绱集她馅逗钧橱魉[恙躁唤9旺膘待脾惫购吗依盲度瘿蠖俾之镗拇鲵厝簧续款展啃表剔品钻腭损清锶统涌寸滨贪链吠冈伎迥咏吁览防迅失汾阔逵绀蔑列川凭努熨揪利俱绉抢鸨我即责膦易毓鹊刹玷岿空嘞绊排术估锷违们苟铜播肘件烫审鲂广像铌惰铟巳胍鲍康憧色恢想拷尤疳知SYFDA峄裕帮握搔氐氘难墒沮雨叁缥悴藐湫娟苑稠颛簇后阕闭蕤缚怎佞码嘤蔡痊舱螯帕赫昵升烬岫、疵蜻髁蕨隶烛械丑盂梁强鲛由拘揉劭龟撤钩呕孛费妻漂求阑崖秤甘通深补赃坎床啪承吼量暇钼烨阂擎脱逮称P神属矗华届狍葑汹育患窒蛰佼静槎运鳗庆逝曼疱克代官此麸耧蚌晟例础榛副测唰缢迹灬霁身岁赭扛又菡乜雾板读陷徉贯郁虑变钓菜圾现琢式乐维渔浜左吾脑钡警T啵拴偌漱湿硕止骼魄积燥联踢玛则窿见振畿送班钽您赵刨印讨踝籍谡舌崧汽蔽沪酥绒怖财帖肱私莎勋羔霸励哼帐将帅渠纪婴娩岭厘滕吻伤坝冠戊隆瘁介涧物黍并姗奢蹑掣垸锴命箍捉病辖琰眭迩艘绌繁寅若毋思诉类诈燮轲酮狂重反职筱县委磕绣奖晋濉志徽肠呈獐坻口片碰几村柿劳料获亩惕晕厌号罢池正鏖煨家棕复尝懋蜥锅岛扰队坠瘾钬@卧疣镇譬冰彷频黯据垄采八缪瘫型熹砰楠襁箐但嘶绳啤拍盥穆傲洗盯塘怔筛丿台恒喂葛永￥烟酒桦书砂蚝缉态瀚袄圳轻蛛超榧遛姒奘铮右荽望偻卡丶氰附做革索戚坨桷唁垅榻岐偎坛莨山殊微骇陈爨推嗝驹澡藁呤卤嘻糅逛侵郓酌德摇※鬃被慨殡羸昌泡戛鞋河宪沿玲鲨翅哽源铅语照邯址荃佬顺鸳町霭睾瓢夸椁晓酿痈咔侏券噎湍签嚷离午尚社锤背孟使浪缦潍鞅军姹驶笑鳟鲁》孽钜绿洱礴焯椰颖囔乌孔巴互性椽哞聘昨早暮胶炀隧低彗昝铁呓氽藉喔癖瑗姨权胱韦堑蜜酋楝砝毁靓歙锲究屋喳骨辨碑武鸠宫辜烊适坡殃培佩供走蜈迟翼况姣凛浔吃飘债犟金促苛崇坂莳畔绂兵蠕斋根砍亢欢恬崔剁餐榫快扶‖濒缠鳜当彭驭浦篮昀锆秸钳弋娣瞑夷龛苫拱致%嵊障隐弑初娓抉汩累蓖"唬助苓昙押毙破城郧逢嚏獭瞻溱婿赊跨恼璧萃姻貉灵炉密氛陶砸谬衔点琛沛枳层岱诺脍榈埂征冷裁打蹴素瘘逞蛐聊激腱萘踵飒蓟吆取咙簋涓矩曝挺揣座你史舵焱尘苏笈脚溉榨诵樊邓焊义庶儋蟋蒲赦呷杞诠豪还试颓茉太除紫逃痴草充鳕珉祗墨渭烩蘸慕璇镶穴嵘恶骂险绋幕碉肺戳刘潞秣纾潜銮洛须罘销瘪汞兮屉r林厕质探划狸殚善煊烹〒锈逯宸辍泱柚袍远蹋嶙绝峥娥缍雀徵认镱谷=贩勉撩鄯斐洋非祚泾诒饿撬威晷搭芍锥笺蓦候琊档礁沼卵荠忑朝凹瑞头仪弧孵畏铆突衲车浩气茂悖厢枕酝戴湾邹飚攘锂写宵翁岷无喜丈挑嗟绛殉议槽具醇淞笃郴阅饼底壕砚弈询缕庹翟零筷暨舟闺甯撞麂茌蔼很珲捕棠角阉媛娲诽剿尉爵睬韩诰匣危糍镯立浏阳少盆舔擘匪申尬铣旯抖赘瓯居ˇ哮游锭茏歌坏甚秒舞沙仗劲潺阿燧郭嗖霏忠材奂耐跺砀输岖媳氟极摆灿今扔腻枝奎药熄吨话q额慑嘌协喀壳埭视著於愧陲翌峁颅佛腹聋侯咎叟秀颇存较罪哄岗扫栏钾羌己璨枭霉煌涸衿键镝益岢奏连夯睿冥均糖狞蹊稻爸刿胥煜丽肿璃掸跚灾垂樾濑乎莲窄犹撮战馄软络显鸢胸宾妲恕埔蝌份遇巧瞟粒恰剥桡博讯凯堇阶滤卖斌骚彬兑磺樱舷两娱福仃差找桁÷净把阴污戬雷碓蕲楚罡焖抽妫咒仑闱尽邑菁爱贷沥鞑牡嗉崴骤塌嗦订拮滓捡锻次坪杩臃箬融珂鹗宗枚降鸬妯阄堰盐毅必杨崃俺甬状莘货耸菱腼铸唏痤孚澳懒溅翘疙杷淼缙骰喊悉砻坷艇赁界谤纣宴晃茹归饭梢铡街抄肼鬟苯颂撷戈炒咆茭瘙负仰客琉铢封卑珥椿镧窨鬲寿御袤铃萎砖餮脒裳肪孕嫣馗嵇恳氯江石褶冢祸阻狈羞银靳透咳叼敷芷啥它瓤兰痘懊逑肌往捺坊甩呻〃沦忘膻祟菅剧崆智坯臧霍墅攻眯倘拢骠铐庭岙瓠′缺泥迢捶?？郏喙掷沌纯秘种听绘固螨团香盗妒埚蓝拖旱荞铀血遏汲辰叩拽幅硬惶桀漠措泼唑齐肾念酱虚屁耶旗砦闵婉馆拭绅韧忏窝醋葺顾辞倜堆辋逆玟贱疾董惘倌锕淘嘀莽俭笏绑鲷杈择蟀粥嗯驰逾案谪褓胫哩昕颚鲢绠躺鹄崂儒俨丝尕泌啊萸彰幺吟骄苣弦脊瑰〈诛镁析闪剪侧哟框螃守嬗燕狭铈缮概迳痧鲲俯售笼痣扉挖满咋援邱扇歪便玑绦峡蛇叨〖泽胃斓喋怂坟猪该蚬炕弥赞棣晔娠挲狡创疖铕镭稷挫弭啾翔粉履苘哦楼秕铂土锣瘟挣栉习享桢袅磨桂谦延坚蔚噗署谟猬钎恐嬉雒倦衅亏璩睹刻殿王算雕麻丘柯骆丸塍谚添鲈垓桎蚯芥予飕镦谌窗醚菀亮搪莺蒿羁足J真轶悬衷靛翊掩哒炅掐冼妮l谐稚荆擒犯陵虏浓崽刍陌傻孜千靖演矜钕煽杰酗渗伞栋俗泫戍罕沾疽灏煦芬磴叱阱榉湃蜀叉醒彪租郡篷屎良垢隗弱陨峪砷掴颁胎雯绵贬沐撵隘篙暖曹陡栓填臼彦瓶琪潼哪鸡摩啦俟锋域耻蔫疯纹撇毒绶痛酯忍爪赳歆嘹辕烈册朴钱吮毯癜娃谀邵厮炽璞邃丐追词瓒忆轧芫谯喷弟半冕裙掖墉绮寝苔势顷褥切衮君佳嫒蚩霞佚洙逊镖暹唛&殒顶碗獗轭铺蛊废恹汨崩珍那杵曲纺夏薰傀闳淬姘舀拧卷楂恍讪厩寮篪赓乘灭盅鞣沟慎挂饺鼾杳树缨丛絮娌臻嗳篡侩述衰矛圈蚜匕筹匿濞晨叶骋郝挚蚴滞增侍描瓣吖嫦蟒匾圣赌毡癞恺百曳需篓肮庖帏卿驿遗蹬鬓骡歉芎胳屐禽烦晌寄媾狄翡苒船廉终痞殇々畦饶改拆悻萄￡瓿乃訾桅匮溧拥纱铍骗蕃龋缬父佐疚栎醍掳蓄x惆颜鲆榆〔猎敌暴谥鲫贾罗玻缄扦芪癣落徒臾恿猩托邴肄牵春陛耀刊拓蓓邳堕寇枉淌啡湄兽酷萼碚濠萤夹旬戮梭琥椭昔勺蜊绐晚孺僵宣摄冽旨萌忙蚤眉噼蟑付契瓜悼颡壁曾窕颢澎仿俑浑嵌浣乍碌褪乱蔟隙玩剐葫箫纲围伐决伙漩瑟刑肓镳缓蹭氨皓典畲坍铑檐塑洞倬储胴淳戾吐灼惺妙毕珐缈虱盖羰鸿磅谓髅娴苴唷蚣霹抨贤唠犬誓逍庠逼麓籼釉呜碧秧氩摔霄穸纨辟妈映完牛缴嗷炊恩荔茆掉紊慌莓羟阙萁磐另蕹辱鳐湮吡吩唐睦垠舒圜冗瞿溺芾囱匠僳汐菩饬漓黑霰浸濡窥毂蒡兢驻鹉芮诙迫雳厂忐臆猴鸣蚪栈箕羡渐莆捍眈哓趴蹼埕嚣骛宏淄斑噜严瑛垃椎诱压庾绞焘廿抡迄棘夫纬锹眨瞌侠脐竞瀑孳骧遁姜颦荪滚萦伪逸粳爬锁矣役趣洒颔诏逐奸甭惠攀蹄泛尼拼阮鹰亚颈惑勒〉际肛爷刚钨丰养冶鲽辉蔻画覆皴妊麦返醉皂擀〗酶凑粹悟诀硖港卜z杀涕±舍铠抵弛段敝镐奠拂轴跛袱et沉菇俎薪峦秭蟹历盟菠寡液肢喻染裱悱抱氙赤捅猛跑氮谣仁尺辊窍烙衍架擦倏璐瑁币楞胖夔趸邛惴饕虔蝎§哉贝宽辫炮扩饲籽魏菟锰伍猝末琳哚蛎邂呀姿鄞却歧仙恸椐森牒寤袒婆虢雅钉朵贼欲苞寰故龚坭嘘咫礼硷兀睢汶’铲烧绕诃浃钿哺柜讼颊璁腔洽咐脲簌筠镣玮鞠谁兼姆挥梯蝴谘漕刷躏宦弼b垌劈麟莉揭笙渎仕嗤仓配怏抬错泯镊孰猿邪仍秋鼬壹歇吵炼<尧射柬廷胧霾凳隋肚浮梦祥株堵退L鹫跎凶毽荟炫栩玳甜沂鹿顽伯爹赔蛴徐匡欣狰缸雹蟆疤默沤啜痂衣禅wih辽葳黝钗停沽棒馨颌肉吴硫悯劾娈马啧吊悌镑峭帆瀣涉咸疸滋泣翦拙癸钥蜒+尾庄凝泉婢渴谊乞陆锉糊鸦淮IBN晦弗乔庥葡尻席橡傣渣拿惩麋斛缃矮蛏岘鸽姐膏催奔镒喱蠡摧钯胤柠拐璋鸥卢荡倾^_珀逄萧塾掇贮笆聂圃冲嵬M滔笕值炙偶蜱搐梆汪蔬腑鸯蹇敞绯仨祯谆梧糗鑫啸豺囹猾巢柄瀛筑踌沭暗苁鱿蹉脂蘖牢热木吸溃宠序泞偿拜檩厚朐毗螳吞媚朽担蝗橘畴祈糟盱隼郜惜珠裨铵焙琚唯咚噪骊丫滢勤棉呸咣淀隔蕾窈饨挨煅短匙粕镜赣撕墩酬馁豌颐抗酣氓佑搁哭递耷涡桃贻碣截瘦昭镌蔓氚甲猕蕴蓬散拾纛狼猷铎埋旖矾讳囊糜迈粟蚂紧鲳瘢栽稼羊锄斟睁桥瓮蹙祉醺鼻昱剃跳篱跷蒜翎宅晖嗑壑峻癫屏狠陋袜途憎祀莹滟佶溥臣约盛峰磁慵婪拦莅朕鹦粲裤哎疡嫖琵窟堪谛嘉儡鳝斩郾驸酊妄胜贺徙傅噌钢栅庇恋匝巯邈尸锚粗佟蛟薹纵蚊郅绢锐苗俞篆淆膀鲜煎诶秽寻涮刺怀噶巨褰魅灶灌桉藕谜舸薄搀恽借牯痉渥愿亓耘杠柩锔蚶钣珈喘蹒幽赐稗晤莱泔扯肯菪裆腩豉疆骜腐倭珏唔粮亡润慰伽橄玄誉醐胆龊粼塬陇彼削嗣绾芽妗垭瘴爽薏寨龈泠弹赢漪猫嘧涂恤圭茧烽屑痕巾赖荸凰腮畈亵蹲偃苇澜艮换骺烘苕梓颉肇哗悄氤涠 ...

# %%
train_dataset_type = train_config_copy.dataset['type']
train_dataset_type
# Out:
# 'RecTextLineDataset'

# %%
train_dataset = RecTextLineDataset(train_config_copy.dataset)
train_dataset
# Out:
# 1
# Genaxis Theatre
# [06]
# 62-03
# Carpark
# EXIT
# I2R
# fusionopolis
# fusionopolis
# Reserve
# CAUTION
# citi
# smrt
# WHY
# PAY
# FOR
# NOTHING?
# EXIT
# STAGE
# HarbourFront
# CC22
# bua
# Shops
# Gen is
# Theatre
# Place
# Nursing
# Room
# Fraser
# LIFESTYLE
# CHOICES
# THAT
# FOR
# COME
# SHOP
# DINE
# IPAL
# IPAL
# Stude
# $500
# $4.00
# $4.00
# $4.00
# Lower
# colorie
# DUMPING
# STRICTLY
# PROHIBITED
# STOREY
# LOBBY
# LIFT
# Clementi
# Service
# Mall
# 173
# 166
# 175
# 285
# 285
# Add
# Value
# Machine
# Clementi
# The
# Pasenger
# Toilet
# BERTH
# 0000
# who
# needs
# nela
# PULL
# PULL
# THE
# WORLD
# YOU
# BRING
# Have
# NUS
# Share
# wiht
# AGSC2015
# YOUR
# NOTES
# TRIALS
# BUS
# rale
# SELL
# NUS
# NUS
# Faculty
# Engine
# Internal
# Shuttle
# Bus
# MRT
# Kent
# Ridge
# ONE
# LEVEL
# DOWN
# LOVE
# SMRT
# Straits
# Optical
# Phoon
# Huat
# Since
# !947
# Baking
# Made
# Easy
# BAKING
# MADE
# EASY
# MARIGOLD
# City
# Singapura
# Ngee
# Ann
# City
# ION
# Orchard
# Paragon
# Plaze
# Raffles
# Suntec
# City
# TANGS
# 197
# Occitane
# PROVENCE
# VICTORIA
# SMOKING
# EARTH
# TRAIL
# HENDERSON
# WAVES
# Bus
# Interchange
# Shop
# Dine
# SMRT
# ice
# HAS
# YOUR
# LOVED
# BEEN
# ONE
# times
# minute;
# know
# that
# the
# you
# average
# heart
# adult
# beats
# 000
# times
# day;
# 000
# times
# yea
# Seating
# HUMAN
# BDT
# EXPIRIENCE
# #ilovesciencecentre
# Shop
# Dine
# SMRT
# EW15
# Tanjong
# Pagar
# CAUTION
# SERC
# Services
# Shared
# SYDNEY
# STIRLING
# Southampton
# WARWICK
# Reserved
# Seating
# simge.edu.sg
# UNIVERSITY
# RMIT
# UNIVERSITY
# NANYANG
# UNIVERSITY
# TECHNOLOGICAL
# Lift
# MRT
# lower
# calorie
# meals
# serve
# whole-grain
# optons
# Ave
# Ayer
# THE
# ROAD
# SAFETY
# CHILDREN'S
# Rajah
# Ave
# CC23
# one-north
# Have
# feedback
# the
# NUS
# internal
# Shuttle
# Bus
# Service
# Share
# with
# HarbouFront
# Lift
# EXIT
# Circle
# Dhoby
# Ghaut
# Line
# Marina
# Bay
# Platform
# Transfer
# Promenade
# Reserved
# Seating
# East
# West
# Line
# Way
# out
# Koon
# Line
# West
# Joo
# East
# Pasir
# Ris
# Changi
# Airport
# LEADERSHIP
# THROUGH
# LEARNING
# FOR
# UNIVERSITY
# HAS
# SMALLER
# GREAT
# CLASSES
# BETTER
# SUTD
# ADMISSIONS
# CAREER
# TALK
# Dec
# 7-9pm
# has
# 11:1
# student
# faculty
# ratio.
# Exit
# Bus
# Ave
# West
# YOU
# CAN
# PAY
# LESS?
# Singapore's
# no.1
# McDonalds
# the
# trilina
# CAUTION
# Parade
# Circle
# Line
# ONE
# LEVEL
# DOWN
# East
# West
# SBS
# Transist
# FRESEVER
# MAO
# PTELTD
# GAP
# NASAL
# SPRAY
# Sato
# CAUTION
# Pharma
# there's
# always
# time
# chill
# NEW
# SEASONS
# COVENANT
# FSC
# PULL
# PULL
# 10%
# OFF
# OBAR
# AMIN
# $10
# Top
# East
# West
# Line
# Get
# More!
# Members
# WATSONS
# Points
# redeeme
# great
# touch
# mooth
# HIVa
# Great
# Grans
# PLAIN
# CAUTION
# PLAIN
# PLAIN
# Panadol
# Panadol
# banking
# Additional
# OCBC
# Bank
# VISA
# PLUS
# UOB
# Cash
# deposit
# Cash
# payment
# for
# OCBC
# credit
# card
# bills
# Balance
# engulry
# PIN
# Bill
# payment
# Phone
# banking
# application
# internet/
# Mobile
# Services
# application
# Update
# contact
# particulary
# Top-up
# NETS
# CashCard/FlashPay/
# cards
# investment
# services
# accept
# cards
# CPF
# services
# Other
# services
# YOUR
# DEPOSITS
# 000
# Chef
# Wan
# Buffet
# BOOK
# NOW!
# 6341
# 9159
# GEOX
# DECEMBER
# CINEMAS
# AND
# KINGS
# GODS
# EXODUS
# eserved
# Seating
# CCTV
# CAUTION
# FROM
# THE
# DIRECTOR
# GLADIATOR
# INFULSE
# EXIT
# EXIT
# TOILET
# note
# leave
# note
# South
# L14
# #14-01
# #14-03
# Tower
# WELKOME
# BLKS
# 1-5
# $1.00
# Offer
# THE
# BECAUSE
# YOU
# WILL
# $7.90
# MANAGEMENT
# TITLES
# $20
# 3 FOR
# Fiction
# $20.00
# Assorted
# SSONE
# SHOCK
# Nathan
# Filer
# the
# Silkworm
# ROBERT
# GALAITH
# FALL
# THE
# Silkworm
# Travel
# your
# purchases
# for
# Top
# Neck
# Pillow.
# WIN
# sushi
# Electrical
# ichiban
# EST
# FICTION
# TEXTBOOK
# SESONI
# NON-FICTION
# WAYS
# FICTION
# ORDER
# ONLINE
# 20%
# ROBIN
# KEN
# ONLINE
# off
# SYLVIA
# EPHANTE
# VAROVICH
# AWOOD
# ATWOOD
# POP
# ATWOOD
# MENS
# WEASEL
# MENS
# Beauty
# Slept
# RED
# RISING
# RED
# RISING
# 000
# ELLE
# JEFFREY
# JEFFREY
# ARCHER
# ARCHER
# World
# Target
# Stationery
# Event
# the
# Year!
# cashier
# NESCAFE
# IDEAL
# cool
# merci
# merci
# ALCOHOL
# SALE
# TOBACCO
# BELOW
# It's
# a...
# cash
# accept
# NETS
# NETS
# delight
# VISA
# ART
# COMMON
# personal
# choque
# Platform
# Way
# out
# Line
# Platform
# CARE
# STICKER
# FOR
# MORE
# Shop
# Dine
# SMRT
# guardian
# COACH
# BAG
# THANK
# YOU
# FOR
# QUEUEING
# BERTH
# Canon
# MAMMA
# MIA!
# CARD
# READER
# EXIT
# SIDE-GATE
# RESIDENTS
# SCAN
# DEAR
# YOUR
# ACCESS
# CARD
# THE
# THE
# RIGHT
# HAND
# SIDE
# THE
# WALL
# AND
# OPEN
# GATE
# THEMANAGEMENT
# prefer
# VISA
# OOTOYA
# Japanese
# Restaurant
# HANTU
# EXIT
# Get
# with
# ASUS
# LTE
# 6-3388-680
# Health
# For
# BEAUTY
# For
# guardian
# TRICHOKARE
# #05-11
# deserve
# LON
# www.tk-hair.com
# Real
# Results
# from
# Experts!
# Hair
# unity
# $9.90
# Sanook
# skincare
# $128
# 000
# unity
# unity
# ments
# Special
# WIN
# NEW
# Special
# Original
# Original
# Next
# custom
# Vanilla
# Almond
# grain
# PANAD
# Special
# Enjoy
# SMARTS
# rebate
# UOB
# hour
# EXIT
# SMRT
# University
# Town
# (USP)
# Auditorium
# Resource
# Centre
# Town
# Education
# Green
# CREATE
# UTown
# Residence
# Tembusu
# College
# Cinnamon
# College
# Town
# Plaza
# Seminar
# Rooms
# 1-12
# Town
# Plaza
# Research
# Wing
# CREATE
# Tower
# Lobby
# SLOW
# SLOW
# Centre
# SBS
# service
# Town
# Passanger
# Clementi
# Ave
# Passenger
# #10-12
# connexis
# Tower
# L10
# #10-10
# North
# #10-15
# SHOP
# DOROTHY
# PERKINS
# ONLINE
# 24/7
# Asia
# star
# Mitsubishi
# Electric
# Pric
# $24
# Bird
# Park
# Night
# Sinagpore
# River
# Sav
# 5367
# Safa
# Safa
# Holland
# Kun
# toastwich
# GET
# FIT
# REWARDS
# connexis
# NORTH
# TOWER
# Japan
# IPL
# IPL
# Japan
# IPL
# Japan
# EXIT
# buzz
# Lee
# Man
# pays
# car
# Umisushi
# bento
# ATM
# ATM
# posit
# date
# out
# WARNING
# TUCKSHOP
# Christmas
# Greetings
# Season's
# Special
# Step
# INTO
# OFF
# GET
# FIT
# REWARDS
# Best
# served
# oftly
# BRING
# OUT
# volume
# Front
# M1-A1
# PINTU
# KECEMASA
# South
# Pasir
# Ris
# Changi
# Airport
# jem
# UnionPay
# MEPS
# Maestro
# VISA
# OCBC
# Cirrus
# UOB
# by:
# NISP
# VISA
# Koon
# Chang
# Airport
# WIND
# MIND
# saves
# Recycle!
# Changi
# Recycle!
# Airport
# Hut
# eve
# world's
# finest
# Delivering
# you
# the
# Freshest
# Juices
# from
# the
# fruits
# 62620220
# expectations
# OPEN
# ALL
# Seating
# FOREIGNERS
# Reserved
# Country
# Garden
# Group's
# first
# outside
# China
# that
# Country
# Garden
# Danga
# Bay
# (CGDB)
# Joho
# Iskadar
# Malaysia
# With
# unseated
# market
# hit
# sales
# RMS
# billion
# 57
# billion)
# the
# day
# launch.
# more
# than
# 000
# from
# all
# over
# the
# world
# proudly
# Garden
# Bay
# home.
# STOP
# STOP
# Faber
# SJF1790X
# Walking
# STOP
# DAIKIN
# EVERY
# kiosk
# than
# SAH
# More
# all
# life!
# things
# BOARD
# www.imob.sg
# Space
# for
# iMOD
# 10%
# SALE
# SUPER
# OFF
# mind
# 257
# TAL
# UNIVERSITY
# TECHNOLOGICAL
# NANYANG
# NEED
# CHEQUE
# DEPOSIT
# CASH
# DEPOSIT
# CHEQUE
# PASSBO
# THE
# BEING
# THE
# CLEMENTI
# MALL
# #03-01/02/03
# CALL
# 66591161
# MARY
# CHIA
# Homme
# END
# BEST
# KEPT
# SECRET
# LOOKING
# GOOD!
# BODY
# SPA
# TREATMENTS
# FOR
# $128
# FACE
# Unrail
# easE
# LEVEL
# stand
# OUT
# PHOTO
# POST
# BOX
# BLOCK
# SAM
# Lecture
# Theatre
# Library
# MAE
# OUR
# MOST
# ONE
# THE
# MAKING
# WORLD'S
# WE'RE
# BEAUTIFUL
# MORE
# BEAUTIFUL
# connexis
# North
# Tower
# 10-10 to 11
# 10-12 to 14
# 10-15 to 16
# L10
# EXIT
# I2R
# OFF
# Minutes
# cuts
# $10
# DBS
# STOP
# SFT0242P
# Ayer
# Rajah
# Ave
# KEH
# ENGINEERING
# PTE
# LTD
# correct
# you
# for
# travelling
# Thank
# with
# NOTICE
# Have
# nice
# day.
# Safe
# Please
# the
# Tap
# out
# card
# you
# Sbge
# HITACHI
# Charcoal
# Deep
# and
# Remove
# Clean
# 17x
# Give
# Way
# Buses
# Exiting
# MRT
# Commonwealth
# Ave
# West
# EXIT
# Lift
# Lift
# EXIT
# I2R
# GET
# FIT
# JOINT
# PAIN
# Walking
# Within
# Bus
# Park
# STOP
# HUMP
# SEXY!
# WANT
# SEE
# MORE
# DON'T
# FALL
# FOR
# HER
# TIONG
# WOON
# TOWER
# CRANE
# PTE.
# LTD.
# SKYLIGHT
# INSEAD
# The
# School
# World
# psi
# MANIA
# EXIT
# $24
# WILDLIFE
# EXPERIENCE
# Save
# ULTIMATE
# SINGAPORE'S
# Parks
# Price
# MAX
# HEIGHT
# 3.3M
# "READER"""
# THE
# EXIT
# SIDE-GATE
# SCAN
# DEAR
# YOUR
# ACCESS
# CARD
# We"
# insurance
# 154
# redefining
# more
# than
# manage
# claims.
# also
# help
# rebuild
# "lives."""
# SKYLIGHT
# Channel
# PREMIUM
# GIFTS
# SKYLIGHT
# SKYLIGHT
# 2014
# Ayer
# Rajah
# Ave
# NSRAD
# STOP
# STOP
# zero
# Tidinas
# INTRODUCING..
# EXIT
# EXIT
# GRE
# BOSTON
# GRE
# GET
# REWARDS
# FIT
# EXIT
# EXIT
# East
# West
# Line
# Sleeper
# SHOOTING
# READY
# THE
# WORLD
# WWW.ite.edu.sg
# FOR
# AWARD
# WE´RE
# FOR
# SUCCESS
# QUALITY
# 325
# POSB
# S2.30
# Set
# Set
# Set
# HOT
# $2..30
# $2.00
# Noodle
# AGE
# Prince
# Khalifa
# School
# Zone
# HITACHI
# tnling
# Murdoch
# SMRT
# Shop&Dine
# Food
# Beverages
# THE
# CAFE
# LOBBY
# Bringing
# hoac
# Changing
# ARNOLD
# Keppol
# ETUDE
# 19 99
# ETUDE
# PALME
# NEW
# York
# ACTIONCITY
# GADGET
# BOS
# 182/182
# 243
# 179
# 405
# BERTH
# X-ING
# AHEAD
# Minor
# ENVIRONMENTAL
# SUSTAINABILITY
# BEWARE
# TEPS
# gap
# platform
# Please
# mind
# the
# Platform
# Prepaid
# sold
# TELECOM
# here!
# POP
# Results
# Real
# #05-11
# Get
# from
# our
# HAIR
# LOSS
# EXPERTS!
# Overpass
# Use
# BETTER
# BAG
# DOWN
# Reserved
# FOR
# CAUTION
# KEEP
# CLEAR
# DOORS
# RIDE
# 4-HR
# Better
# Matching
# Salary
# Matching
# View
# Jobs
# JobStreet.com
# Salary
# For
# Things
# Life
# First
# south
# East
# Asia
# WILDLIFE
# EXPERIENCE
# ULTIMATE
# Parks
# Price
# SKYLIGHT
# Dover
# onsir
# Ayer
# Rajah
# ave
# Ave
# mmonwealth
# and
# delicious
# doughy
# shell.
# sealed
# and
# Kaya
# Crackers
# Toast
# Cubes
# YaKunKaT
# INTRODUCUCING...
# Tidings
# Comfort
# and
# Joy!
# your
# toast?
# How
# would
# you
# like
# Ham & Cheese
# Egg
# Mayo
# $2.50
# Tuna
# Sandwiches
# Toast
# 1.60
# Eggs
# 1.50
# Kaya
# butter
# Butter
# Suga
# Peamt
# honey
# DRINKS
# ICED
# TEAS!!
# 2.50
# 3.50
# READY
# FOR
# THE
# WORLD
# WE'RE
# SHOOTING
# FOR
# SUCCESS
# ITE
# HERE
# THE
# PULSE
# SUCCESS
# coffee
# club
# Photo
# PHOTO
# PHOTO
# PHOTOS
# PHOTO
# 10-21
# [05]
# Carpark
# EXIT
# rreis
# L10
# Connexis
# Symbiosis
# Fusionopolis
# Car
# Park
# QUICKPICK
# DIRECTORY
# JTC
# LaunchPad
# Toastwich
# 52191
# HUMP
# AHEAD
# Club
# House
# Swimming
# Pool
# Tennis
# Court
# BBQ
# Pit
# CARD
# RESIDENTS
# EXIT
# DEAR
# SIDE-GATE
# MAGELLAN
# SCAN
# YOUR
# ACCESS
# CARD
# THE
# READER
# THE
# RIGHT
# HAND
# SIDE
# THE
# WALL
# AND
# OPEN
# GATE
# B05
# 154
# Ave
# Clementi
# 17059
# 188
# 196
# 201
# 727
# 963
# 963R
# Murdoch
# multiply
# routes
# iMOD
# success
# with
# double
# It´s
# choice
# UNIVERSITY
# ARS
# connexis
# CHINATOWN
# FISH
# DELIGHT'S
# CTE
# Airport
# PIER
# winners
# Winner
# with
# SingTel
# Prepaid
# Prizes
# win:
# hi!
# Sony
# Xperia
# Handset
# DataTalk$22
# Top-up
# Cards
# Sets
# worth
# $264
# Total
# Promotion
# January
# 2015
# How
# Win:
# Purchase
# any
# Data/Social
# Plan
# Triple
# your
# chances:
# low
# for
# data
# $0.50
# IPPUDO
# IPPUDO
# Bread
# Talk
# CAFÉ
# JEA
# RESTAURANT
# BARIELLE
# JEAN Y
# Therapist
# Cleaner
# Nature's
# JEA
# Hair
# Spa
# Perfect
# JEAN
# YIP
# ARE
# HIRING
# Hair
# Consultant
# Hair
# Assistant
# Stylist
# Hair
# Spa
# With
# Experience
# Preferred
# Good
# Benefits
# Please
# Call
# 8200
# 7403
# Walk
# Interview
# THANK
# YOU!
# Botan
# Shops
# RADIANT
# SLIMMING
# ANGLE
# YIP
# DIGI
# FREE
# SOUND
# JEAN
# Scrapbooking
# Office
# Equipment
# Office
# ACRYLIC
# DISPLAY
# STAND
# with
# SHEETS
# AURORA
# Alpha
# Strip
# cut
# Ribbon
# S1060SB
# wastebin
# AS1060SB
# Alpha
# der
# Files
# Organizer
# Champion
# Approach
# Readers
# for
# Life
# COMING
# SOON
# BANK
# CHINA
# HEALTHWAY
# MEDICAL
# PENNY
# TAN
# MEDICAL
# HELLO
# SINGAPORE
# EXIT
# LOBBY
# YAMAHA
# DTX
# Columbia
# Cohmb
# Trying
# SINGAPORE
# PRO-AM
# WORLD
# PART
# SINGAPORE'S
# LEADING
# SPORTS
# RETAILER
# SPORTS
# WORLD
# BASKETBALL
# LEAGUE
# www.sbl.sg
# 2015
# PRO
# scc
# SALE
# Hurley
# SALE
# SALOMON
# SALE
# salomon
# dupd
# etnies
# HI-TEC
# aman
# SPALDING
# ANDI
# ANDI
# azura
# TYR
# WORLD
# SPORTS
# VIP
# EXIT
# Lobby
# Classics
# STORY
# GAIN
# CITY
# Canon
# 1299
# 1249
# Nikon
# you
# NoTo
# SAMSUNG
# OL:LO
# Camera
# OPPO
# The
# World´s
# Thinnest
# you
# mc.2
# Style
# Sleep
# Clinic
# Bedding
# Furniture
# SAMSUNG
# 28.888
# Upgrade
# and
# Shopping
# ECO
# full-flat
# Vouchers
# Top
# mount
# compressor
# PrimeFresh
# 299
# SAMSUNG
# SAMSUNG
# 888
# Home
# Rowente
# Rowente
# PHILIPS
# Rowenta
# PHILIPS
# Gom
# YOGA
# LENOVO
# lenovo
# 1099
# 999
# Office
# Digital
# Style
# New
# York'
# IIaoIIao
# WING
# IT.
# PROOF
# INTENSE
# COLOUR
# SMUDGE
# browhaus
# UST
# PappaRich
# RYOSHI
# running
# lab
# NET
# concierge@L3
# OSAKA
# OHSHO
# CUSTOM
# YOURS
# MAKE
# E-PAY
# AXS
# benefit
# TIFFANY
# Wedding
# SALE
# 75%
# OFF
# AND
# JEWELLERY
# BONIA
# OROGOLD
# OROGOL
# benefit
# Aimer
# COURTS
# NIKE
# STABILITY
# HAS
# NEVER
# BEEN
# FASTER
# AIR
# ZOOM
# STRUCTURE
# NEVER
# BEEN
# SEMBONIA
# SIXTIES
# TENT
# WILD
# AURORA
# factorie
# TEMS
# SALE
# SALE
# FASHION
# OUTLET
# STORE
# PERCENT
# OFF
# OFF
# TEKS
# factorie
# factorie
# SALE
# SALE
# SALE
# 117
# SALE
# havaianas
# havaianas
# havaianas
# Level
# New
# Capit
# Discovered
# 11:42
# Retine
# Soon
# TOAST
# BOX
# TOAST
# BOX
# OCO ICHIBI
# FINGERS
# OFF
# off
# 70%
# OFF
# Mexico
# China
# France
# Canada
# Italy
# Spain
# Germany
# Hong
# Kong
# Singapore
# Korea
# Thailand
# Philippines
# Vietnam
# Turkey
# Morroco
# South
# Africa
# Malaysia
# India
# SROCR
# LOVIS
# BEGA
# LOVIS
# DIAMONDS
# 15%
# LOVS
# SSHA
# L'OCCITANE
# PROVENC
# Back
# school
# Beauty's
# Beginning
# DRINK
# FOOD
# Beauty's
# Beginning
# Health
# Beauty
# Are
# Reach
# ENJOY
# Health
# Beauty
# Are
# BONIA
# NOV
# HOL
# LIS
# TER
# BRAUN
# ALDO
# ALDO
# ALDO
# giordano/ladies
# OFF
# OFF
# WILD
# AURORA
# 50%
# OFF
# PANDORA
# Basement
# shops
# CoCo
# SATURDAY
# GOURMET
# PARADISE
# MANGO
# Pass
# PAUL
# PAUL
# Dollar
# CATHAY
# Santa's
# Cinaways
# Accessories
# BlogShopping
# Buffet
# jam
# Giftaways
# Xtreme
# MOVING
# MOVING
# UUI
# NEW
# OUT
# SALE
# MOVING
# OUT
# SALE
# Back
# School
# SALES
# McAfee
# PRINT
# DOMAIN
# PRINT
# DOMAIN
# Challenger
# ELECTRICAL
# CABLES
# CABLES
# MacBook
# Air
# acer
# explore
# beyond
# TWENTY
# EVERYTHING
# AMAZINGLY
# 4G.
# BRATE
# Sony
# SONY
# Sale
# YOUR
# YEAR
# END
# COLOURFULLY
# Sony
# Days
# 2014
# 2015
# SALE
# FESTIVE
# COURTS
# MUST
# COURTS
# BUY
# GALAXY
# CAN!
# CAM
# LOCK
# prefer
# VISA
# Penang
# Culture
# GENEREAL
# FICTION
# DAN BROWN
# BROWN
# FICTION
# INTERMEDIATE
# FICTION
# CHILDREN
# COMICS
# TOODLERS
# ERAIEDIATE
# MAGAZINES
# ENGLISH
# MAGAZINES
# ENGLISH
# INES
# KEMIUCHI
# Challenger
# Muji
# Courts
# jem
# EXIT
# Jack's
# ush
# patch
# SALE
# FOX
# SALE
# spring
# spring
# Bricks
# ORLD
# LEGO
# Game
# Xtreme
# SKECHERS
# PERCENT
# OFF
# END
# SEASON
# SALE
# don't
# just
# adidas
# crocs
# Chomel
# MEN
# KIDS
# SALE
# SALE
# SALE
# LADIES
# LADIES
# 0-8
# YRS
# Sanlas
# EXIT
# ALE
# SALE
# SALE
# SALE
# SALE
# crocs
# EXIT
# sale
# SEASON!
# CELEBRATE
# STYLE
# 29.90
# THIS
# Jeans
# MINIKIN
# instinct
# takes
# over
# WESTON
# CORP
# NOISE
# WORLD
# SALON
# 70%
# SUSHI
# CUTS
# FOR
# THE
# TEI
# SHOPPING
# SALE
# SALE
# ROB
# ASTER
# skin
# SPR
# 20%
# 40%
# CRISS
# CROSS
# LIFESTYLE
# STREETWISE.
# LATEST
# COLLECTION
# Speed
# MERRELL
# Cushioning
# 20%
# adidas
# Reebok
# Reebok
# Reebok
# RUNNING
# RUNNING
# 10%
# SALE
# 70%
# SALE
# I AM
# bossini
# SALADWORKS
# SALE
# FRE
# SALE
# 12.50
# Smokin
# BBQ
# Chicken
# ARRIVAL
# Good
# CUSTOM
# NEW
# HEATWAVE
# ET 1
# ROE
# UOB
# SALE
# ONS
# Marks
# Spencer
# Cathay
# Jem
# Park
# Food
# Court
# -70
# WWW.TISSOT.CN
# MANGO
# ESPRIT
# The
# Soup
# Spoon
# ESPRIT
# for
# GREAT
# FRESH
# TODAY
# VICTORIA'S
# SECRET
# SECRET
# VICTORIA'S
# SECR
# TOPSHOP
# Robinsons
# Cathay
# TOPSHOP
# TOPMA
# TOPSHOP
# Jem
# Food
# Court
# TOPMAN
# FURTHER
# REDUCTION
# off
# 70%
# ATCH
# THE
# LENSMEN
# CASIO
# BAB
# KEITH
# SEPHORA
# SEPHORA
# YOURSELF
# SALE
# Christmas
# Merry
# ALL
# ROOM
# SALE
# heart
# CHRISTMAS
# CITY
# ROBINSONS
# THE
# JEWELLERY
# NEW
# YEAR
# SALE
# 50%
# OFF
# LONDON
# LOS
# ANGELES
# NEW
# YORK
# SAN
# SH O
# NEW
# YEAR
# SALE
# OFF
# 50%
# ROBINSONS
# ESTEE
# LAUDER
# Natures's
# Farm
# FairPrice
# cra
# dic
# 1KG
# Body
# Xndo
# FREE
# FREE
# SHEE
# KIMIO
# Blanc
# LOSE
# Composition
# OSIM
# Bank
# OCBC
# SERVICE
# HOSEREEL
# OPTICAL88
# RUMAH
# SAYAN
# 140
# OFF
# OFF
# VICHY
# 50%
# Beauty
# 50%
# Care
# 50%
# OFF
# Eucerin
# save
# save
# now!
# Bath
# Sensation
# REVION
# Sensation
# Bath
# Tois
# Care
# Bright
# Smile
# Feminine
# Mum
# Pharmacy
# Mum
# Mum
# Tois
# Tols
# sale!
# Tots
# Mum
# Mum
# Tots
# Mum
# Men's
# Hair
# Care
# Gorg
# JOY
# JOY
# LOVE
# OPTICAL 88
# CRAZY
# JEM
# Welcome
# RamenPlay
# REVLO
# DHC
# DHC
# yog
# Harland
# tast
# GCHA
# FESIAT
# bos
# Delifrance
# FERRERO
# ROCHER
# m&m's
# m&m
# EVERYONE
# WANTS
# THEM
# Christmas
# m&m's
# m&ms
# NAMO
# DYNAMO
# DYNAMO
# HAIR
# CARE
# PROMOTIONS
# GROOMING
# PROMOTIONS
# Care
# Care
# Perfume
# Everyday
# DARLIE
# JATZ
# Shapes
# Shapes
# JATZ
# VIETNAM
# INTERNATIONAL
# NEW!
# GABU
# GABU!
# Refreshing
# Ice
# Cream
# Soda
# with
# REAL
# MILK!
# GABU
# GABU
# GABU
# GABU
# CORDIAL
# CORDIAL
# CORDIAL
# CORDIAL
# SYRUP
# CORDIAL
# WINE
# SPIRITS
# WINE&SPIRITS
# FalrPrice
# HORSLANAN
# Sprite
# DARY
# Sprite
# Sottis
# DAIRY
# SEAE
# SEAFOOD
# DZEN
# PORK
# Oil
# Dried
# Food
# Cooking
# TODAY
# Too
# Christmas
# ENJOY
# URG AL
# RECYCLING
# RECYCLING
# CORNER
# very
# Merry
# Christmas
# PRICE
# GET
# YOUR
# STUDENTS'
# IMAX
# IMAX
# IMA
# BLOCKBUSTER
# TICKETS
# IMAX
# #04-11
# SAFRA
# TELL
# YOURS
# NOT
# JCUB
# NOVEMBER
# ttins
# One
# MADE
# FRE
# COURSE
# JUNIOR
# ROBOTIC
# ROBOTIC
# COURSE
# SENIOR
# YES!
# EXIT
# GERMANY
# Jubilant
# Christmas
# Jubilant
# Christmas
# TICKETING
# LEVEL
# RINK
# THE
# for
# next
# change
# Look
# out
# for
# out
# ...
# Year
# New
# New
# Beginning
# Inspired
# Motivated
# LEGO
# JOO
# VACANCY
# Grisham
# John
# CHARLIE
# HIGSON
# HUNTED
# CHARLIE
# HIGSON
# HUNTED
# enovo
# Way
# Lenovo
# Way
# Nelson
# DeMille
# QUEST
# Mille
# FST
# ROWLING
# J.K.
# ROWLING
# CASUAL
# Gray
# Mountain
# ROSIE
# uniain
# ray
# investment
# children's
# finance
# LEGO
# RADE
# lifestyle
# FILOFAX
# PARKER
# accessories
# accessories
# engui
# lifestyle
# times
# LEGO
# LEGO
# SRIM
# Chaeng
# KEEP
# CALM
# AND
# STAY
# COOL
# Love
# Life
# LIVE
# LIFE
# riding
# PEP
# YOU
# SMILE
# PERSON
# JOY
# BOOTH
# EXIT
# Payless
# SHOESOURCE
# JAVENUE
# FLIPBOOTH
# NEW
# TRADITION
# CELEBRATE
# for
# Admire
# for
# $12
# $20
# chrec
# STARBUCKS
# COFFEE
# Christmas
# Green
# Tea
# PROMOTION
# OPEN
# Perfume
# YOU
# SHION
# Avenue
# Girls'
# Generation
# meets
# Baby-G
# Baby-G
# McDonalds
# smiggle
# sale!
# Special
# DELUXE
# MASSIVE
# CLEARANCE
# SALE
# Moving
# adidas
# MENS
# FOOTWEAR
# MENS
# TRAINING
# BIOAPEX
# Cosmeccutical
# SCHOOL
# Apex
# BUSINESS
# Jurong
# East
# JobStreet
# Better
# Things
# For
# Life
# com
# Salary
# Matching
# OMG
# Easier
# Way
# Voted
# The
# JobStreet
# 506
# 183
# 183
# BERTH
# Welcome
# East
# The
# JTC
# Summit
# Toilet
# Bus
# Canteen
# 197
# sunflower
# sunflower
# TEL:
# 67782831
# Course
# Chinese
# Painting
# Coursi
# Tel:
# F&N
# Magnolia
# Choice
# BAN
# SOON
# SEWING
# MACHINE
# YEO
# TRADING
# Laundry
# CHOR
# HONG
# The
# Doctors
# HENG
# FURNITURE
# REDMAN
# Pain
# Back
# Foot
# Knee
# Your
# Stop
# Our
# Solution
# ASTER
# SPRING
# ORIGIN
# BEAUTY
# European H
# POST
# OFFICE
# ALAN
# GUYS
# NLB
# Public
# Library
# Clementi
# www
# ADU
# AUTHOR
# Faces
# AOJIEOJBAKAS
# Econometrics
# 330
# DEBUNKING
# ECONOMICS
# 330
# 122
# NLB
# Year
# Potential
# KEY
# Stretch
# Mind
# Stretching
# Courses
# Express
# Foodfore
# Foto
# EXIT
# Chartered
# Yellow
# Standard
# Chartered
# Foodfare
# auto
# OUT
# theft
# grand
# LOOKING
# KEPT
# SECRET
# BEST
# good
# union
# LD OF SPORTS
# one
# Feel
# Singtel
# WIN
# you
# ASUS
# SAMSUNG
# TABLETS
# SONY
# WIN
# 2198
# 299
# 769
# SAMSUNG
# 1249
# SAMSUNG
# 1098
# 199
# acer
# 2298
# 1398
# 1198
# 1998
# 1098
# 1398
# 2298
# 949
# 2198
# 7698
# 1Gbps
# ASUS
# ASUS
# 1249
# SAMSUNG
# GERATOR
# SON
# SHARP
# AQUOS
# MRBT
# ARP
# cache
# cache
# cache
# cocho
# cache
# JAPAN
# HOME
# POH
# HENG
# NEW
# BEST
# BUY
# $428
# $71
# GIORDANO
# SILVER
# COTTON
# JAY
# GEE
# CARD
# Members
# Get
# More
# GET
# YOUR
# $150
# VOUCHER
# mimosa
# SALE
# dENIZEN
# aurora
# CLEMENTI
# thank
# you
# for
# your
# patronage
# Clementi
# EW23
# Clementi
# drepublic
# ISLAND
# ADMISSIONS
# AND
# UNLIMITED
# PRIVILEGES!
# 25!
# ENJOY
# HERE
# SAMSUNG
# Do you Note?
# Kick
# The
# New
# Year
# Start
# off
# THE
# NEW
# EXPLOSIVE
# WIN
# Electrical
# GAME
# ost
# Sound
# Stadium
# Stadium
# Sound
# Stadium
# View
# View
# Stadium
# Stadium
# View
# Stadium
# Sound
# SESAME
# STREET
# BIRDS
# TRAIN
# DINOSAUR
# pason
# Any
# Any
# Any
# day.
# CENTRE
# MINIDRONES
# Parrot
# JOY
# SALE
# SALE
# STYLES
# SALE
# SALE
# ART
# ARTBOX
# Lobby
# LONG
# JohN
# SILVERS
# GIORDA
# ACCENT
# CANDLE
# Sasa
# Drop-off
# S ON
# WHERE
# WELCOME
# FRIENDS
# BEST
# HarbourFront
# VER
# VOLENDAM
# START
# 1600 MRS
# LOT
# AEROLINE
# HarbourFront
# $10
# PASTAMANIA!
# POH
# KIM
# LONG
# DAY
# FRENCH
# BREAD
# ALL
# SALE
# MID
# SALE
# RITZBO
# MID
# 2.35
# 2.50
# Bank
# OCBC
# Bank
# BREAKFAST
# Bank
# Hungry?
# biggie.
# BIG
# BREAKFAST
# GLITTER
# GLAM
# GLITTER
# GLAM
# nailz
# VINO
# Salon
# The
# Dressing
# Salon
# 2070
# SingTel
# ASUS
# SEARCH
# ASUS
# tech@vogue
# ASUS
# SMILE
# FAMILY
# tech@vogue
# ASUS
# ASUS
# $15
# Salads
# Serenity
# Rice
# Diskes
# Suckling
# Soups
# TEAM
# SALON
# AVEDA
# $15
# $15
# Dress
# Accessories
# Bottoms
# Tops
# S31
# $36
# $33
# $28
# ROUTE:
# ALTERNATE
# mins
# MAC
# ORIGINS
# CHANEL
# NEW
# YORK
# COA
# SALE
# STOREWIDE
# bpalette
# SuperdryStore.
# Superdry.
# lapalette
# GAP
# SALE
# brothers
# SALE
# SACOOR
# citing
# privileges
# CAUTION
# FLOOR
# VIVO
# VIVO
# city
# Find
# us!
# EXPERIENCE
# THE
# DREAM
# TRAIN
# RIDE@
# The
# House
# BURGERS
# Chop
# Xpressflower.com
# TOWN
# Garrett
# GOURMEE
# popcorn
# JAPANESE
# GOUR
# SPICY
# BVLGARI
# SALE
# BRENNER
# CHOCOLATE
# BAR
# MAX
# toss
# turn
# toss
# FULL-TIME
# PAR
# GHO
# CHA
# GONG
# SALE
# SALE
# SALE
# VIVOMART
# loVe
# free
# scan
# life
# chi
# spinal
# SPINAL
# SCAN
# Chiropractic:
# Live
# the
# life
# you'd
# love
# live.
# SALE
# SALE
# SALE
# SALE
# have
# TOP
# SHOP
# VIVO
# VIVL
# BEAR
# SAL
# PUE
# PULL
# WAREHOUSE
# ESPRIT
# DBS
# REHOUSE
# Calvin
# Calvin
# CITIGEMS
# EMPORIO
# TAG
# ARMANI
# MAKE
# SEIKO
# MAE
# MAK
# L'OCCITANE
# MAKE
# ORE
# ASTRON
# Lou
# Yau
# =B2-25
# Superdry.
# NovOpe
# Level1
# - #01
# asian
# ZTP
# KOI
# SNAFFLES
# SNAFFLES
# B2-K15
# week
# 1KG
# my4
# LOSE
# simple
# steps
# the
# delight
# here.
# 000
# UOB
# Joy
# Dare
# Comparel
# Compare!
# Flowers
# Cut
# VALUE
# BUY
# 4.20
# 3.15
# 3.15
# RAND
# LOW
# PRICES
# DAILY
# CUBES
# VALUE
# ICE
# CUBES
# CUBES
# FOR
# WALL'S
# WALL
# DRINKS
# ICE
# CUBES
# DHA
# Nature
# CRIME
# and
# Long-lasting
# Color
# improved
# creamy
# foam
# with
# AHITARGYM
# SHOP
# where
# people
# meet
# Massage
# Acupuncture
# Massotherapy
# Body
# Massage
# CHANGER
# MONEY
# CHAN
# OTO
# OTO
# Life
# ichiban
# boshi
# lehiban
# twelve
# cup
# handmade
# aucre
# BROWNIES
# LOAVES
# TARTS
# PARFAITS
# PUDDINGS
# PUSH
# WHOOPIES
# CITIGEMS
# CANDY
# EMPIRE
# TOASTBOX
# Standard
# ANK
# UOB
# DON
# DON
# prettyFIT
# BreadTalk
# VEIL
# mds
# VRG
# FRIENDS
# MAKE
# re           lles
# ETT
# CiTYLiNK
# AEROPOSTALE
# LAST
# DAY
# JEANS
# B  ATA
# CONNECTION
# EXIT
# BODY
# SHOP
# IT'S
# BIG
# THE
# SALE
# KISSJane
# fipper
# Feel
# the
# Rubber!
# outhaven
# ThaiExpress
# SALADSTOP!
# Square
# CiTYLiNK
# LOOK
# OUT
# FOR
# BRAND
# NEW
# RETAIL
# WING
# AND
# SHOPPING
# OPTIONS
# YOUR
# WAY
# SERV
# MORE
# SHOPPING
# SOUVENIRS
# HOME
# SALE
# GEOX
# Food
# Court
# (at
# Level
# crocs
# crocs
# SENNHEISER
# PLANET
# SENNHEISER
# fourskin
# EXIT
# Trying
# stuff
# Columbia
# RLD
# SPORTS
# EXIT
# EXIT
# SIMMONS
# PICKET
# RAIL
# fourskin
# Optics
# House
# Optics
# MEGASTORE
# CITY
# GAIN
# OUR
# STARBUCKS
# COFFEE
# STARB
# MORE
# MORE
# LEVEL2
# SHOPS
# SHOPS
# LEVEL2
# VIASS
# SUBWAY
# CITY
# EXIT
# LITTLE
# YDU
# TH S
# HOME-GROW
# JOHN
# LITTLE
# BOUTIQUE
# MARKS&
# SPENCER
# ST.MARC
# CAFE
# GKO
# victoria's
# SECRET
# SALE
# ALDO
# LDO
# PRESIOUS
# thots
# the
# ISONS
# sale
# 70%
# SECRET
# A'S
# WAREHOUS
# Hello
# 2015!
# $30
# off
# SALE
# MANY
# ITEMS
# 70%
# OFF
# TOPMAN
# COM
# mentos
# mentos
# mentos
# mentos
# mentos
# mentos
# mentos
# mentos
# mentos
# mento
# Shops
# ahead
# Esplanade
# Xchange
# Shop
# kate
# NEW
# YORK
# MARKETPLACE
# 50%
# OFF
# MARKET
# VITALITY
# COURT
# PODI
# ANE
# swatch
# ROBINSONS
# SALE
# SAKAE
# SUSHI
# ALL
# BLOUSES
# $1990
# sant
# DBS
# Giant
# TOAST
# food
# foodrepublic
# TOWN
# ONSEN
# 01-06
# OSEN
# RALPH
# LAUREN
# LAUREN
# adidas
# CANS
# PLASTIC
# don't
# just
# run.
# glide
# our
# potential
# with
# motherswork
# minds
# DISCOVER
# MORE
# notherswork
# motherswork
# DISCOVER
# MORE
# crocs
# PORE!
# EXIT
# THE
# BAY
# Bleem
# crocs
# adidas
# don't
# just
# Dior
# ARM
# LOOKED
# HOT
# Colum
# MINX
# JACKET
# ENHANCED
# LIKE
# DOWN
# DOWN
# STEROIDS
# BUT
# IT'S
# LEGAL
# SEPHORA
# CATS
# EXIT
# MASTER
# CARD
# THEATRES
# BOX
# OFFICE
# PANDORA
# COACH
# PORSCHE
# SKATING
# HOTEL
# SKYPARK
# CASINO
# HOTEL
# COACH
# TERMINAL
# PRADA
# PRADA
# LOUIS
# VUITTON
# VUITTON
# LOUIS
# TERMINAL
# PRADA
# CASINO
# HOTEL
# PRADA
# COACH
# PRADA
# BVLGA
# VERSACE
# VERSACE
# ONE
# MAN
# ONE
# MACHINE
# GUCCI
# GUCCI
# GUCCI
# LEVEL
# OPI
# ZARA
# TANG
# roberto
# cavalli
# ZARA
# SHANGHAI
# ACTION
# Hair
# ISIS
# Doc
# SHOPPES
# THE
# MORE
# DISCOVER
# MARINA
# San
# INGAPO
# HOTTIS
# Bon
# Appetit!
# CRATE
# CREAM
# THE
# ICE
# Quick
# BIG
# CHA
# JIXIANG
# ZHAI
# BLUM
# Co.
# TOKYO
# OPTICAL
# STA
# SUSHI
# Healthy
# Fresh
# Delicious
# HOPE
# SANDS
# BAY
# MARINA
# A-T
# SHOPPES
# THE
# CHANEL
# COURT
# RESTAURANTS
# BRITY
# RESTAURANTS
# FOOD
# CASINO
# GUY
# HALANA
# Dior
# THE
# VINCI:
# CATS
# SHAPING
# FUTURE
# GUCCI
# GUCCI
# GUCCI
# GARDENS
# THE
# HUBLOT
# HUBLOT
# AED
# HUBL
# MARDIN
# MONDIAL
# SIQUEEN
# FOSSIL
# STEVE
# MADDEN
# CCI
# CONVENTION
# OMEGA
# OMEGA
# SALE
# MADDEN
# JIMMY
# STEVE
# FOSSIL
# GUCCI
# Juicy
# GUESS
# GUCCI
# 50%
# OFF
# BANANA
# REPUBLIC
# GUESS
# swatc
# BANANA
# FOSSIL
# STEVE
# QUEEN
# SALE
# CHARLES
# ROYAL
# SELANGOR
# Way
# out
# Ean
# System
# map
# City
# Dine
# Esplanade
# Hall
# The
# Dine
# smrt
# iae
# Shop
# FLIGHT
# $1.50
# BLOUSES
# ALL
# ant
# DOCKER
# CONNECTION
# dENiZEN
# dENiZEN
# SALE
# OFF
# SAL
# CITYLINK
# TOPS
# 19.90
# shu
# shu
# shu
# shu
# shu
# uemura
# shu
# shu
# shu
# shu
# shu
# SALE
# TOPSHOP
# EXIT
# TOPSHOP
# ZARA
# LOBBY A
# TOPSHOP
# TOPMAN
# TOPSHOP
# Dior
# (I)
# GEOX
# SALE
# MORE
# SHOPS
# GEIGER
# KURT
# LONDON
# ZARA
# ZARA
# ZARA
# ZALORA
# DIGITAL
# off
# OFFLINE
# FOSSI
# DIGITAL
# SHOPPING
# SHOP
# WITH
# FOSSIC
# tcc
# Pull
# and
# Bear
# tcc
# promod
# SALE
# NOW!
# Enjoyd
# 7698
# EXIT
# shka
# LOBBY
# PATERSON
# VICTORIA'S
# SKE
# EXIT
# KASE
# strad
# STEVE
# MADDEN
# ALDO
# ALDO
# WHEELOCK
# PLACE
# LDO
# PLACE
# Calvin
# Klein
# Calvin
# Klein
# underwear
# stradivarius
# MAN
# THIS
# 510
# 511
# 513
# 504
# 505
# LEVI'S
# LIVE
# THIS
# CHINESE
# NEW
# S10
# 511
# 513
# 505
# 504
# LEVI'S
# LEVI'S
# 501
# Accessorize
# LOVE
# SALE
# SALE
# SALE
# promod
# NOW!
# -70%
# EXIT
# B1/B3
# ZARA
# TOPSHOP
# UNIQLO
# ZALORA
# LORA
# SALE
# SALE
# SALE
# sale
# sale
# SALE
# sale
# SALE
# SALE
# sale
# SALE
# SALE
# sale
# sale
# SALE
# ALE
# SAL
# ALE
# SAL
# SALE
# ale
# ALE
# ZARA
# LOBBY
# UNIQLO
# TOPSHOP
# KURT
# GEIGER
# LONDON
# GEIGERS
# KURT
# GEIGER
# Dior
# 1/2
# price
# sale
# shu
# shu
# shu
# ODY
# SALE
# EXIT
# UNI
# QLO
# THE
# BODY
# SHOP
# B2-40/41
# SALE
# IT'S
# BIG
# AND
# IT'S
# SALE
# uemura
# AMERICAN
# EXPRESS
# ARMANI
# EXCHANGE
# G-STAR
# CALVIN
# KLEIN
# JEANS
# BREAD
# BUTTER
# TRUE
# SALE
# MOLESKINE
# MOLESKINE
# SALE
# EXIT
# SWAROVSKI
# SWAROVSKI
# ORCHARD
# HAT
# ORCHARD
# MRT
# Ion
# PATERSON
# LINK
# WAREHOUSE
# SALE
# SALE
# FOREVER
# SHOP
# FOREVER
# citibank
# EXIT
# G-STAR
# CALVIN
# KLEIN
# JEANS
# OFF
# SINGA
# C  MPER
# LOVE
# NEW
# OPENIN
# I O N
# INGAPORE
# URAL
# ORCHARD
# SALES
# REBAJAS
# SOLDES
# ZNIZANJE
# UTA
# LOBBY
# G-STAR
# ARMANI
# EXCHANGE
# Ion
# G-STAR
# DIRECTORY
# EVISU
# BREAD
# BUTTER
# JBRAND
# John
# TENRY
# Blue
# JOE'S
# DENHAM
# KURO
# The
# Strike
# Prps
# HYDROGEN
# REPLAY
# REBAJAS
# SAL
# RASPRODA
# SWAROVS
# SHOPS
# L1/L2/L3/L4
# ORCHARD
# MRT
# MORE
# Samantha
# Thai
# Thava
# L1/L2/L3
# Samantha
# Thave
# SEPHORA
# SEPHORA
# FFICINE
# PANERAI
# miu
# miu
# OFFICINE
# PANERAI
# PANE
# OFFICINE
# BARTOUX
# F. NIELLY
# TAGHeuer
# BAR
# GALERIES
# EXIT
# BARTOUX
# MaxMara
# BOTTEGA
# VENETA
# BOTTEGA
# VENETA
# SEPHORA
# Cartier
# GIORGIO
# miu
# miu
# GIORGIO
# IWC
# VACHERON
# CONSTANTIN
# #02-07
# CHAUMET
# EXIT
# HARRY
# WINSTON
# LOUIS
# VUITTON
# PRADA
# Dior
# DOLCE
# GABBANA
# FURLA
# Ion
# FURLA
# FURLA
# EXIT
# PHILIP
# kate
# spade
# PHILIP
# STEIN
# GIVE
# LOVE
# Barret
# MERCI
# USE
# MAIN
# ENTRANCE
# MARC
# EXIT
# Alice
# BLENHEIM
# AVENUE
# NHEIM
# NUE
# LONDON
# Alice
# and
# Olivia
# stacey
# bendet
# Sale
# OFF
# Alice
# Pols
# SINGAPORE
# AIRLINES
# HAIR
# ATELIER
# Ion
# ART
# Ion
# Salt
# Grill
# Crate
# Barrel
# OAKS
# Health
# Beauty
# Naturally
# vom
# FASS
# EXIT
# PROOF
# LEVEL
# Ion
# SKINC
# LAB
# SERIES
# GRINGARE
# FOR
# Ion
# SEMI-ANNUAL
# OFF
# SECRET
# SALE
# KIKKI.K
# ORCHARD
# EXIT
# LOBBY
# TAXI
# ION
# with
# Global
# Link
# count
# CASIO
# all
# across
# Link
# ticketing
# SIM
# cards
# changing
# CLOSED
# inl
# pass
# and
# connected
# just
# Marina
# Bay
# Marina
# ong
# East
# will
# end
# half
# hour
# earlier
# Sookee
# PAVILLION
# Ion
# LOBBY
# ORCHARD
# JEWELLERY
# STREET
# SINGPOST
# Ion
# Ion
# BreadTalk
# CHARLES
# KEITH
# SALE
# Eli
# EXIT
# Talk
# BreadTalk
# ON:SAL
# ON SALE
# Talk
# Talk
# EXIT
# TOASTBOX
# BreadTalk
# GRAPHICS
# TEES
# FOR
# COTTON
# EXIT
# SECRET
# SALE
# SALE
# lock
# SALE
# SALE
# SALE
# REBATE
# Bank
# OCBC
# JOSE
# EBER
# YEAR
# STORES
# Garrett
# THEFACESHO
# Limited
# Eddition
# CALENDAR
# COLLECT
# Limited
# Edition
# MONTHLY
# CALENDAR
# POSTER
# COLLECT
# HOLLAND
# EXIT
# Sasa
# MAKE-UP
# THE
# SKIn
# STUDIO
# SETAN
# Grand
# ALE
# H2O
# h2o
# Hollk
# Grand
# SALE
# SALE
# Grand
# Anniversary
# Grand
# Anniversary
# SALE
# SALE
# SALE
# SALE
# Grand
# Grand
# SALE
# SALE
# SALE
# Grand
# Grand
# Anniversary
# SALE
# SALE
# Evottica
# 149
# nanoflex
# TOUCH
# MANGO
# TOUCH
# BLACKCLOSE
# collectpoint
# SALE
# SALE
# BLACKCLOSE
# collectpoint
# SAL
# SALE
# Grand
# Grand
# Anniversary
# Anniversary
# SALE
# SALE
# colectpoint
# SALE
# SALE
# OFF
# SALE
# SIS
# SPA
# CEYLON
# DOROT
# SAL
# CEYLON
# SPA
# LUXURY
# AYURVEDA
# Sookee
# REVER
# NEW
# SALE
# ERN
# WATCH
# EXIT
# ZARA
# Blush!
# bread
# Freshly
# baked
# crunchy
# Specials
# Garlic
# course
# below
# ZERO
# SPOT
# 100%
# CARE
# Zero
# Spot
# Laundry
# 6852
# 1771
# www.zerospot.com
# period
# HEIGHT
# LIMIT
# MAX.
# min
# 1.7m
# Grace
# MORE
# OTS
# ENTRANCE
# MORRIS
# ROBIN
# SAL
# ROBINSO
# ROBINSONS
# SALE
# TEP
# OUND
# YEAR
# OCBC
# SALE
# ROBINSONS
# EBA
# ALL
# YEAR
# ROUND
# BRANDS
# OCBC
# Bank
# SALE
# SALE
# SALE
# SALE
# OFF
# SALE
# SALE
# LANCOME
# shu
# SALE
# Dior
# SALE
# Dior
# EVA
# FORMULA
# DIAGNOSIS
# 257
# POSSIBLE
# TECHNOLOGICAL
# FORMULAS
# UNIQUE
# SKINCARE
# FOR
# ioma
# CREME
# SALE
# SELLERS
# HERMES
# HERMES
# RETAIL
# THAN
# THRILLS
# OVER
# OCBC
# ROBINSONS
# GROUP
# VISA
# CARD
# ANY
# launch
# arrival
# EXIT
# SALE
# THAN
# ANY
# REBATE
# MORE
# STORES
# ENJOY
# OTHER
# CARD
# RETAIL
# BRANDS
# ILLS
# SALE
# EBATE
# HERE
# ALL
# YEAR
# ROUND
# HEBE
# WORTH
# WAITING
# FOR
# SALE
# THE
# HERE
# OCBC
# ALL
# ROUND
# SALE
# Ban
# YELLOW
# KORNER
# PARIS
# Chloe
# LOVE
# STORY
# Chloe
# TOPMAN
# BROOKS
# SAL
# SALE
# ITE
# PBOTHERS
# TOPSHOP
# SALE
# SALE
# MANY
# MARKS
# SPENCER
# sale
# sale
# $100
# OFF!
# Alexis
# METRO
# MARKS
# OFF
# sale
# MAKE
# STORE
# Klein
# coast
# LONDON
# 70%
# SALE
# ALDO
# WAREHOUSE
# SALE
# PIANO
# KAWAI
# MUSIC
# SCHOOL
# SUS
# SUSHI
# TEI
# I.MAGES
# CHINA
# Commune
# ACTION
# Salon
# ELEVEn
# ASAGAO
# MINIMART
# Kiri
# TEA
# TEA
# SingTel
# Prepaid
# Cards
# sold
# here!
# SingTel
# EXIT
# SingTel
# GOLDEN
# SUN
# CALIFORNIA
# Available
# here!
# SingTel
# sold
# LOVE
# MAIDS
# EXIT
# MATAHARI
# UcNo:12C6009
# Attention!
# FILIPIN
# DOMES
# HELPE
# SALARY
# WORK
# EMPLOYMENT
# AGENCY
# KONG
# Licence
# SING
# No:
# 03C5262
# MAIDS
# INDONESIAN
# DEVELOPMENT
# DOCUMENTATION
# 6825
# LATINA
# L'OREAL
# $ 15
# PROFESSIONNEL
# sms
# Waxing
# #04-29
# $30
# one
# METRO
# STRO
# Price
# LOWEST
# PRICES!!
# DUTY
# FREE
# PERFUMES
# Scent
# Dollars
# Scent
# EXPLOSIVE
# FANTASTIC
# DISCOUNTS!!
# Massive
# Savings!!
# SingTel
# Prepaid
# Cards
# Tel.
# no.:
# ( +65) 6732 2900
# PHILOXENOS
# Venice
# for
# Nut
# Assorted
# $10
# BEST
# Chocolate
# CHOICE
# TRADING
# FIRST
# FACTORY
# PRICE
# YEAR
# END
# SALE
# FILIPINO
# Nut
# Chocolate
# Assorted
# for
# for
# PTE
# KABAYAN
# 02-25
# KABAYAN
# FILIPINO
# LTD
# PTE
# RESTAURANT
# LTD
# FILIPINO
# YAN
# LTD
# PTE
# RANT
# RESTAURANT
# KABAYAN
# FILIPINO
# RESTAURANT
# PTE
# LTD
# FILIPINO
# KABAYAN
# RESTAURANT
# COUNTER/KITCHEN
# ASSISTANT
# WANTED:
# WANTED;
# REMITTANCE
# 03-26
# CLERK
# ATTED
# sexy
# 7380921
# THE
# GIFT
# SHOP
# ing
# Amor
# NOY
# EXPRESS
# 02-46
# S.K
# EXIT
# $10
# S.K.
# LEATHER
# HOUSE
# ALTERATION
# SERVICES
# $10
# $10
# HAPPY
# Phoenix
# #02-81
# 02-59
# Available
# Foot
# vices
# GLOBAL
# TRAVE
# JMG
# AYAM
# RIA
# SMASHED
# FRIED
# CHICKEN
# SINCE
# 1890
# Miguel
# EXCELLENCE
# SALE
# ING
# BIG
# GREAT
# SALON
# SALE
# MATCH
# for
# UTY
# SHOP
# SHOP
# Hair
# salon
# BARBER
# TIP
# TOP
# JOY
# Delicacies
# seafood
# For
# Your
# VISA
# Higest
# Price
# NETS
# Offers
# NETS
# Gold
# Items
# Based
# Daily
# Gold
# Rates
# GOLDENLAND
# WATCH
# SingTel
# Remit
# Start
# your
# account
# at:
# #01-26/27
# HanGTen
# ASIAN
# 1000
# CANS
# TRAS
# RECYCLE
# LASTIC
# ANS
# HERE
# ION
# sensitiv
# Spring
# Water
# Thermal
# natural
# Avente
# active
# efficacy
# Proven
# for
# BODY
# SHOP
# 01-62
# THE
# FREE
# NEW
# LOCATION
# NEW
# Green
# Life
# Shaklee
# rage
# SALE
# 50%
# FREE
# Storage
# people
# The
# fresh
# food
# Cold
# CHEESE
# New
# Make
# Own
# BAKERY
# 100
# 100
# CHEESE
# THE
# MONTH
# WINES
# WIN
# WIN
# THE
# MONTH
# SUSH
# WINES
# WIN
# WIN
# WIN
# SUSHI
# SEAFOOD
# Our
# Choice
# MILO
# NESCAFE
# STARS
# 100
# FRESHLY
# MADE
# SALAD
# MEAT
# SEAFOOD
# SUSHI
# RECIPES
# Herbs
# Spices
# RECIPES
# PEPERO
# LOTTE
# GET
# MILO
# PEPERO
# KitKat
# FREE
# MISTER
# MINIT
# CITY
# CHANGER
# MONEY
# THE
# LAUNDRY
# CHANGER
# BEST
# CLUB
# Weddings
# orchardcentral
# NANYANG
# OLD
# COFFEE
# shea
# B2-A7
# BAKING
# SOON
# BAKING
# SOON
# and
# FRUITY
# TREATS
# Beer
# Beers
# Ciders
# DESSERT
# CCO
# PLATED
# DESSERT
# TARTS
# Gus
# FNE
# MACCHA
# HOUSE
# NDS
# Beauty's
# Beginning
# NDS
# SIDE
# LABEL
# YOURSELF
# CREATIVE
# TOKYU
# HANDS
# KILLNEY
# BOAD
# ORCHARD
# ROAD
# lifts
# serve
# L10.
# Access
# Levels
# please
# transfer
# Levels
# B2/1/4/7/9
# case
# approach
# concierge
# Level
# orse
# not
# use
# lift.
# B-One
# The
# Med
# The
# Carpark
# Ramp
# Exchange
# The
# Indulge
# The
# Runway
# Indulge
# The
# Runway
# Indulge
# Discovery
# Walk
# B-One
# The
# Med
# Med
# L12
# L11
# L10
# Access
# all
# floors.
# please
# transfer
# Level
# Roof
# Garden
# Roof
# Garden
# Carpark
# Verandah
# Carpark
# Verandah
# Carpark
# The
# Ramp
# Carpark
# LEVEL
# AMKISOKI
# THE
# EXCEPTIONAL
# QUALITY
# SYEARS
# VERANDAH
# RAMEN
# CHAMPION
# NANTSUTTE
# SINGAPORE
# 5YEARS
# RAMEN
# TON
# Garden
# This
# Lift
# LOBBY
# L12
# Serves
# #12-02
# BEER
# SOMA
# korean
# BBQ
# buffet
# cook
# HOT
# STUFF
# STYLE
# MMA
# SOMA
# SOMA
# EVOLVE
# MIXED
# GOWN
# GOWNS
# STARA
# BR  AL
# BRIDAL
# STARA
# BRIDAL
# GOWNS
# PROMOTION!!
# SALES
# 20%
# HOM
# YOGA
# Reebok
# CAMELBAK
# GOT
# YOUR
# OGIO
# speedo
# mps
# ONE
# ar.
# play
# exclusives
# gest

# %%
train_config_copy.loader
# Out:
# {'type': 'DataLoader',
#  'batch_size': 16,
#  'shuffle': True,
#  'num_workers': 1,
#  'collate_fn': {'type': 'RecCollateFn',
#   'img_w': 120,
#   'dataset': <__main__.RecTextLineDataset at 0x7f1060adac90>}}

# %%
train_dataloader_type = 'DataLoader'
train_collate_fn_dict = {'type': 'RecCollateFn', 'img_w': 120}
train_collate_fn_type = 'RecCollateFn'

# %%
train_config_copy.loader.collate_fn['dataset'] = train_dataset

# %%
train_config_copy.loader
# Out:
# {'type': 'DataLoader',
#  'batch_size': 16,
#  'shuffle': True,
#  'num_workers': 1,
#  'collate_fn': {'type': 'RecCollateFn',
#   'img_w': 120,
#   'dataset': <__main__.RecTextLineDataset at 0x7f10462f2c10>}}

# %%
train_collate_fn = RecCollateFn(**(train_config_copy.loader.collate_fn))

# %%
type(train_collate_fn)
train_config_copy.loader
# Out:
# {'type': 'DataLoader',
#  'batch_size': 16,
#  'shuffle': True,
#  'num_workers': 1,
#  'collate_fn': {'type': 'RecCollateFn',
#   'img_w': 120,
#   'dataset': <__main__.RecTextLineDataset at 0x7f10462f2c10>}}

# %%
train_dataloader = DataLoader(dataset=train_dataset, batch_size = 2, shuffle = True, num_workers = 2)

# %%
dataiter = iter(train_dataloader)

# %%
type(train_dataloader)
# Out:
# torch.utils.data.dataloader.DataLoader

# %%
next(dataiter)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-180-4c6a08307c0a> in <module>()
# ----> 1 next(dataiter)
#
# /home/elimen/anaconda3/envs/pytorch/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     433         if self._sampler_iter is None:
#     434             self._reset()
# --> 435         data = self._next_data()
#     436         self._num_yielded += 1
#     437         if self._dataset_kind == _DatasetKind.Iterable and \
#
# /home/elimen/anaconda3/envs/pytorch/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1083             else:
#    1084                 del self._task_info[idx]
# -> 1085                 return self._process_data(data)
#    1086
#    1087     def _try_put_index(self):
#
# /home/elimen/anaconda3/envs/pytorch/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _process_data(self, data)
#    1109         self._try_put_index()
#    1110         if isinstance(data, ExceptionWrapper):
# -> 1111             data.reraise()
#    1112         return data
#    1113
#
# /home/elimen/anaconda3/envs/pytorch/lib/python3.7/site-packages/torch/_utils.py in reraise(self)
#     426             # have message field
#     427             raise self.exc_type(message=msg)
# --> 428         raise self.exc_type(msg)
#     429
#     430
#
# RuntimeError: Caught RuntimeError in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "/home/elimen/anaconda3/envs/pytorch/lib/python3.7/site-packages/torch/utils/data/_utils/worker.py", line 198, in _worker_loop
#     data = fetcher.fetch(index)
#   File "/home/elimen/anaconda3/envs/pytorch/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py", line 47, in fetch
#     return self.collate_fn(data)
#   File "/home/elimen/anaconda3/envs/pytorch/lib/python3.7/site-packages/torch/utils/data/_utils/collate.py", line 73, in default_collate
#     return {key: default_collate([d[key] for d in batch]) for key in elem}
#   File "/home/elimen/anaconda3/envs/pytorch/lib/python3.7/site-packages/torch/utils/data/_utils/collate.py", line 73, in <dictcomp>
#     return {key: default_collate([d[key] for d in batch]) for key in elem}
#   File "/home/elimen/anaconda3/envs/pytorch/lib/python3.7/site-packages/torch/utils/data/_utils/collate.py", line 63, in default_collate
#     return default_collate([torch.as_tensor(b) for b in batch])
#   File "/home/elimen/anaconda3/envs/pytorch/lib/python3.7/site-packages/torch/utils/data/_utils/collate.py", line 55, in default_collate
#     return torch.stack(batch, 0, out=out)
# RuntimeError: stack expects each tensor to be equal size, but got [16, 72, 3] at entry 0 and [20, 46, 3] at entry 1

# %%
label_list=[]
dirpath = "/home/elimen/Data/OCR_dataset"
with open("/home/elimen/Data/OCR_dataset/icdar2015/recognition/train_bak.txt", 'r', encoding='utf-8') as f_reader:
    for m_line in f_reader.readlines():
        params = m_line.strip().split('\t')
        if len(params) == 3:
            m_image_name, m_gt_text, _ = params
            path_split = m_image_name.split('\\')[2:]
            path = ''
            for s in path_split:
                path = os.path.join(path,s)
            img_path = os.path.join(dirpath,path)
            label = img_path + "\t" + m_gt_text
            label_list.append(label)
        else:
            print("Wrong content:{}".format(params))

# %%
with open("train.txt","w") as f_writer:
    for i in range(len(label_list)):
        f_writer.writelines(label_list[i]+"\n")

# %%
label_list=[]
dirpath = "/home/elimen/Data/OCR_dataset"
with open("/home/elimen/Data/OCR_dataset/icdar2015/recognition/test_bak.txt", 'r', encoding='utf-8') as f_reader:
    for m_line in f_reader.readlines():
        params = m_line.strip().split('\t')
        if len(params) == 3:
            m_image_name, m_gt_text, _ = params
            path_split = m_image_name.split('\\')[2:]
            path = ''
            for s in path_split:
                path = os.path.join(path,s)
            img_path = os.path.join(dirpath,path)
            label = img_path + "\t" + m_gt_text
            label_list.append(label)
        else:
            print("Wrong content:{}".format(params))

# %%
with open("eval.txt","w") as f_writer:
    for i in range(len(label_list)):
        f_writer.writelines(label_list[i]+"\n")

# %%
import json
with open('/home/elimen/Data/OCR_dataset/synthetic_digit/labels.json', 'r') as f_json:
    content = f_json.read()
digitimg_dict = json.loads(content)
digitimg_dict['labels']
# Out:
# {'000000000': ',580,368.722,',
#  '000000001': ',724,282.336,',
#  '000000002': ',945.608,012,',
#  '000000003': '3,856,048.814',
#  '000000004': ',232,981,268.',
#  '000000005': '42,346.461,11',
#  '000000006': '9.646,629,956',
#  '000000007': '75,240,443,83',
#  '000000008': '9,375,392.397',
#  '000000009': '05,112,130,96',
#  '000000010': '61,653,981.73',
#  '000000011': '26.428,765,58',
#  '000000012': '717,692,038,1',
#  '000000013': '51.419,846,58',
#  '000000014': '.607,746,369,',
#  '000000015': ',572.948,725,',
#  '000000016': '.508,037,705,',
#  '000000017': '3306,790,159.',
#  '000000018': '2,377.691,569',
#  '000000019': '9418,899,237.',
#  '000000020': '508,037,705,4',
#  '000000021': ',203.331,573,',
#  '000000022': ',895,980.357,',
#  '000000023': '0,117,306.657',
#  '000000024': '6,465,362,910',
#  '000000025': '2,312.846,929',
#  '000000026': '409,973.619,0',
#  '000000027': '978,115,340,7',
#  '000000028': '98,779,464.67',
#  '000000029': '78,504,087.65',
#  '000000030': ',314,224.8480',
#  '000000031': '214,979,835.3',
#  '000000032': ',751.766,667,',
#  '000000033': '542,818,842.7',
#  '000000034': ',395.307,559,',
#  '000000035': '093,618.087,0',
#  '000000036': '6,107,243,259',
#  '000000037': '82,724,282.33',
#  '000000038': '49,951,334,08',
#  '000000039': '.602,748,551,',
#  '000000040': '670.326,481,2',
#  '000000041': '41,497,217,00',
#  '000000042': '40.386,308,89',
#  '000000043': '50.955,277,65',
#  '000000044': '60,558.523,24',
#  '000000045': '667.904,159,0',
#  '000000046': '231,024,379,7',
#  '000000047': '388.172,728,5',
#  '000000048': '612,467,748,0',
#  '000000049': '4,713,536,993',
#  '000000050': '47,472.733,02',
#  '000000051': '856,637,539,9',
#  '000000052': '196,789,117,1',
#  '000000053': '3,641.779,123',
#  '000000054': '38,972,482,24',
#  '000000055': '.757,015,947,',
#  '000000056': '2,891,234,935',
#  '000000057': '243.729,123,0',
#  '000000058': ',936,637,337.',
#  '000000059': ',366,466,748.',
#  '000000060': '69,914,963.97',
#  '000000061': '566.49160,647',
#  '000000062': '51,194.818,64',
#  '000000063': '4.106,143,690',
#  '000000064': ',122,626.541,',
#  '000000065': '73.171,268,87',
#  '000000066': '989,741,395.3',
#  '000000067': ',275,966.619,',
#  '000000068': ',490,771.988,',
#  '000000069': '81,011,909,25',
#  '000000070': '05,156.363,18',
#  '000000071': '.341,483,856,',
#  '000000072': '4,473,931,627',
#  '000000073': ',408.926,640,',
#  '000000074': '09,738,208.99',
#  '000000075': '461,605,074.2',
#  '000000076': '21.907,001,79',
#  '000000077': '626.541,235,5',
#  '000000078': '.609,913,872,',
#  '000000079': '955,509,669,5',
#  '000000080': '23929,472,984',
#  '000000081': '4,979,835.301',
#  '000000082': '0.11164,990,9',
#  '000000083': '821,696,411.3',
#  '000000084': '707,828.251,5',
#  '000000085': '50267,143,442',
#  '000000086': '860,558.523,2',
#  '000000087': ',907,813,875.',
#  '000000088': '807,318,230,6',
#  '000000089': '.584,337,136,',
#  '000000090': '70,751,935.09',
#  '000000091': '67,437.916,77',
#  '000000092': '862,841,785,8',
#  '000000093': '08,639,978.19',
#  '000000094': '.049,488,999,',
#  '000000095': ',734,253.587,',
#  '000000096': '34,506,611,39',
#  '000000097': '66,767,334,14',
#  '000000098': '3,587,482.199',
#  '000000099': ',721,449,374.',
#  '000000100': '45.608,012,87',
#  '000000101': '69,410,167.57',
#  '000000102': '8.02140,880,0',
#  '000000103': '.294,938,435,',
#  '000000104': '94,203,255.86',
#  '000000105': '018.779,984,2',
#  '000000106': '214,910,408,4',
#  '000000107': '150.747,397,8',
#  '000000108': '60.004,635,80',
#  '000000109': '15,022.472,72',
#  '000000110': '8.471,044,128',
#  '000000111': '.235,154,408,',
#  '000000112': ',886,680.189,',
#  '000000113': '22,830.393,49',
#  '000000114': '4,540,829.692',
#  '000000115': ',899,237.041,',
#  '000000116': '82,677,451.19',
#  '000000117': '337.171,606,3',
#  '000000118': '8,197,105,801',
#  '000000119': '.484,208,707,',
#  '000000120': ',422,486.413,',
#  '000000121': ',068,827.528,',
#  '000000122': ',138,891.609,',
#  '000000123': '.442,703,138,',
#  '000000124': '23,041,039.56',
#  '000000125': ',804.91179,91',
#  '000000126': '5,355,126,595',
#  '000000127': '89,085,262,07',
#  '000000128': '729,653,677,0',
#  '000000129': '84,017,315.85',
#  '000000130': '5.41966,508,8',
#  '000000131': ',309.599,401,',
#  '000000132': '39,275,263,38',
#  '000000133': '1,327,765.421',
#  '000000134': '4,998,563.759',
#  '000000135': '2,391,663.633',
#  '000000136': '08,722,422,34',
#  '000000137': '11,605,586,18',
#  '000000138': '9,085,262,077',
#  '000000139': '82,335,417,16',
#  '000000140': '17526,982,604',
#  '000000141': '251,975.971,5',
#  '000000142': '75,025.234,52',
#  '000000143': '26,814.474,82',
#  '000000144': '7,664,874,158',
#  '000000145': '709,514.8866,',
#  '000000146': '1,696,036.201',
#  '000000147': '287,510,487,6',
#  '000000148': '774,248,232,8',
#  '000000149': '171,689,388,9',
#  '000000150': '843,379,306.2',
#  '000000151': '8.589,085,262',
#  '000000152': '003,929,375,3',
#  '000000153': '361,281.027,5',
#  '000000154': '141,045,247,1',
#  '000000155': ',372,619,658.',
#  '000000156': '24,570,174.16',
#  '000000157': '4,976,703,527',
#  '000000158': '90,771.988,00',
#  '000000159': '4,737.462,913',
#  '000000160': '0.884,481,209',
#  '000000161': '99,941.734,11',
#  '000000162': '65,518,250,10',
#  '000000163': ',946,063,131.',
#  '000000164': '39,802,441,59',
#  '000000165': '2.234,398,132',
#  '000000166': '61,026,558.62',
#  '000000167': '9,903,765.505',
#  '000000168': '71792,135,531',
#  '000000169': ',063,583.717,',
#  '000000170': '859,864,571,1',
#  '000000171': '76,507,386.68',
#  '000000172': '87,828,136.66',
#  '000000173': '570,174.169,0',
#  '000000174': '9,530,398,634',
#  '000000175': '27.251,839,90',
#  '000000176': '9,002,269,700',
#  '000000177': '.069,116,699,',
#  '000000178': ',752.192,891,',
#  '000000179': '473.796,211,0',
#  '000000180': ',062.014,754,',
#  '000000181': '.252,614,278,',
#  '000000182': '73,928,506.83',
#  '000000183': '61,281.027,54',
#  '000000184': '7,215,585.077',
#  '000000185': ',736.134,021,',
#  '000000186': '759,993,312,9',
#  '000000187': '309,738,208.9',
#  '000000188': '9,512,799,941',
#  '000000189': ',997,437,910.',
#  '000000190': '1,830,508.318',
#  '000000191': '309,047.444,5',
#  '000000192': '4,540,075.461',
#  '000000193': '8,827.528,865',
#  '000000194': '46,190,459,78',
#  '000000195': '9,565,132.128',
#  '000000196': '862.355,339,8',
#  '000000197': '867,719,664.1',
#  '000000198': '82,138,700,05',
#  '000000199': '9,361.915,534',
#  '000000200': '6,859,208,074',
#  '000000201': '117,306.657,7',
#  '000000202': ',619,952.3653',
#  '000000203': '.895,355,126,',
#  '000000204': '73,627,948,82',
#  '000000205': ',042,159.171,',
#  '000000206': '1.419,846,580',
#  '000000207': '14,224.84808,',
#  '000000208': '6,077,177.202',
#  '000000209': '26.479,388,38',
#  '000000210': '.348,098,510,',
#  '000000211': '962,402.247,4',
#  '000000212': '1.555,775,146',
#  '000000213': '534,506,611,3',
#  '000000214': '39,126,992.22',
#  '000000215': '189,537,006.7',
#  '000000216': '72.895,355,12',
#  '000000217': ',164,471.783,',
#  '000000218': ',952,127.671,',
#  '000000219': ',460,939,525.',
#  '000000220': '770.18611,831',
#  '000000221': ',581,469,768.',
#  '000000222': '69,584.54681,',
#  '000000223': '52,782.469,00',
#  '000000224': '0,599.966,272',
#  '000000225': '18,641,058,05',
#  '000000226': '63.261,328,18',
#  '000000227': ',525.76401,14',
#  '000000228': ',337,718,737.',
#  '000000229': '867,617.884,4',
#  '000000230': '7,678.294,938',
#  '000000231': '22,952,127.67',
#  '000000232': ',389.865,207,',
#  '000000233': '9,183.711,501',
#  '000000234': '526,097,756,6',
#  '000000235': '799,351,591,0',
#  '000000236': '21,846,464,10',
#  '000000237': '64.809,435,08',
#  '000000238': '3.576,962,478',
#  '000000239': ',843.385,915,',
#  '000000240': ',501,443,321.',
#  '000000241': '68.652,333,18',
#  '000000242': ',426.622,589,',
#  '000000243': '6,946,063,131',
#  '000000244': '401,892,016,7',
#  '000000245': '141,045,247,1',
#  '000000246': '604.532,713,9',
#  '000000247': '98.733,933,50',
#  '000000248': '935.152,833,1',
#  '000000249': '218,019,011,8',
#  '000000250': '254,249,323,3',
#  '000000251': '7,854,930,303',
#  '000000252': '2,589,941,439',
#  '000000253': '40879,834,743',
#  '000000254': '4,909,647,192',
#  '000000255': '6,238,931.966',
#  '000000256': ',228,826,814.',
#  '000000257': '9,719.334,165',
#  '000000258': ',337,906.304,',
#  '000000259': '27,759.29888,',
#  '000000260': ',883,742,519.',
#  '000000261': '.239,489,564,',
#  '000000262': '997,298,779,4',
#  '000000263': '838,609.839,8',
#  '000000264': '78,051,974.46',
#  '000000265': ',797,658,585.',
#  '000000266': '.40486,860,55',
#  '000000267': '188,765,420.5',
#  '000000268': '903,765.505,6',
#  '000000269': ',831,761,751.',
#  '000000270': '535.237,942,8',
#  '000000271': ',814.474,826,',
#  '000000272': '5,574,507,163',
#  '000000273': '8,581.64151,5',
#  '000000274': '02,748,551,39',
#  '000000275': '.561,658,737,',
#  '000000276': '.383,829,032,',
#  '000000277': ',298,779,464.',
#  '000000278': '49.087,958,54',
#  '000000279': ',135.346,107,',
#  '000000280': ',737.109,141,',
#  '000000281': '691,920.688,9',
#  '000000282': '61,925,351.95',
#  '000000283': '.50593,508,52',
#  '000000284': '177.202,554,6',
#  '000000285': '304,520,319.7',
#  '000000286': '5,645.854,888',
#  '000000287': '2,816.29973,6',
#  '000000288': '504,276.589,1',
#  '000000289': '729,805,221.3',
#  '000000290': '292,148,185,4',
#  '000000291': '67,762,307,27',
#  '000000292': ',222,809,249.',
#  '000000293': '508,498,804.9',
#  '000000294': '8775,735,605.',
#  '000000295': '67,424,710.90',
#  '000000296': ',037,705,495.',
#  '000000297': '8,136.662,945',
#  '000000298': ',995,230,600.',
#  '000000299': '03,527.722,61',
#  '000000300': '648.274,159,1',
#  '000000301': '85.972,052,91',
#  '000000302': '883,120,599.9',
#  '000000303': '9,228,826,814',
#  '000000304': '.395,135,596,',
#  '000000305': '78330,940,422',
#  '000000306': '4,980,899,816',
#  '000000307': ',932,528.267,',
#  '000000308': '4.399,337,052',
#  '000000309': '.576,370,867,',
#  '000000310': '849,951,334,0',
#  '000000311': '540.984,857,6',
#  '000000312': ',859,208,074.',
#  '000000313': ',113.561,658,',
#  '000000314': '76,805.238,17',
#  '000000315': '9,435,083,918',
#  '000000316': '45.356,217,37',
#  '000000317': '4,204,777.176',
#  '000000318': '9,768.482,620',
#  '000000319': '96,344,766.57',
#  '000000320': '1,539.095,242',
#  '000000321': '.501,618,267,',
#  '000000322': '48671,958,118',
#  '000000323': ',148,185,447.',
#  '000000324': '46,241.493,54',
#  '000000325': '955,277,652,7',
#  '000000326': '035,468.227,6',
#  '000000327': '36,152,151.90',
#  '000000328': '22,830.393,49',
#  '000000329': ',445,763.338,',
#  '000000330': '948,265,046.6',
#  '000000331': ',141,838,609.',
#  '000000332': '85.224,275,20',
#  '000000333': '0.181,145,737',
#  '000000334': '609,807,595,5',
#  '000000335': '14,910,408,42',
#  '000000336': '67,437.916,77',
#  '000000337': '2,812.557,378',
#  '000000338': '10.2267,160,4',
#  '000000339': '5,311.875,240',
#  '000000340': '7,184,619,952',
#  '000000341': '6,204,413.401',
#  '000000342': '6,346,418,724',
#  '000000343': '095,996.047,6',
#  '000000344': '239,959,465,4',
#  '000000345': '220,483.303,2',
#  '000000346': '73,931,627.95',
#  '000000347': ',788,722.254,',
#  '000000348': '6.233,337,955',
#  '000000349': '9,765,694,338',
#  '000000350': '.81515,175,13',
#  '000000351': '1.235,154,408',
#  '000000352': '24.971,093,26',
#  '000000353': '83,742,519.42',
#  '000000354': '719,516,564.8',
#  '000000355': ',375,955,078.',
#  '000000356': '56,666,143,44',
#  '000000357': '97418,906,354',
#  '000000358': ',761,026,558.',
#  '000000359': ',185.301,187,',
#  '000000360': '0,523,767.401',
#  '000000361': '1,101,331.522',
#  '000000362': '8,976,968.877',
#  '000000363': '6,982,604.214',
#  '000000364': '7,607,555.424',
#  '000000365': '8,398,191.173',
#  '000000366': '4,109,844.938',
#  '000000367': '.883,423,130,',
#  '000000368': '369.687,240,1',
#  '000000369': '625,279,523.4',
#  '000000370': '.027,542,818,',
#  '000000371': ',167,729.585,',
#  '000000372': ',283,891,618.',
#  '000000373': ',392,654.643,',
#  '000000374': '7.803,343,790',
#  '000000375': '8,641,058,058',
#  '000000376': '278,856.032,9',
#  '000000377': '695,400.395,8',
#  '000000378': '207,902,471.1',
#  '000000379': '0,167.571,235',
#  '000000380': '421.511,505,1',
#  '000000381': '372,031.778,3',
#  '000000382': '817,837.578,1',
#  '000000383': '13,843,379,30',
#  '000000384': '88,937.369,84',
#  '000000385': '13,536,993.76',
#  '000000386': ',183.711,501,',
#  '000000387': ',851,509.253,',
#  '000000388': '75.332,932,45',
#  '000000389': '915,156.98880',
#  '000000390': '89,803,673,38',
#  '000000391': '.84808,535,22',
#  '000000392': '83,587,482.19',
#  '000000393': '192,804,736.8',
#  '000000394': '54.68395,283,',
#  '000000395': '61.914,666,06',
#  '000000396': '18,019,011,88',
#  '000000397': '4,019,425,789',
#  '000000398': '508,871.544,0',
#  '000000399': '282,249,457.8',
#  '000000400': '0,490.459,807',
#  '000000401': ',607.538,652,',
#  '000000402': '4,307.607,746',
#  '000000403': ',019,014,405.',
#  '000000404': '685.073,296,4',
#  '000000405': ',034.442,703,',
#  '000000406': '719.334,165,4',
#  '000000407': '6.134,156,291',
#  '000000408': '8,908,619,457',
#  '000000409': '9.203,830,633',
#  '000000410': '2.951,190,317',
#  '000000411': '56,412,229,73',
#  '000000412': '72,783,520,62',
#  '000000413': '95,242,481,65',
#  '000000414': ',382.629,423,',
#  '000000415': ',515,400,502.',
#  '000000416': '009,973.171,2',
#  '000000417': '393,497,718,0',
#  '000000418': '2,158,194.246',
#  '000000419': '8,132,180,045',
#  '000000420': '6,469,408,506',
#  '000000421': '6,650,703,570',
#  '000000422': '698,364,083.3',
#  '000000423': ',636.879,206,',
#  '000000424': '98,047.239,88',
#  '000000425': ',135,596,347.',
#  '000000426': '086,983,146,5',
#  '000000427': '9,923,012,551',
#  '000000428': '594,203,255.8',
#  '000000429': '89,267,824,01',
#  '000000430': '5,283.237,020',
#  '000000431': '534,863.129,4',
#  '000000432': '141,030.23929',
#  '000000433': '41.555,775,14',
#  '000000434': '1,310,078,064',
#  '000000435': '706.481,011,9',
#  '000000436': '1.219,427,163',
#  '000000437': '5.883,423,130',
#  '000000438': '842.767,721,4',
#  '000000439': '8.087,010,064',
#  '000000440': '.36592,391,66',
#  '000000441': ',442,019,701.',
#  '000000442': ',264.799,756,',
#  '000000443': '863,326,941.1',
#  '000000444': ',117,113.561,',
#  '000000445': '776,366,466,7',
#  '000000446': '786.543,372,7',
#  '000000447': '32,451,409.29',
#  '000000448': ',352,898,139.',
#  '000000449': '021,607.597,6',
#  '000000450': '220.865,912,7',
#  '000000451': '108.869,391,8',
#  '000000452': '88.297,570,27',
#  '000000453': '53,102,832.84',
#  '000000454': ',521,125,000.',
#  '000000455': '7.593,160,274',
#  '000000456': '8.645,138,161',
#  '000000457': ',199,168,621.',
#  '000000458': '21,087,925,88',
#  '000000459': '6.236,128,198',
#  '000000460': ',722.076,542,',
#  '000000461': '960.454,521,1',
#  '000000462': '2,945,534,051',
#  '000000463': '6,423.206,030',
#  '000000464': '084,280,811.2',
#  '000000465': '8,046.139,347',
#  '000000466': '9.105,261,313',
#  '000000467': '9.064,813,877',
#  '000000468': '78,412,301.01',
#  '000000469': '0,728.626,655',
#  '000000470': '.332,358,885,',
#  '000000471': '5,319.377,178',
#  '000000472': '4.71358,432,6',
#  '000000473': '.318,863,326,',
#  '000000474': '038,972,482,2',
#  '000000475': '7,855,350.656',
#  '000000476': '804,887,972.4',
#  '000000477': '9,642,787,887',
#  '000000478': ',157.922,906,',
#  '000000479': '30.3138,519,7',
#  '000000480': '20,267.054,62',
#  '000000481': '98755,645,400',
#  '000000482': '77.691,569,91',
#  '000000483': ',012,873,061.',
#  '000000484': '13,371,517,46',
#  '000000485': '6,942.964,938',
#  '000000486': '848,892.377,0',
#  '000000487': '8.489,989,741',
#  '000000488': '3,882.234,398',
#  '000000489': '2428,672,791.',
#  '000000490': ',607,665.634,',
#  '000000491': '929,375,392.3',
#  '000000492': '98.446,777,80',
#  '000000493': '891.609,807,5',
#  '000000494': '492,028.575,8',
#  '000000495': ',000,906,968.',
#  '000000496': '0,382.629,423',
#  '000000497': ',327,765.421,',
#  '000000498': '40,416.791,67',
#  '000000499': '8,147.08168,0',
#  '000000500': '70.359,766,40',
#  '000000501': '34.04393,682,',
#  '000000502': '21,076,250,49',
#  '000000503': '7.422,049,109',
#  '000000504': ',767,334,140.',
#  '000000505': '84.106,143,69',
#  '000000506': '86,308,893,78',
#  '000000507': ',211,737,077.',
#  '000000508': '1,658,737,873',
#  '000000509': '591,054,388.1',
#  '000000510': '08,669.578,48',
#  '000000511': '.163,348,967,',
#  '000000512': '13,371,517,46',
#  '000000513': '99,711,914,01',
#  '000000514': '4,782,724,282',
#  '000000515': '.056,145,122,',
#  '000000516': '6,143,444.554',
#  '000000517': '.732,431,676,',
#  '000000518': '821,235,623,4',
#  '000000519': '05,034.442,70',
#  '000000520': '449,357,751.1',
#  '000000521': '327,765.421,0',
#  '000000522': '436,583.152,6',
#  '000000523': ',766.358,927,',
#  '000000524': '163,978.484,2',
#  '000000525': '1,975.971,542',
#  '000000526': ',316,946,014.',
#  '000000527': '68.877,583,42',
#  '000000528': '250,504.329,8',
#  '000000529': '890,181.309,0',
#  '000000530': '34,863.129,47',
#  '000000531': '51,048.499,27',
#  '000000532': '.482,620,643,',
#  '000000533': '9,807,215,585',
#  '000000534': '2,086.687,819',
#  '000000535': ',085.308,066,',
#  '000000536': ',825,647,070.',
#  '000000537': '415,803.581,0',
#  '000000538': '08,012,873,06',
#  '000000539': '10.406,605,06',
#  '000000540': '8.00,,,,.,,,,',
#  '000000541': '45,122.853,12',
#  '000000542': '687,819,328,4',
#  '000000543': '9,151,401.558',
#  '000000544': '863,824.094,5',
#  '000000545': '11,001,597.31',
#  '000000546': '106,543.85243',
#  '000000547': '35,003.928,29',
#  '000000548': '8,898,040,706',
#  '000000549': '4,711,650,505',
#  '000000550': '489,784.777,0',
#  '000000551': '83,876.056,17',
#  '000000552': '03,957,945,00',
#  '000000553': ',487,648.067,',
#  '000000554': ',063,131.514,',
#  '000000555': '816.14932,511',
#  '000000556': ',777.176,357,',
#  '000000557': '.596,870,327,',
#  '000000558': '34,033,092.35',
#  '000000559': '5,801.617,536',
#  '000000560': '92,148,185,44',
#  '000000561': '311,050,130.3',
#  '000000562': '0,724,668.676',
#  '000000563': '063,457,066.9',
#  '000000564': '7.836,214,979',
#  '000000565': ',923,126,434.',
#  '000000566': '02.752,465,10',
#  '000000567': '10,014.451,78',
#  '000000568': '00,,,,.,,,,,,',
#  '000000569': '08,443.999,48',
#  '000000570': '78,489,237,07',
#  '000000571': '6.541,235,529',
#  '000000572': '66,405,156.36',
#  '000000573': ',115.421,260,',
#  '000000574': '955,380.818,4',
#  '000000575': '839,802,441,5',
#  '000000576': '5,574.254,153',
#  '000000577': ',805,563.909,',
#  '000000578': '82,401,615,63',
#  '000000579': '57.783,998,41',
#  '000000580': '5,128,001,890',
#  '000000581': '49.863,708,93',
#  '000000582': '3.161,295,534',
#  '000000583': '2,542.378,268',
#  '000000584': ',025.234,525,',
#  '000000585': '2,052,917,159',
#  '000000586': '169.802,885,7',
#  '000000587': ',090,638,581.',
#  '000000588': '462,133.71792',
#  '000000589': '6,036.20121,7',
#  '000000590': '.68139,126,99',
#  '000000591': '788,611.363,0',
#  '000000592': '066.955,509,6',
#  '000000593': '129,478,868,5',
#  '000000594': ',528.267,440,',
#  '000000595': '08,707,667.90',
#  '000000596': '6,921,788.618',
#  '000000597': '69,370,123.28',
#  '000000598': '826,989.298,4',
#  '000000599': '4,072,040,694',
#  '000000600': '7,748,035.395',
#  '000000601': '7,392,654.643',
#  '000000602': '990,906.299,7',
#  '000000603': '351,591,019.7',
#  '000000604': ',584,179.111,',
#  '000000605': '82,604.214,91',
#  '000000606': '72.951,190,31',
#  '000000607': ',638,581.6415',
#  '000000608': '35,123,108.86',
#  '000000609': ',564,122.984,',
#  '000000610': '93,312,982.73',
#  '000000611': '19.877,891,39',
#  '000000612': '53,071.207,28',
#  '000000613': '.406,231,224,',
#  '000000614': ',775.294,465,',
#  '000000615': '4,742.383,829',
#  '000000616': '.239,170,728,',
#  '000000617': '7.776,366,466',
#  '000000618': '.782,961,653,',
#  '000000619': ',278.392,055,',
#  '000000620': '.054,626,027,',
#  '000000621': '505,015.014,9',
#  '000000622': '09,141,799,41',
#  '000000623': '893,786.334,5',
#  '000000624': '09,249.458,19',
#  '000000625': ',721,449,374.',
#  '000000626': ',339,882,598.',
#  '000000627': '395,135,596,3',
#  '000000628': '22,809,249.45',
#  '000000629': ',446,514.089,',
#  '000000630': '6,604.532,713',
#  '000000631': '849,951,334,0',
#  '000000632': '7.578,857,608',
#  '000000633': '316,465,362,9',
#  '000000634': '778,826,989.2',
#  '000000635': '98,804.91179,',
#  '000000636': ',140,694,865.',
#  '000000637': '84,046,687.74',
#  '000000638': '28.397,654,42',
#  '000000639': '18,219,570.49',
#  '000000640': ',139,690.009,',
#  '000000641': '22,798,824,24',
#  '000000642': '55,985,732,79',
#  '000000643': '102,842,159.7',
#  '000000644': '4,804,887,972',
#  '000000645': '70,275,770.37',
#  '000000646': '869,391,855,5',
#  '000000647': '551.632,973,3',
#  '000000648': '26,452.218,48',
#  '000000649': ',893,786.334,',
#  '000000650': '.632,923,126,',
#  '000000651': '25.82502,210,',
#  '000000652': '09,923,012,55',
#  '000000653': '594,863,288,9',
#  '000000654': '21,078,838,80',
#  '000000655': '15,173,155.42',
#  '000000656': '78,281.212,79',
#  '000000657': '878,358,361,3',
#  '000000658': '457.877,239,4',
#  '000000659': ',424,710.907,',
#  '000000660': '1,995,230,600',
#  '000000661': '7,654,420,268',
#  '000000662': '274,571,722,9',
#  '000000663': ',594,648.936,',
#  '000000664': '90,690.963,63',
#  '000000665': '8,890,181.309',
#  '000000666': '7,253,472.951',
#  '000000667': '2,914.71358,4',
#  '000000668': '9,727,129.233',
#  '000000669': '212,035.525,1',
#  '000000670': '.178,361,906,',
#  '000000671': '.629,423,097,',
#  '000000672': '8,390,033,080',
#  '000000673': '.726,648,848,',
#  '000000674': '63,189,787,20',
#  '000000675': '982.737,710,7',
#  '000000676': '064,742.383,8',
#  '000000677': '.789,610,561,',
#  '000000678': '.617,184,047,',
#  '000000679': '55,582.96755,',
#  '000000680': '38,875,437.92',
#  '000000681': '626,027,787.4',
#  '000000682': ',789.046,059,',
#  '000000683': '349,523,003.5',
#  '000000684': '0,645.252,614',
#  '000000685': ',159,239,922.',
#  '000000686': ',659.05275,97',
#  '000000687': '579,635,208,4',
#  '000000688': ',278.392,055,',
#  '000000689': ',100,540.984,',
#  '000000690': '64,571,135.34',
#  '000000691': '717,085.551,4',
#  '000000692': '57,174.643,14',
#  '000000693': '4,338.99971,7',
#  '000000694': '6,301.554,858',
#  '000000695': '34,398,132,78',
#  '000000696': '10,915,243.94',
#  '000000697': '56,145,122,91',
#  '000000698': '772.437,636,6',
#  '000000699': '540,613.984,1',
#  '000000700': '557,164,471.7',
#  '000000701': '7.656,469,408',
#  '000000702': '07375,531,484',
#  '000000703': '6,979.771,938',
#  '000000704': '60907,423,389',
#  '000000705': '31.522,942,82',
#  '000000706': '39,467,295,47',
#  '000000707': '077.578,857,6',
#  '000000708': ',508,025.679,',
#  '000000709': '3,461,925,351',
#  '000000710': '47,521,981,15',
#  '000000711': '811.159,211,1',
#  '000000712': ',737.109,141,',
#  '000000713': '7,066.955,509',
#  '000000714': '57,144,041.86',
#  '000000715': '.797,037,129,',
#  '000000716': ',411.332,358,',
#  '000000717': '.476,681,489,',
#  '000000718': '.306,460,767,',
#  '000000719': '9,063,457,066',
#  '000000720': '.29888,497,44',
#  '000000721': '35.329,349,36',
#  '000000722': '9,389.865,207',
#  '000000723': '96,036.20121,',
#  '000000724': '4,312,910,334',
#  '000000725': '1,573,553,960',
#  '000000726': ',873.454,782,',
#  '000000727': ',948,217,192.',
#  '000000728': '2,082.477,053',
#  '000000729': ',957,130.721,',
#  '000000730': '011,611,078,6',
#  '000000731': '319,527.69587',
#  '000000732': '72,866,734,25',
#  '000000733': '.23929,472,98',
#  '000000734': '45,122,914.71',
#  '000000735': '3,155.427,343',
#  '000000736': ',535.197,808,',
#  '000000737': ',911,887.635,',
#  '000000738': '6,563.564,976',
#  '000000739': '.557,671,749,',
#  '000000740': '54,693,269.45',
#  '000000741': '823.022,998,1',
#  '000000742': ',530,398,634.',
#  '000000743': '567,050,360.1',
#  '000000744': '041,331.483,3',
#  '000000745': '787,212,035.5',
#  '000000746': '959,353,360.1',
#  '000000747': '047.239,883,1',
#  '000000748': '775.385,179,4',
#  '000000749': '57,624,101.26',
#  '000000750': '3,403,768,362',
#  '000000751': '8.21178,112,8',
#  '000000752': '3,673,382.456',
#  '000000753': '3,111,455.644',
#  '000000754': '4,041.864,800',
#  '000000755': '94,648.936,77',
#  '000000756': ',531,963.546,',
#  '000000757': '963,636,152,1',
#  '000000758': '725,421,244,4',
#  '000000759': ',248,890,181.',
#  '000000760': ',162,052.834,',
#  '000000761': '.594,863,288,',
#  '000000762': ',957,945,004.',
#  '000000763': '692,038,147.0',
#  '000000764': '63,131.514,97',
#  '000000765': ',449,727.292,',
#  '000000766': '6,680,459.778',
#  '000000767': '.36539,826,45',
#  '000000768': '41,799,414.32',
#  '000000769': '03,929,375,39',
#  '000000770': '69,867,719,66',
#  '000000771': '665,151,327,7',
#  '000000772': ',655.602,748,',
#  '000000773': '78990,862,828',
#  '000000774': ',803,368.652,',
#  '000000775': ',976,785.171,',
#  '000000776': '06.625,061,93',
#  '000000777': '9,357,751.183',
#  '000000778': '13.258,136,37',
#  '000000779': '83,742,519.42',
#  '000000780': '2,620,643,695',
#  '000000781': '1.956,436,793',
#  '000000782': '9.751,083,394',
#  '000000783': '665,011,696,0',
#  '000000784': ',034.442,703,',
#  '000000785': '4.29312,000,1',
#  '000000786': '0,197,741.614',
#  '000000787': '30.117,339,00',
#  '000000788': '.793,064,386,',
#  '000000789': '23,126,434.04',
#  '000000790': '350.056,145,1',
#  '000000791': '9,375,392.397',
#  '000000792': '549,889,178.4',
#  '000000793': '413,594,861,3',
#  '000000794': '976,968.877,5',
#  '000000795': '29,472,984.85',
#  '000000796': '9.458,190,446',
#  '000000797': '75,711,373,64',
#  '000000798': ',132.581,577,',
#  '000000799': '76,301.554,85',
#  '000000800': '.046,059,974,',
#  '000000801': '.255,883,742,',
#  '000000802': '492,408.926,6',
#  '000000803': '77,572.948,72',
#  '000000804': ',691,920.688,',
#  '000000805': '600.294,777,1',
#  '000000806': ',135,930,529.',
#  '000000807': '186.556,412,2',
#  '000000808': ',877,022.774,',
#  '000000809': '35,083,918.03',
#  '000000810': '7.401,892,016',
#  '000000811': '61,313,888.64',
#  '000000812': '29.585,273,21',
#  '000000813': ',673.726,648,',
#  '000000814': '312,982.737,7',
#  '000000815': '951,190,317,2',
#  '000000816': '67,731,074.31',
#  '000000817': '2,802,113.818',
#  '000000818': '81,145,737,53',
#  '000000819': '821,760.11164',
#  '000000820': '5.118,005,078',
#  '000000821': '23.412,838,52',
#  '000000822': ',308.295,223,',
#  '000000823': '53,383.972,02',
#  '000000824': '429,580.029,7',
#  '000000825': '.91179,915,15',
#  '000000826': '60,372,653.75',
#  '000000827': '4,099.144,473',
#  '000000828': '141,838,609.8',
#  '000000829': '499,680,011,1',
#  '000000830': '388,667,424,7',
#  '000000831': '.139,347,151,',
#  '000000832': ',824.903,957,',
#  '000000833': ',978,223.069,',
#  '000000834': '9.797,037,129',
#  '000000835': '4,520,319.799',
#  '000000836': '401.558,049,4',
#  '000000837': ',902,900,752.',
#  '000000838': '77.992,633,80',
#  '000000839': '629,423,097,3',
#  '000000840': '94,934,679.02',
#  '000000841': '67,006.486,94',
#  '000000842': ',654,048,756.',
#  '000000843': '22.197,186,56',
#  '000000844': '4.094,567,050',
#  '000000845': '8,132,180,045',
#  '000000846': '157,564,239,7',
#  '000000847': ',178.137,737,',
#  '000000848': ',481,275,966.',
#  '000000849': '139.668,584,0',
#  '000000850': '18,379,406.95',
#  '000000851': '.329,896,344,',
#  '000000852': '6.015,079,299',
#  '000000853': '23,003.543,18',
#  '000000854': '872,542.378,2',
#  '000000855': ',746,369,482.',
#  '000000856': '475.568,334,6',
#  '000000857': '626,801,107,5',
#  '000000858': '357,255,852,5',
#  '000000859': '40,694,865.37',
#  '000000860': '7,437,910.898',
#  '000000861': '01,890.085,34',
#  '000000862': ',735,965,645.',
#  '000000863': ',232,780,939.',
#  '000000864': '339,874,926,0',
#  '000000865': '957,159,559,9',
#  '000000866': '21,504,423.50',
#  '000000867': '460,523,767.4',
#  '000000868': '05,563.909,51',
#  '000000869': '990,862,828.3',
#  '000000870': '74,413.171,00',
#  '000000871': '1,083,439.665',
#  '000000872': '8,504,087.656',
#  '000000873': ',746.426,305,',
#  '000000874': '418,724.709,1',
#  '000000875': '0.845,351,873',
#  '000000876': '89.076,665,79',
#  '000000877': '421,087,925,8',
#  '000000878': '.721,928,417,',
#  '000000879': '5,211,190.885',
#  '000000880': ',803,948.811,',
#  '000000881': '405.511,365,0',
#  '000000882': '7606,532,037.',
#  '000000883': '5,146,834.187',
#  '000000884': '76.056,175,85',
#  '000000885': '2.964,938,622',
#  '000000886': ',497,445.578,',
#  '000000887': '039.561,335,4',
#  '000000888': ',445,286,512.',
#  '000000889': '471,840.945,1',
#  '000000890': ',434.04393,68',
#  '000000891': '543,087,547.3',
#  '000000892': '554,909,647,1',
#  '000000893': '837.448,023,3',
#  '000000894': '.129,478,868,',
#  '000000895': '17,361,795,52',
#  '000000896': ',243.729,123,',
#  '000000897': '8.297,570,275',
#  '000000898': '3,928,506.834',
#  '000000899': '952,500,505,2',
#  '000000900': '94,059,864,40',
#  '000000901': '39,106,882.41',
#  '000000902': '09,141,799,41',
#  '000000903': '.308,722,422,',
#  '000000904': '7,037,129,850',
#  '000000905': '0.294,777,168',
#  '000000906': '5,861.958,808',
#  '000000907': '564,074,085.3',
#  '000000908': '640,416.791,6',
#  '000000909': ',680,459.778,',
#  '000000910': '3,003.543,183',
#  '000000911': '4,007.127,651',
#  '000000912': ',997,021,379.',
#  '000000913': '6,920,981,947',
#  '000000914': ',952.292,148,',
#  '000000915': '4,635,804,221',
#  '000000916': '258,987,607.5',
#  '000000917': ',925,873.454,',
#  '000000918': '78.137,737,34',
#  '000000919': '667,424,710.9',
#  '000000920': '1,009,973.171',
#  '000000921': '4,125,957.947',
#  '000000922': '32.759,993,31',
#  '000000923': '607,665.634,8',
#  '000000924': '.355,339,882,',
#  '000000925': '557,901,242.0',
#  '000000926': '997,298,779,4',
#  '000000927': '732,087,313,0',
#  '000000928': ',834.187,581,',
#  '000000929': '645.854,888,5',
#  '000000930': '504,276.589,1',
#  '000000931': '84,900,633.99',
#  '000000932': ',973,305,111.',
#  '000000933': '6,288,785.186',
#  '000000934': '.655,169,903,',
#  '000000935': '816.29973,604',
#  '000000936': '1,708.063,625',
#  '000000937': ',622,909,952.',
#  '000000938': '8,885,746.426',
#  '000000939': '.854,888,568,',
#  '000000940': ',540,091,706.',
#  '000000941': '8,885,746.426',
#  '000000942': '1,591,019.726',
#  '000000943': '233,537,717,0',
#  '000000944': ',052,917,159.',
#  '000000945': ',998,412,686.',
#  '000000946': '558.624,141,8',
#  '000000947': '4.16191,452,8',
#  '000000948': ',887.275,848,',
#  '000000949': '475,711,373,6',
#  '000000950': '15,758.527,65',
#  '000000951': '6,729,805,221',
#  '000000952': '250,492.722,0',
#  '000000953': ',814,268.902,',
#  '000000954': '469,035,024.9',
#  '000000955': '2,402.247,490',
#  '000000956': '6,897,478,373',
#  '000000957': '.429,836,774,',
#  '000000958': '07,813,875.41',
#  '000000959': '821,760.11164',
#  '000000960': '1,291,788,611',
#  '000000961': ',186,564,447.',
#  '000000962': ',023,358,405.',
#  '000000963': '787,212,035.5',
#  '000000964': ',468.665,518,',
#  '000000965': '7,442.819,501',
#  '000000966': ',438,468.632,',
#  '000000967': '2,177.285,907',
#  '000000968': '788,611.363,0',
#  '000000969': ',289,680.4515',
#  '000000970': '646.664,339,1',
#  '000000971': '8,147.499,680',
#  '000000972': '3,422,486.413',
#  '000000973': ',319,357.157,',
#  '000000974': '3,182,308.295',
#  '000000975': '96,789,117,17',
#  '000000976': ',258,987,607.',
#  '000000977': '3,467.617,184',
#  '000000978': ',517.099,009,',
#  '000000979': '8,899,237.041',
#  '000000980': '9.046,059,974',
#  '000000981': '.197,186,564,',
#  '000000982': '2.579,761,026',
#  '000000983': '45,108.353,25',
#  '000000984': '5,122.853,128',
#  '000000985': '81,283,837.44',
#  '000000986': '47,437,230,09',
#  '000000987': ',199,168,621.',
#  '000000988': '.078,511,207,',
#  '000000989': '2,910,334.038',
#  '000000990': '1,281.027,542',
#  '000000991': '842,159.744,1',
#  '000000992': '408,506.525,9',
#  '000000993': '507,520,386.3',
#  '000000994': '.079,447,299,',
#  '000000995': '83,175.17526,',
#  '000000996': '01.011,611,07',
#  '000000997': '60,838.408,11',
#  '000000998': '17.525,944,12',
#  '000000999': ',731,936,274.',
#  ...}

# %%
label_list=[]
dirpath = "/home/elimen/Data/OCR_dataset/synthetic_digit"

for i,k in enumerate(digitimg_dict['labels']):
    v = digitimg_dict['labels'][k]
    path = ''
    img_path = os.path.join(dirpath,d)
    label = img_path + ".jpg" + "\t" + v
    label_list.append(label)

label_list
# Out:
# ['/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,580,368.722,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,724,282.336,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,945.608,012,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t3,856,048.814',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,232,981,268.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t42,346.461,11',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t9.646,629,956',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t75,240,443,83',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t9,375,392.397',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t05,112,130,96',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t61,653,981.73',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t26.428,765,58',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t717,692,038,1',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t51.419,846,58',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.607,746,369,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,572.948,725,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.508,037,705,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t3306,790,159.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t2,377.691,569',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t9418,899,237.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t508,037,705,4',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,203.331,573,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,895,980.357,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t0,117,306.657',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t6,465,362,910',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t2,312.846,929',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t409,973.619,0',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t978,115,340,7',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t98,779,464.67',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t78,504,087.65',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,314,224.8480',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t214,979,835.3',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,751.766,667,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t542,818,842.7',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,395.307,559,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t093,618.087,0',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t6,107,243,259',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t82,724,282.33',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t49,951,334,08',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.602,748,551,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t670.326,481,2',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t41,497,217,00',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t40.386,308,89',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t50.955,277,65',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t60,558.523,24',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t667.904,159,0',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t231,024,379,7',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t388.172,728,5',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t612,467,748,0',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t4,713,536,993',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t47,472.733,02',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t856,637,539,9',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t196,789,117,1',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t3,641.779,123',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t38,972,482,24',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.757,015,947,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t2,891,234,935',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t243.729,123,0',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,936,637,337.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,366,466,748.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t69,914,963.97',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t566.49160,647',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t51,194.818,64',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t4.106,143,690',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,122,626.541,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t73.171,268,87',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t989,741,395.3',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,275,966.619,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,490,771.988,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t81,011,909,25',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t05,156.363,18',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.341,483,856,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t4,473,931,627',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,408.926,640,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t09,738,208.99',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t461,605,074.2',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t21.907,001,79',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t626.541,235,5',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.609,913,872,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t955,509,669,5',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t23929,472,984',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t4,979,835.301',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t0.11164,990,9',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t821,696,411.3',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t707,828.251,5',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t50267,143,442',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t860,558.523,2',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,907,813,875.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t807,318,230,6',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.584,337,136,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t70,751,935.09',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t67,437.916,77',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t862,841,785,8',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t08,639,978.19',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.049,488,999,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,734,253.587,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t34,506,611,39',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t66,767,334,14',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t3,587,482.199',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,721,449,374.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t45.608,012,87',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t69,410,167.57',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t8.02140,880,0',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.294,938,435,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t94,203,255.86',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t018.779,984,2',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t214,910,408,4',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t150.747,397,8',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t60.004,635,80',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t15,022.472,72',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t8.471,044,128',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.235,154,408,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,886,680.189,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t22,830.393,49',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t4,540,829.692',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,899,237.041,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t82,677,451.19',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t337.171,606,3',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t8,197,105,801',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.484,208,707,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,422,486.413,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,068,827.528,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,138,891.609,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.442,703,138,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t23,041,039.56',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,804.91179,91',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t5,355,126,595',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t89,085,262,07',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t729,653,677,0',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t84,017,315.85',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t5.41966,508,8',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,309.599,401,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t39,275,263,38',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t1,327,765.421',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t4,998,563.759',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t2,391,663.633',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t08,722,422,34',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t11,605,586,18',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t9,085,262,077',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t82,335,417,16',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t17526,982,604',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t251,975.971,5',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t75,025.234,52',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t26,814.474,82',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t7,664,874,158',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t709,514.8866,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t1,696,036.201',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t287,510,487,6',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t774,248,232,8',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t171,689,388,9',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t843,379,306.2',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t8.589,085,262',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t003,929,375,3',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t361,281.027,5',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t141,045,247,1',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,372,619,658.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t24,570,174.16',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t4,976,703,527',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t90,771.988,00',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t4,737.462,913',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t0.884,481,209',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t99,941.734,11',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t65,518,250,10',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,946,063,131.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t39,802,441,59',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t2.234,398,132',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t61,026,558.62',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t9,903,765.505',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t71792,135,531',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,063,583.717,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t859,864,571,1',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t76,507,386.68',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t87,828,136.66',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t570,174.169,0',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t9,530,398,634',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t27.251,839,90',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t9,002,269,700',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.069,116,699,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,752.192,891,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t473.796,211,0',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,062.014,754,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.252,614,278,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t73,928,506.83',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t61,281.027,54',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t7,215,585.077',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,736.134,021,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t759,993,312,9',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t309,738,208.9',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t9,512,799,941',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,997,437,910.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t1,830,508.318',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t309,047.444,5',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t4,540,075.461',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t8,827.528,865',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t46,190,459,78',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t9,565,132.128',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t862.355,339,8',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t867,719,664.1',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t82,138,700,05',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t9,361.915,534',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t6,859,208,074',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t117,306.657,7',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,619,952.3653',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.895,355,126,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t73,627,948,82',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,042,159.171,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t1.419,846,580',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t14,224.84808,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t6,077,177.202',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t26.479,388,38',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.348,098,510,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t962,402.247,4',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t1.555,775,146',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t534,506,611,3',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t39,126,992.22',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t189,537,006.7',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t72.895,355,12',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,164,471.783,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,952,127.671,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,460,939,525.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t770.18611,831',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,581,469,768.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t69,584.54681,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t52,782.469,00',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t0,599.966,272',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t18,641,058,05',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t63.261,328,18',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,525.76401,14',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,337,718,737.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t867,617.884,4',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t7,678.294,938',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t22,952,127.67',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,389.865,207,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t9,183.711,501',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t526,097,756,6',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t799,351,591,0',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t21,846,464,10',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t64.809,435,08',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t3.576,962,478',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,843.385,915,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,501,443,321.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t68.652,333,18',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,426.622,589,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t6,946,063,131',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t401,892,016,7',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t141,045,247,1',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t604.532,713,9',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t98.733,933,50',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t935.152,833,1',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t218,019,011,8',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t254,249,323,3',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t7,854,930,303',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t2,589,941,439',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t40879,834,743',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t4,909,647,192',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t6,238,931.966',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,228,826,814.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t9,719.334,165',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,337,906.304,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t27,759.29888,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,883,742,519.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.239,489,564,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t997,298,779,4',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t838,609.839,8',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t78,051,974.46',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,797,658,585.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.40486,860,55',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t188,765,420.5',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t903,765.505,6',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,831,761,751.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t535.237,942,8',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,814.474,826,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t5,574,507,163',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t8,581.64151,5',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t02,748,551,39',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.561,658,737,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.383,829,032,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,298,779,464.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t49.087,958,54',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,135.346,107,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,737.109,141,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t691,920.688,9',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t61,925,351.95',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.50593,508,52',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t177.202,554,6',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t304,520,319.7',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t5,645.854,888',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t2,816.29973,6',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t504,276.589,1',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t729,805,221.3',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t292,148,185,4',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t67,762,307,27',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,222,809,249.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t508,498,804.9',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t8775,735,605.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t67,424,710.90',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,037,705,495.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t8,136.662,945',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,995,230,600.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t03,527.722,61',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t648.274,159,1',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t85.972,052,91',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t883,120,599.9',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t9,228,826,814',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.395,135,596,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t78330,940,422',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t4,980,899,816',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,932,528.267,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t4.399,337,052',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.576,370,867,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t849,951,334,0',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t540.984,857,6',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,859,208,074.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,113.561,658,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t76,805.238,17',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t9,435,083,918',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t45.356,217,37',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t4,204,777.176',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t9,768.482,620',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t96,344,766.57',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t1,539.095,242',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.501,618,267,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t48671,958,118',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,148,185,447.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t46,241.493,54',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t955,277,652,7',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t035,468.227,6',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t36,152,151.90',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t22,830.393,49',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,445,763.338,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t948,265,046.6',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,141,838,609.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t85.224,275,20',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t0.181,145,737',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t609,807,595,5',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t14,910,408,42',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t67,437.916,77',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t2,812.557,378',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t10.2267,160,4',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t5,311.875,240',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t7,184,619,952',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t6,204,413.401',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t6,346,418,724',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t095,996.047,6',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t239,959,465,4',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t220,483.303,2',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t73,931,627.95',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,788,722.254,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t6.233,337,955',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t9,765,694,338',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.81515,175,13',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t1.235,154,408',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t24.971,093,26',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t83,742,519.42',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t719,516,564.8',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,375,955,078.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t56,666,143,44',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t97418,906,354',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,761,026,558.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,185.301,187,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t0,523,767.401',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t1,101,331.522',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t8,976,968.877',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t6,982,604.214',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t7,607,555.424',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t8,398,191.173',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t4,109,844.938',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.883,423,130,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t369.687,240,1',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t625,279,523.4',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.027,542,818,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,167,729.585,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,283,891,618.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,392,654.643,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t7.803,343,790',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t8,641,058,058',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t278,856.032,9',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t695,400.395,8',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t207,902,471.1',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t0,167.571,235',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t421.511,505,1',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t372,031.778,3',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t817,837.578,1',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t13,843,379,30',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t88,937.369,84',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t13,536,993.76',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,183.711,501,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,851,509.253,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t75.332,932,45',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t915,156.98880',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t89,803,673,38',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.84808,535,22',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t83,587,482.19',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t192,804,736.8',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t54.68395,283,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t61.914,666,06',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t18,019,011,88',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t4,019,425,789',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t508,871.544,0',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t282,249,457.8',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t0,490.459,807',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,607.538,652,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t4,307.607,746',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,019,014,405.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t685.073,296,4',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,034.442,703,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t719.334,165,4',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t6.134,156,291',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t8,908,619,457',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t9.203,830,633',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t2.951,190,317',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t56,412,229,73',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t72,783,520,62',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t95,242,481,65',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,382.629,423,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,515,400,502.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t009,973.171,2',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t393,497,718,0',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t2,158,194.246',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t8,132,180,045',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t6,469,408,506',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t6,650,703,570',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t698,364,083.3',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,636.879,206,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t98,047.239,88',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,135,596,347.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t086,983,146,5',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t9,923,012,551',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t594,203,255.8',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t89,267,824,01',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t5,283.237,020',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t534,863.129,4',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t141,030.23929',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t41.555,775,14',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t1,310,078,064',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t706.481,011,9',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t1.219,427,163',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t5.883,423,130',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t842.767,721,4',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t8.087,010,064',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.36592,391,66',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,442,019,701.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,264.799,756,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t863,326,941.1',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,117,113.561,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t776,366,466,7',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t786.543,372,7',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t32,451,409.29',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,352,898,139.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t021,607.597,6',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t220.865,912,7',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t108.869,391,8',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t88.297,570,27',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t53,102,832.84',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,521,125,000.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t7.593,160,274',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t8.645,138,161',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,199,168,621.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t21,087,925,88',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t6.236,128,198',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,722.076,542,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t960.454,521,1',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t2,945,534,051',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t6,423.206,030',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t084,280,811.2',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t8,046.139,347',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t9.105,261,313',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t9.064,813,877',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t78,412,301.01',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t0,728.626,655',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.332,358,885,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t5,319.377,178',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t4.71358,432,6',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.318,863,326,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t038,972,482,2',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t7,855,350.656',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t804,887,972.4',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t9,642,787,887',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,157.922,906,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t30.3138,519,7',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t20,267.054,62',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t98755,645,400',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t77.691,569,91',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,012,873,061.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t13,371,517,46',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t6,942.964,938',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t848,892.377,0',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t8.489,989,741',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t3,882.234,398',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t2428,672,791.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,607,665.634,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t929,375,392.3',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t98.446,777,80',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t891.609,807,5',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t492,028.575,8',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,000,906,968.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t0,382.629,423',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,327,765.421,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t40,416.791,67',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t8,147.08168,0',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t70.359,766,40',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t34.04393,682,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t21,076,250,49',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t7.422,049,109',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,767,334,140.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t84.106,143,69',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t86,308,893,78',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,211,737,077.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t1,658,737,873',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t591,054,388.1',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t08,669.578,48',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.163,348,967,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t13,371,517,46',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t99,711,914,01',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t4,782,724,282',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.056,145,122,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t6,143,444.554',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.732,431,676,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t821,235,623,4',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t05,034.442,70',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t449,357,751.1',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t327,765.421,0',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t436,583.152,6',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,766.358,927,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t163,978.484,2',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t1,975.971,542',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,316,946,014.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t68.877,583,42',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t250,504.329,8',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t890,181.309,0',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t34,863.129,47',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t51,048.499,27',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.482,620,643,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t9,807,215,585',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t2,086.687,819',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,085.308,066,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,825,647,070.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t415,803.581,0',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t08,012,873,06',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t10.406,605,06',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t8.00,,,,.,,,,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t45,122.853,12',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t687,819,328,4',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t9,151,401.558',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t863,824.094,5',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t11,001,597.31',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t106,543.85243',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t35,003.928,29',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t8,898,040,706',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t4,711,650,505',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t489,784.777,0',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t83,876.056,17',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t03,957,945,00',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,487,648.067,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,063,131.514,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t816.14932,511',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,777.176,357,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.596,870,327,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t34,033,092.35',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t5,801.617,536',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t92,148,185,44',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t311,050,130.3',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t0,724,668.676',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t063,457,066.9',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t7.836,214,979',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,923,126,434.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t02.752,465,10',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t10,014.451,78',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t00,,,,.,,,,,,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t08,443.999,48',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t78,489,237,07',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t6.541,235,529',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t66,405,156.36',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,115.421,260,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t955,380.818,4',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t839,802,441,5',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t5,574.254,153',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,805,563.909,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t82,401,615,63',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t57.783,998,41',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t5,128,001,890',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t49.863,708,93',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t3.161,295,534',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t2,542.378,268',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,025.234,525,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t2,052,917,159',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t169.802,885,7',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,090,638,581.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t462,133.71792',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t6,036.20121,7',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.68139,126,99',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t788,611.363,0',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t066.955,509,6',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t129,478,868,5',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,528.267,440,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t08,707,667.90',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t6,921,788.618',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t69,370,123.28',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t826,989.298,4',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t4,072,040,694',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t7,748,035.395',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t7,392,654.643',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t990,906.299,7',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t351,591,019.7',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,584,179.111,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t82,604.214,91',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t72.951,190,31',
# ...
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,132.581,577,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t76,301.554,85',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.046,059,974,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.255,883,742,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t492,408.926,6',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t77,572.948,72',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,691,920.688,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t600.294,777,1',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,135,930,529.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t186.556,412,2',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,877,022.774,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t35,083,918.03',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t7.401,892,016',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t61,313,888.64',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t29.585,273,21',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,673.726,648,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t312,982.737,7',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t951,190,317,2',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t67,731,074.31',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t2,802,113.818',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t81,145,737,53',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t821,760.11164',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t5.118,005,078',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t23.412,838,52',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,308.295,223,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t53,383.972,02',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t429,580.029,7',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.91179,915,15',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t60,372,653.75',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t4,099.144,473',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t141,838,609.8',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t499,680,011,1',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t388,667,424,7',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.139,347,151,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,824.903,957,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,978,223.069,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t9.797,037,129',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t4,520,319.799',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t401.558,049,4',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,902,900,752.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t77.992,633,80',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t629,423,097,3',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t94,934,679.02',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t67,006.486,94',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,654,048,756.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t22.197,186,56',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t4.094,567,050',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t8,132,180,045',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t157,564,239,7',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,178.137,737,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,481,275,966.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t139.668,584,0',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t18,379,406.95',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.329,896,344,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t6.015,079,299',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t23,003.543,18',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t872,542.378,2',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,746,369,482.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t475.568,334,6',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t626,801,107,5',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t357,255,852,5',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t40,694,865.37',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t7,437,910.898',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t01,890.085,34',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,735,965,645.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,232,780,939.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t339,874,926,0',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t957,159,559,9',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t21,504,423.50',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t460,523,767.4',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t05,563.909,51',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t990,862,828.3',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t74,413.171,00',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t1,083,439.665',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t8,504,087.656',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,746.426,305,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t418,724.709,1',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t0.845,351,873',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t89.076,665,79',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t421,087,925,8',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.721,928,417,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t5,211,190.885',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,803,948.811,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t405.511,365,0',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t7606,532,037.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t5,146,834.187',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t76.056,175,85',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t2.964,938,622',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,497,445.578,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t039.561,335,4',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,445,286,512.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t471,840.945,1',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,434.04393,68',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t543,087,547.3',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t554,909,647,1',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t837.448,023,3',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.129,478,868,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t17,361,795,52',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,243.729,123,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t8.297,570,275',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t3,928,506.834',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t952,500,505,2',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t94,059,864,40',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t39,106,882.41',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t09,141,799,41',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.308,722,422,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t7,037,129,850',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t0.294,777,168',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t5,861.958,808',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t564,074,085.3',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t640,416.791,6',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,680,459.778,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t3,003.543,183',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t4,007.127,651',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,997,021,379.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t6,920,981,947',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,952.292,148,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t4,635,804,221',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t258,987,607.5',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,925,873.454,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t78.137,737,34',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t667,424,710.9',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t1,009,973.171',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t4,125,957.947',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t32.759,993,31',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t607,665.634,8',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.355,339,882,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t557,901,242.0',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t997,298,779,4',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t732,087,313,0',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,834.187,581,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t645.854,888,5',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t504,276.589,1',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t84,900,633.99',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,973,305,111.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t6,288,785.186',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.655,169,903,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t816.29973,604',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t1,708.063,625',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,622,909,952.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t8,885,746.426',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.854,888,568,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,540,091,706.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t8,885,746.426',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t1,591,019.726',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t233,537,717,0',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,052,917,159.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,998,412,686.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t558.624,141,8',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t4.16191,452,8',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,887.275,848,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t475,711,373,6',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t15,758.527,65',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t6,729,805,221',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t250,492.722,0',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,814,268.902,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t469,035,024.9',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t2,402.247,490',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t6,897,478,373',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.429,836,774,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t07,813,875.41',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t821,760.11164',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t1,291,788,611',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,186,564,447.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,023,358,405.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t787,212,035.5',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,468.665,518,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t7,442.819,501',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,438,468.632,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t2,177.285,907',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t788,611.363,0',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,289,680.4515',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t646.664,339,1',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t8,147.499,680',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t3,422,486.413',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,319,357.157,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t3,182,308.295',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t96,789,117,17',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,258,987,607.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t3,467.617,184',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,517.099,009,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t8,899,237.041',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t9.046,059,974',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.197,186,564,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t2.579,761,026',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t45,108.353,25',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t5,122.853,128',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t81,283,837.44',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t47,437,230,09',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,199,168,621.',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.078,511,207,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t2,910,334.038',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t1,281.027,542',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t842,159.744,1',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t408,506.525,9',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t507,520,386.3',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t.079,447,299,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t83,175.17526,',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t01.011,611,07',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t60,838.408,11',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t17.525,944,12',
#  '/home/elimen/Data/OCR_dataset/synthetic_digit/000000000.jpg\t,731,936,274.',
#  ...]

# %%
with open("/home/elimen/Data/OCR_dataset/synthetic_digit/train.txt","w") as fjson_writer:
    for i in range(len(label_list)):
        fjson_writer.writelines(label_list[i]+"\n")
